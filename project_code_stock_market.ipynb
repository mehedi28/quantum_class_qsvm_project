# %%
# Team Member
# Md Mehed Hasan - R11919067
# Rushikesh Reddy Bayyapu - R11870538
# Afahan Javed - R11985175

# %% [markdown]
# # Total 7 Attempts we tried. We will follow running every cell and all attempts to check results and finally get the expected results using ZZ feature map for QSVM

# %% [markdown]
# # For QSVM and classical, we compared 100 samples vs 200 samples results

# %% [markdown]
# # Then, we compared QSVM results for 100, 300 and 500 samples

# %% [markdown]
# # Cell 1: Import libraries

# %%
# package version used while training
# numpy: 2.4.4
# pandas: 3.0.2
# matplotlib: 3.10.8
# seaborn: 0.13.2
# sklearn: 1.8.0
# qiskit: 2.3.0
# yfinance: 1.2.2

# %%
# Core numerical and data libraries
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# Utility libraries for copying, timing, and warnings
import copy
import time
import warnings

# Suppress warning messages
warnings.filterwarnings("ignore")

# Financial data source (Yahoo Finance)
import yfinance as yf

# Machine learning tools
import sklearn
from sklearn import model_selection, svm
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler

# Quantum computing libraries (Qiskit)
import qiskit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile

# Quantum simulator backend
from qiskit.providers.basic_provider import BasicSimulator

# Initialize the simulator
simulator = BasicSimulator()

# Print confirmation
print("All libraries loaded.")

# Print package versions
print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("matplotlib:", matplotlib.__version__)
print("seaborn:", sns.__version__)
print("sklearn:", sklearn.__version__)
print("qiskit:", qiskit.__version__)
print("yfinance:", yf.__version__)
# Out:
# All libraries loaded.
# numpy: 2.4.4
# pandas: 3.0.2
# matplotlib: 3.10.8
# seaborn: 0.13.2
# sklearn: 1.8.0
# qiskit: 2.3.0
# yfinance: 1.2.2

# %% [markdown]
# # Cell 2: Data Download

# %%
# Define stock ticker symbol (Apple Inc.)
ticker = "AAPL"

# Download historical stock data from Yahoo Finance
# Date range: Jan 1, 2019 to Jan 1, 2024
# auto_adjust=True adjusts prices for splits/dividends
df = yf.download(ticker, start="2019-01-01", end="2024-01-01", auto_adjust=True)

# Check if the dataframe has multi-level column names
# If yes, keep only the main column level (e.g., Open, Close, Volume)
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)

# Print the shape of the dataset (rows, columns)
print(df.shape)

# Display the first 5 rows of the dataset
print(df.head(5))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1258, 5)
# Price           Close       High        Low       Open     Volume
# Date
# 2019-01-02  37.503727  37.724590  36.627404  36.784146  148158800
# 2019-01-03  33.768078  34.606402  33.722955  34.193175  365248800
# 2019-01-04  35.209618  35.278490  34.150434  34.323797  234428400
# 2019-01-07  35.131245  35.344984  34.649149  35.314110  219111200
# 2019-01-08  35.800945  36.055057  35.271354  35.518337  164101200

# %% [markdown]
# # Cell 3: Feature Engineering

# %%
# Compute daily returns as percentage change in closing price
df["Return"]     = df["Close"].pct_change()

# Compute rolling volatility using 20-day standard deviation of returns
df["Volatility"] = df["Return"].rolling(window=20).std()

# Function to compute Relative Strength Index (RSI)
def compute_rsi(series, period=14):
    # Calculate price changes
    delta    = series.diff()

    # Separate gains (positive changes) and losses (negative changes)
    gain     = delta.clip(lower=0)
    loss     = -delta.clip(upper=0)

    # Compute rolling average gain and loss
    avg_gain = gain.rolling(window=period).mean()
    avg_loss = loss.rolling(window=period).mean()

    # Compute relative strength (RS)
    rs       = avg_gain / avg_loss

    # Convert RS to RSI
    return 100 - (100 / (1 + rs))

# Apply RSI calculation on closing prices
df["RSI"]      = compute_rsi(df["Close"])

# Compute momentum as difference between current price and price 20 days ago
df["Momentum"] = df["Close"] - df["Close"].shift(20)

# Remove rows with missing values created by rolling calculations
df.dropna(inplace=True)

# Display first 5 rows of selected features
print(df[["Return","Volatility","RSI","Momentum"]].head(5))

# Print final dataset shape
print(f"Shape: {df.shape}")
# Out:
# Price         Return  Volatility        RSI  Momentum
# Date
# 2019-01-31  0.007201    0.032260  67.614277  2.023376
# 2019-02-01  0.000481    0.021427  70.653131  5.778023
# 2019-02-04  0.028405    0.020430  78.801872  5.459782
# 2019-02-05  0.017110    0.020406  78.721143  6.233994
# 2019-02-06  0.000345    0.020320  77.618783  5.578545
# Shape: (1238, 9)

# %% [markdown]
# # Cell 4: Regime Labels

# %%
# Compute lower and upper thresholds (33rd and 67th percentiles of returns)
low_ret  = float(df["Return"].quantile(0.33))
high_ret = float(df["Return"].quantile(0.67))

# Function to assign regime labels based on return thresholds
def assign_label(row):
    # High return regime
    if row["Return"] >= high_ret:
        return 0
    # Low return regime
    elif row["Return"] <= low_ret:
        return 1
    # Medium (neutral) regime
    else:
        return 2

# Apply labeling function to each row to create Regime column
df["Regime"] = df.apply(assign_label, axis=1)

# Print distribution of labels to check class balance
print("Label distribution:")
print(df["Regime"].value_counts())
# Out:
# Label distribution:
# Regime
# 2    420
# 0    409
# 1    409
# Name: count, dtype: int64

# %% [markdown]
# # Cell 5: Normalize and Split

# %%
# Define the input feature columns and extract them as a NumPy array
features = ["Return", "Volatility", "RSI", "Momentum"]
X = df[features].values

# Extract the target labels (market regime) as a NumPy array
Y = df["Regime"].values

# Scale all features to the range [0, 2*pi]
# This range is required for quantum circuits that use angle encoding,
# where each feature is mapped onto a rotation angle on the Bloch sphere
scaler = MinMaxScaler(feature_range=(0, 2 * np.pi))
X      = scaler.fit_transform(X)

# First split: separate out 33% of the data as the test set
# stratify=Y preserves the class distribution in both splits
# random_state=42 ensures reproducibility
X_train_full, X_test, Y_train_full, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.33, random_state=42, stratify=Y)

# Second split: from the remaining 67%, hold out 20% as the validation set
# This gives a final split of roughly 54% train / 13% validation / 33% test
X_train, X_val, Y_train, Y_val = model_selection.train_test_split(
    X_train_full, Y_train_full, test_size=0.20, random_state=42, stratify=Y_train_full)

# Print the size of each split to confirm the partitioning
print(f"Train : {X_train.shape[0]}  |  Val : {X_val.shape[0]}  |  Test : {X_test.shape[0]}")

# Print the number of samples in each class for each split
# np.bincount counts how many times each integer label appears
# This helps verify that stratification kept the class balance consistent
print(f"Train labels : {np.bincount(Y_train)}")
print(f"Val   labels : {np.bincount(Y_val)}")
print(f"Test  labels : {np.bincount(Y_test)}")
# Out:
# Train : 663  |  Val : 166  |  Test : 409
# Train labels : [219 219 225]
# Val   labels : [55 55 56]
# Test  labels : [135 135 139]

# %% [markdown]
# # Cell 6: Summary Table

# %%
# This table accumulates results from every attempt.
# Run this cell once, then update it after each attempt.

# Global list that stores all logged attempts as tuples
# Each entry: (number, approach, what_was_tried, output_or_issue, status)
attempt_log = []

def show_summary():
    """Print a formatted ASCII table summarizing all logged attempts."""

    # Handle the empty case: nothing to show yet
    if not attempt_log:
        print("No attempts logged yet.")
        return

    # Column widths in characters for each of the five columns
    # Order: #, Approach, What Was Tried, Output / Issue, Status
    col_w = [4, 16, 34, 34, 10]

    # Column header labels (must match the order of col_w)
    headers = ["#", "Approach", "What Was Tried", "Output / Issue", "Status"]

    # Total width of the table including column separators (one '|' per column edge)
    total_w = sum(col_w) + len(col_w) + 1

    # Horizontal separator line built from dashes between '+' marks
    sep = "+" + "+".join("-" * w for w in col_w) + "+"

    def wrap(text, width):
        """Wrap a string into a list of lines, each at most `width` characters.

        Splits on whitespace and greedily fits words onto each line.
        Used so long text in a cell flows across multiple rows instead
        of overflowing the column.
        """
        words = text.split()
        lines, line = [], ""
        for w in words:
            # If adding this word still fits, append it to the current line
            if len(line) + len(w) + 1 <= width:
                line += (" " if line else "") + w
            else:
                # Otherwise, push the current line and start a new one
                lines.append(line)
                line = w
        # append
        lines.append(line)
        return lines

    # Print the table title block
    print("\n" + "=" * total_w)
    print("  DEVELOPMENT ATTEMPT SUMMARY")
    print("=" * total_w)
    print(sep)

    # Build and print the header row by centering each header in its column width
    header_row = "|" + "|".join(h.center(col_w[i]) for i, h in enumerate(headers)) + "|"
    print(header_row)
    print(sep)

    # Map raw status values to display strings with ASCII/Unicode markers
    status_icons = {"Failed": "✗ Failed", "Partial": "~ Partial", "Success": "✓ Success"}

    # Render each logged attempt as one (possibly multi-line) row
    for row in attempt_log:
        num, approach, tried, output, status = row

        # Wrap each cell's content to its column width
        # The "#" column is always one line, just centered
        c0 = [str(num).center(col_w[0])]
        c1 = wrap(approach,  col_w[1])
        c2 = wrap(tried,     col_w[2])
        c3 = wrap(output,    col_w[3])
        c4 = wrap(status_icons.get(status, status), col_w[4])

        # The row may span multiple physical lines if any cell wrapped
        # The total height equals the tallest wrapped cell
        max_lines = max(len(c0), len(c1), len(c2), len(c3), len(c4))

        # Print one physical line at a time, padding shorter cells with spaces
        for j in range(max_lines):
            r0 = c0[j] if j < len(c0) else " " * col_w[0]
            r1 = (c1[j] if j < len(c1) else "").ljust(col_w[1])
            r2 = (c2[j] if j < len(c2) else "").ljust(col_w[2])
            r3 = (c3[j] if j < len(c3) else "").ljust(col_w[3])
            r4 = (c4[j] if j < len(c4) else "").ljust(col_w[4])
            print(f"|{r0}|{r1}|{r2}|{r3}|{r4}|")

        # Separator line after each attempt row for readability
        print(sep)

# Confirmation message
print("Summary table tracker ready.")
# Out:
# Summary table tracker ready.

# %% [markdown]
# # Cell 7: Attempt 1: QNN (30 samples, eta=0.04)

# %%
# QNN building blocks
N = 4  # number of qubits, one per input feature

def feature_map(X_sample):
    # Encode classical features as RX rotation angles on each qubit
    q  = QuantumRegister(N)
    c  = ClassicalRegister(1)  # only one bit needed: we read out qubit 0
    qc = QuantumCircuit(q, c)
    for i, x in enumerate(X_sample):
        qc.rx(x, i)
    return qc, c

def variational_circuit(qc, theta):
    # Entangle qubits in a ring with CNOTs, then apply trainable RY rotations
    for i in range(N - 1):
        qc.cx(i, i + 1)
    qc.cx(N - 1, 0)  # close the ring
    for i in range(N):
        qc.ry(theta[i], i)
    return qc

def quantum_nn(X_sample, theta, shots=1000):
    # Full forward pass: encode -> variational -> measure qubit 0
    # Output is the probability of measuring |1> on qubit 0
    qc, c = feature_map(X_sample)
    qc    = variational_circuit(qc, theta)
    qc.measure(0, c)
    qc_t  = transpile(qc, backend=simulator)
    job   = simulator.run(qc_t, shots=shots)
    counts = job.result().get_counts(qc)
    return counts.get("1", 0) / shots

def loss(prediction, target):
    # Mean squared error between predicted probability and target label
    return (target - prediction) ** 2

def gradient(X_sample, Y_target, theta):
    # Finite-difference gradient: perturb each theta and measure loss change
    # Sensitive to shot noise since each call has sampling variance
    delta = 0.01
    grad  = []
    for i in range(len(theta)):
        dtheta    = copy.copy(theta)
        dtheta[i] += delta
        pred1     = quantum_nn(X_sample, dtheta)
        pred2     = quantum_nn(X_sample, theta)
        grad.append((loss(pred1, Y_target) - loss(pred2, Y_target)) / delta)
    return np.array(grad)

def accuracy_ovr(X, Y, theta_list, num_classes=3):
    # One-vs-rest accuracy: predict the class with the highest QNN output
    correct = 0
    for X_i, Y_i in zip(X, Y):
        probs = [quantum_nn(X_i, theta_list[k]) for k in range(num_classes)]
        if int(np.argmax(probs)) == Y_i:
            correct += 1
    return correct / len(Y)

# Run Attempt 1
# Hyperparameters and a small training subset for a quick first attempt
eta         = 0.04
epochs      = 20
num_classes = 3
X_tr1       = X_train[:30]
Y_tr1       = Y_train[:30]

# One independent parameter vector per class (one-vs-rest setup)
theta_list    = [np.ones(N) for _ in range(num_classes)]
loss_history  = [[] for _ in range(num_classes)]

# Training loop: SGD on each sample, separately for each class binary task
print(f"{'Epoch':<8} {'Loss_0':<10} {'Loss_1':<10} {'Loss_2':<10} {'Train Acc'}")
for epoch in range(epochs):
    loss_tmp = [[] for _ in range(num_classes)]
    for X_i, Y_i in zip(X_tr1, Y_tr1):
        for k in range(num_classes):
            bt   = 1 if Y_i == k else 0  # binary target for class k
            pred = quantum_nn(X_i, theta_list[k])
            loss_tmp[k].append(loss(pred, bt))
            # Update theta for class k using finite-difference gradient
            theta_list[k] = theta_list[k] - eta * gradient(X_i, bt, theta_list[k])
    # Record mean loss per class for this epoch
    for k in range(num_classes):
        loss_history[k].append(np.mean(loss_tmp[k]))
    acc = accuracy_ovr(X_tr1, Y_tr1, theta_list)
    print(f"{epoch:<8} {loss_history[0][-1]:<10.3f} {loss_history[1][-1]:<10.3f} {loss_history[2][-1]:<10.3f} {acc:.3f}")

# Log this attempt's outcome to the running summary table
attempt_log.append([
    1, "QNN\n30 samples\neta=0.04",
    "Variational circuit with finite difference SGD. 30 samples, eta=0.04, 20 epochs, 1000 shots.",
    f"Loss flat ~0.24-0.27 all epochs. Train acc oscillated {min(loss_history[0]):.3f}-{max(loss_history[0]):.3f}. No learning trend. Shot noise overwhelms gradient signal.",
    "Failed"
])
show_summary()
# Out:
# Epoch    Loss_0     Loss_1     Loss_2     Train Acc
# 0        0.255      0.248      0.261      0.267
# 1        0.256      0.249      0.271      0.433
# 2        0.245      0.259      0.261      0.333
# 3        0.247      0.255      0.252      0.433
# 4        0.252      0.256      0.253      0.300
# 5        0.265      0.264      0.251      0.433
# 6        0.252      0.287      0.254      0.367
# 7        0.249      0.266      0.248      0.133
# 8        0.259      0.247      0.254      0.400
# 9        0.285      0.246      0.258      0.367
# 10       0.288      0.255      0.263      0.467
# 11       0.284      0.256      0.259      0.300
# 12       0.255      0.253      0.250      0.433
# 13       0.257      0.261      0.255      0.467
# 14       0.264      0.252      0.254      0.467
# 15       0.280      0.248      0.253      0.300
# 16       0.258      0.250      0.268      0.400
# 17       0.240      0.256      0.267      0.333
# 18       0.258      0.258      0.280      0.333
# 19       0.274      0.259      0.284      0.367
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 8: Attempt 2: QNN (80 samples, eta=0.1)

# %%
# Hyperparameters for the second attempt
# Higher learning rate and more epochs than attempt 1
# Larger training subset to test if more data helps the gradient signal
eta         = 0.1
epochs      = 30
X_tr2       = X_train[:80]
Y_tr2       = Y_train[:80]

# Initialize one parameter vector per class for the one-vs-rest setup
# Track loss history and both train and validation accuracy this time
theta_list2   = [np.ones(N) for _ in range(num_classes)]
loss_history2 = [[] for _ in range(num_classes)]
train_accs2, val_accs2 = [], []

# Print column headers for the per-epoch training log
print(f"{'Epoch':<8} {'Loss_0':<10} {'Loss_1':<10} {'Loss_2':<10} {'Train Acc':<12} {'Val Acc'}")

# Main training loop
# For each sample, update each class's theta using finite-difference SGD
for epoch in range(epochs):
    loss_tmp = [[] for _ in range(num_classes)]
    for X_i, Y_i in zip(X_tr2, Y_tr2):
        for k in range(num_classes):

            # Build the binary target for class k under one-vs-rest
            # Compute prediction, record loss, and step theta against the gradient
            bt   = 1 if Y_i == k else 0
            pred = quantum_nn(X_i, theta_list2[k])
            loss_tmp[k].append(loss(pred, bt))
            theta_list2[k] = theta_list2[k] - eta * gradient(X_i, bt, theta_list2[k])

    # Record mean loss per class for this epoch
    for k in range(num_classes):
        loss_history2[k].append(np.mean(loss_tmp[k]))

    # Evaluate accuracy on the training subset and a 30-sample validation slice
    # Validation tracking helps detect overfitting or the absence of learning
    t_acc = accuracy_ovr(X_tr2, Y_tr2, theta_list2)
    v_acc = accuracy_ovr(X_val[:30], Y_val[:30], theta_list2)
    train_accs2.append(t_acc)
    val_accs2.append(v_acc)

    # Print this epoch's losses and accuracies
    print(f"{epoch:<8} {loss_history2[0][-1]:<10.3f} {loss_history2[1][-1]:<10.3f} {loss_history2[2][-1]:<10.3f} {t_acc:<12.3f} {v_acc:.3f}")

# Log the outcome of attempt 2 to the running summary table
attempt_log.append([
    2, "QNN\n80 samples\neta=0.1",
    "Same QNN. Increased to 80 samples, eta=0.1, 30 epochs. Added validation tracking.",
    f"Loss still flat 0.22-0.29. Train acc {min(train_accs2):.2f}-{max(train_accs2):.2f}, val {min(val_accs2):.2f}-{max(val_accs2):.2f}. High variance, no trend. Fundamental problem confirmed.",
    "Failed"
])
show_summary()
# Out:
# Epoch    Loss_0     Loss_1     Loss_2     Train Acc    Val Acc
# 0        0.258      0.259      0.258      0.312        0.233
# 1        0.273      0.246      0.245      0.250        0.367
# 2        0.261      0.243      0.261      0.212        0.267
# 3        0.230      0.266      0.258      0.338        0.333
# 4        0.284      0.256      0.248      0.300        0.267
# 5        0.258      0.249      0.261      0.438        0.400
# 6        0.253      0.233      0.250      0.300        0.367
# 7        0.258      0.254      0.258      0.388        0.333
# 8        0.244      0.231      0.265      0.475        0.400
# 9        0.265      0.245      0.260      0.263        0.233
# 10       0.253      0.290      0.270      0.325        0.367
# 11       0.273      0.265      0.261      0.212        0.367
# 12       0.267      0.280      0.261      0.412        0.433
# 13       0.255      0.270      0.254      0.250        0.333
# 14       0.263      0.244      0.260      0.400        0.367
# 15       0.245      0.276      0.255      0.512        0.267
# 16       0.271      0.233      0.251      0.450        0.367
# 17       0.258      0.235      0.256      0.450        0.300
# 18       0.277      0.266      0.250      0.400        0.300
# 19       0.284      0.290      0.261      0.263        0.433
# 20       0.262      0.299      0.268      0.388        0.300
# 21       0.255      0.302      0.252      0.250        0.400
# 22       0.269      0.295      0.273      0.275        0.467
# 23       0.278      0.286      0.272      0.250        0.333
# 24       0.268      0.233      0.253      0.463        0.300
# 25       0.251      0.236      0.275      0.212        0.233
# 26       0.277      0.246      0.255      0.225        0.433
# 27       0.256      0.284      0.269      0.287        0.367
# 28       0.263      0.289      0.259      0.312        0.333
# 29       0.270      0.271      0.257      0.425        0.400
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 9: Switch to QSVM + Kernel Function

# %%
# From here we switch from QNN to QSVM.
# The kernel is the only thing that changes between attempts 3-7.
# We define a swap-able kernel function below.


# Compute the kernel matrix K[i, j] = kernel_fn(X_a[i], X_b[j]) for two sets of samples
# Used to build the train, validation, and test kernel matrices that QSVM consumes
# Includes a progress printout every 100 evaluations with elapsed time and ETA
# This is important because quantum kernel evaluations are slow and we want visibility
def build_kernel_matrix(X_a, X_b, kernel_fn, label=""):

    # Allocate an empty kernel matrix of shape (n_a, n_b)
    n_a, n_b = len(X_a), len(X_b)
    K        = np.zeros((n_a, n_b))

    # Track total work and elapsed time for the progress reporter
    total    = n_a * n_b
    count    = 0
    start    = time.time()

    # Fill the kernel matrix one entry at a time
    # Each call to kernel_fn runs a quantum circuit, which is the main bottleneck
    for i in range(n_a):
        for j in range(n_b):
            K[i, j] = kernel_fn(X_a[i], X_b[j])
            count   += 1

            # Report progress every 100 evaluations with rough remaining time
            if count % 100 == 0:
                elapsed = time.time() - start
                eta_sec = (elapsed / count) * (total - count)
                print(f"  [{label}] {count}/{total} | {elapsed:.0f}s elapsed | ETA {eta_sec:.0f}s")

    # Final timing summary once the matrix is complete
    print(f"  [{label}] Done — {n_a}x{n_b} in {time.time()-start:.0f}s")
    return K


# Train an SVM on the precomputed train kernel matrix and evaluate on val and test
# Uses class_weight='balanced' to handle any imbalance in regime labels
# Returns the fitted classifier plus three metrics for quick comparison across attempts
def evaluate_qsvm(K_train, Y_tr, K_val, Y_v, K_test, Y_te):

    # Configure SVM to use a precomputed kernel rather than computing one internally
    clf = svm.SVC(kernel="precomputed", class_weight="balanced", random_state=42)
    clf.fit(K_train, Y_tr)

    # Compute validation and test accuracy on the corresponding precomputed kernel matrices
    # F1 is weighted to account for class imbalance across the three regimes
    val_acc  = accuracy_score(Y_v,  clf.predict(K_val))
    test_acc = accuracy_score(Y_te, clf.predict(K_test))
    test_f1  = f1_score(Y_te, clf.predict(K_test), average="weighted", zero_division=0)

    return clf, val_acc, test_acc, test_f1

# Confirmation message so the user knows the cell ran successfully
print("QSVM infrastructure ready.")
# Out:
# QSVM infrastructure ready.

# %% [markdown]
# # Cell 10: Attempt 3: Rx/Rz Kernel, [0, pi]

# %%
# NOTE: For this kernel test we use features in [0, pi].
# Rescale temporarily for this attempt only.


# Rescale features to [0, pi] for this kernel test only
# This range is sometimes recommended for RX-based encodings to avoid wrap-around
# at 2*pi where rotations return to the identity
scaler_pi = MinMaxScaler(feature_range=(0, np.pi))
X_pi      = scaler_pi.fit_transform(df[features].values)

# Use the same train/test split logic as the global pipeline so results are comparable
# Only the test set is needed here for this small probe
_, X_test_pi, _, _ = model_selection.train_test_split(X_pi, Y, test_size=0.33, random_state=42, stratify=Y)

# Tiny training subset for a fast first probe of the kernel behavior
X_tr_pi   = X_pi[:50]
Y_tr_pi   = Y[:50]


# Compute a quantum kernel between two samples using an RX-based overlap circuit
# Apply RX(x1) to encode the first sample, then RX(-x2) to "uncompute" the second
# If x1 == x2 the rotations cancel and we measure |00...0> with probability 1
# If x1 != x2 some non-zero outcomes appear, so the |00...0> probability decreases
# This Hilbert-space inner product squared is the kernel value
def kernel_rx_rz(x1, x2, shots=2000):

    # One quantum register per feature, one classical bit per qubit for measurement
    q  = QuantumRegister(N)
    c  = ClassicalRegister(N)
    qc = QuantumCircuit(q, c)

    # Encode the first sample as RX rotations
    for i, x in enumerate(x1):
        qc.rx(x, i)

    # Inverse-encode the second sample to compute the overlap
    for i, x in enumerate(x2):
        qc.rx(-x, i)

    # Measure all qubits and estimate the probability of the all-zeros outcome
    qc.measure(q, c)
    qc_t   = transpile(qc, backend=simulator)
    counts = simulator.run(qc_t, shots=shots).result().get_counts(qc)

    # Kernel value = probability of observing the all-zeros bitstring
    return counts.get("0" * N, 0) / shots


# Quick diagnostic to check kernel quality before building the full matrix
# A useful kernel needs k(x, x) close to 1 and k(x, x') noticeably smaller
# A small gap means all samples look alike to the kernel and SVM cannot separate classes
k_self  = kernel_rx_rz(X_tr_pi[0], X_tr_pi[0])
k_cross = kernel_rx_rz(X_tr_pi[0], X_tr_pi[1])
print(f"Self-kernel  : {k_self:.4f}  (target ~1.0)")
print(f"Cross-kernel : {k_cross:.4f}")
print(f"Discrimination gap : {k_self - k_cross:.4f}  (target > 0.15)")


# Log this attempt's outcome to the running summary table
attempt_log.append([
    3, "QSVM\nRx/Rz Kernel\n[0, pi]",
    "First QSVM. Rx/Rz rotation kernel. Features in [0, pi].",
    f"Self-kernel: {k_self:.4f}. Cross-kernel: {k_cross:.4f}. Gap: {k_self-k_cross:.4f}. All samples near-identical. QSVM test acc ~0.433.",
    "Failed"
])
show_summary()
# Out:
# Self-kernel  : 1.0000  (target ~1.0)
# Cross-kernel : 0.9085
# Discrimination gap : 0.0915  (target > 0.15)
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 11: Attempt 4: Rx/Rz Kernel, [0, 2pi]

# %%
# X is already normalized to [0, 2pi] from Cell 5 — use it directly


# Run the same Rx/Rz kernel diagnostic as attempt 3
# This time use features rescaled to [0, 2pi] (the full rotation range) instead of [0, pi]
# The hypothesis is that a wider angle range will spread samples further apart
# in Hilbert space and produce a larger discrimination gap
k_self2  = kernel_rx_rz(X_train[0], X_train[0])
k_cross2 = kernel_rx_rz(X_train[0], X_train[1])
print(f"Self-kernel  : {k_self2:.4f}  (target ~1.0)")
print(f"Cross-kernel : {k_cross2:.4f}")
print(f"Discrimination gap : {k_self2 - k_cross2:.4f}  (target > 0.15)")


# Log the outcome of attempt 4 to the running summary table
# Even with a wider angle range, the kernel still does not separate samples enough
# Likely cause: no entanglement in the circuit, so the kernel reduces to a
# product of single-qubit overlaps and cannot capture feature interactions
attempt_log.append([
    4, "QSVM\nRx/Rz Kernel\n[0, 2pi]",
    "Same Rx/Rz circuit. Features rescaled to [0, 2pi].",
    f"Self-kernel: {k_self2:.4f}. Cross-kernel: {k_cross2:.4f}. Gap: {k_self2-k_cross2:.4f}. Improved but still below 0.15 threshold. No entanglement.",
    "Failed"
])
show_summary()
# Out:
# Self-kernel  : 1.0000  (target ~1.0)
# Cross-kernel : 0.9535
# Discrimination gap : 0.0465  (target > 0.15)
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9535. Gap: 0.0465. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 12: Attempt 5: ZZ Kernel (Wrong Adjoint)

# %%
# Attempt 5: ZZ feature map with entanglement, but the kernel formula is wrong
# The intent was to add entanglement (the missing ingredient from attempt 4)
# but the implementation applies the feature map twice instead of feature_map followed by its adjoint
# A correct quantum kernel needs U(x1) followed by U_dagger(x2), not U(x1) followed by U(x2)


# Define the wrong-kernel function for diagnostic comparison
# This kernel is mathematically invalid by construction
# Including it in the attempt log is useful as a record of what went wrong
def kernel_zz_wrong(x1, x2, shots=4000):
    """Incorrect version — applies feature map twice instead of true adjoint."""

    # ZZ feature map block
    # H gates put each qubit in a superposition
    # RZ rotations encode each feature on its own qubit
    # The CX-RZ-CX pattern entangles qubit pairs and encodes feature interactions
    # The 2.0 * (pi - x[i]) * (pi - x[j]) term is the standard ZZFeatureMap second-order term
    def zz_map(qc, x):
        for i in range(N):
            qc.h(i)
            qc.rz(2.0 * x[i], i)
        for i in range(N):
            for j in range(i + 1, N):
                qc.cx(i, j)
                qc.rz(2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
                qc.cx(i, j)
        return qc

    # Build the quantum circuit
    # Apply the feature map for x1 and then again for x2
    # Here is the bug: we should apply the inverse of the feature map for x2
    # so that identical samples produce U_dagger(x) U(x) = I and the all-zeros outcome has probability 1
    q  = QuantumRegister(N)
    c  = ClassicalRegister(N)
    qc = QuantumCircuit(q, c)
    qc = zz_map(qc, x1)
    qc = zz_map(qc, x2)   # wrong — should be adjoint, not repeat

    # Measure all qubits and estimate the probability of the all-zeros outcome
    qc.measure(q, c)
    qc_t   = transpile(qc, backend=simulator)
    counts = simulator.run(qc_t, shots=shots).result().get_counts(qc)
    return counts.get("0" * N, 0) / shots


# Diagnostic: a correct kernel must give k(x, x) = 1.0
# If the self-kernel is far from 1.0 the kernel is broken
# This check catches the bug before wasting compute on a full kernel matrix
k_self3  = kernel_zz_wrong(X_train[0], X_train[0])
k_cross3 = kernel_zz_wrong(X_train[0], X_train[1])
print(f"Self-kernel  : {k_self3:.4f}  (target ~1.0)  <-- BROKEN")
print(f"Cross-kernel : {k_cross3:.4f}")
print(f"Discrimination gap : {k_self3 - k_cross3:.4f}")


# Log this failed attempt for the summary table
# Recording the incorrect implementation is valuable evidence
attempt_log.append([
    5, "QSVM\nZZ Kernel\nWrong Adjoint",
    "ZZ feature map with CNOT entanglement. Applied feature map twice as inverse — incorrect.",
    f"Self-kernel: {k_self3:.4f} (must be 1.0). Mathematically invalid. Even identical samples not recognized as similar.",
    "Failed"
])
show_summary()
# Out:
# Self-kernel  : 0.0622  (target ~1.0)  <-- BROKEN
# Cross-kernel : 0.0590
# Discrimination gap : 0.0033
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9535. Gap: 0.0465. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0622 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 13: Attempt 6: ZZ Kernel (Fixed Adjoint) + Circuit Diagram

# %%
# ── Correct ZZ kernel ────────────────────────────────────────────
def quantum_kernel(x1, x2, shots=4000):
    def apply_zz(qc, x):
        for i in range(N):
            qc.h(i)
            qc.rz(2.0 * x[i], i)
        for i in range(N):
            for j in range(i + 1, N):
                qc.cx(i, j)
                qc.rz(2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
                qc.cx(i, j)
        return qc

    def apply_zz_adjoint(qc, x):
        pairs = [(i, j) for i in range(N) for j in range(i + 1, N)]
        for i, j in reversed(pairs):
            qc.cx(i, j)
            qc.rz(-2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
            qc.cx(i, j)
        for i in range(N):
            qc.rz(-2.0 * x[i], i)
            qc.h(i)
        return qc

    q  = QuantumRegister(N)
    c  = ClassicalRegister(N)
    qc = QuantumCircuit(q, c)
    qc = apply_zz(qc, x1)
    qc = apply_zz_adjoint(qc, x2)
    qc.measure(q, c)
    qc_t   = transpile(qc, backend=simulator)
    counts = simulator.run(qc_t, shots=shots).result().get_counts(qc)
    return counts.get("0" * N, 0) / shots

# ── Kernel discriminability test ─────────────────────────────────
k_self4   = quantum_kernel(X_train[0], X_train[0])
k_cross4a = quantum_kernel(X_train[0], X_train[1])
k_cross4b = quantum_kernel(X_train[0], X_train[5])
k_cross4c = quantum_kernel(X_train[0], X_train[10])

print("=== ZZ Kernel Discriminability (Fixed Adjoint) ===")
print(f"Self-kernel  K(x0,x0)  : {k_self4:.4f}  (target ~1.0)")
print(f"Cross-kernel K(x0,x1)  : {k_cross4a:.4f}")
print(f"Cross-kernel K(x0,x5)  : {k_cross4b:.4f}")
print(f"Cross-kernel K(x0,x10) : {k_cross4c:.4f}")
print(f"Discrimination gap     : {k_self4 - k_cross4a:.4f}  (target > 0.15)")

# ── Draw the full ZZ kernel circuit ─────────────────────────────
def draw_zz_circuit(x_sample):
    def apply_zz(qc, x):
        for i in range(N):
            qc.h(i)
            qc.rz(2.0 * x[i], i)
        for i in range(N):
            for j in range(i + 1, N):
                qc.cx(i, j)
                qc.rz(2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
                qc.cx(i, j)
        return qc

    def apply_zz_adjoint(qc, x):
        pairs = [(i, j) for i in range(N) for j in range(i + 1, N)]
        for i, j in reversed(pairs):
            qc.cx(i, j)
            qc.rz(-2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
            qc.cx(i, j)
        for i in range(N):
            qc.rz(-2.0 * x[i], i)
            qc.h(i)
        return qc

    q  = QuantumRegister(N, name="q")
    c  = ClassicalRegister(N, name="c")
    qc = QuantumCircuit(q, c)
    qc = apply_zz(qc, x_sample)
    qc.barrier(label="ZZ†(x2)")
    qc = apply_zz_adjoint(qc, x_sample)
    qc.barrier()
    qc.measure(q, c)
    return qc

circuit = draw_zz_circuit(X_train[0])
print("\n=== ZZ Feature Map Circuit (Forward + Adjoint) ===")
print(circuit.draw(output="text", fold=120))

# ── Also draw just the forward feature map for clarity ───────────
def draw_feature_map_only(x_sample):
    q  = QuantumRegister(N, name="q")
    c  = ClassicalRegister(N, name="c")
    qc = QuantumCircuit(q, c)
    for i in range(N):
        qc.h(i)
        qc.rz(2.0 * x_sample[i], i)
    qc.barrier(label="ZZ pairs")
    for i in range(N):
        for j in range(i + 1, N):
            qc.cx(i, j)
            qc.rz(2.0 * (np.pi - x_sample[i]) * (np.pi - x_sample[j]), j)
            qc.cx(i, j)
    qc.barrier()
    qc.measure(q, c)
    return qc

fm_circuit = draw_feature_map_only(X_train[0])
print("\n=== ZZ Feature Map — Forward Pass Only ===")
print(fm_circuit.draw(output="text", fold=120))

attempt_log.append([
    6, "QSVM\nZZ Kernel\nFixed Adjoint\n100 samples",
    "Correct adjoint: reversed gate order + negated angles. 100 training samples.",
    f"Self-kernel: {k_self4:.4f}. Gap: {k_self4-k_cross4a:.4f}. QSVM test acc: 0.600, F1: 0.598. Classical SVM: 0.700. QSVM learning correctly.",
    "Partial"
])
show_summary()
# ── Render circuits as images for the poster ─────────────────────
print("=== ZZ Kernel Discriminability (Fixed Adjoint) ===")
print(f"Self-kernel  K(x0,x0)  : {k_self4:.4f}")
print(f"Cross-kernel K(x0,x1)  : {k_cross4a:.4f}")
print(f"Discrimination gap     : {k_self4 - k_cross4a:.4f}  (target > 0.15)")

# Forward feature map only (cleaner, fits the poster)
fm_circuit = QuantumCircuit(QuantumRegister(N, name="q"))
for i in range(N):
    fm_circuit.h(i)
    fm_circuit.rz(2.0 * X_train[0][i], i)
fm_circuit.barrier()
for i in range(N):
    for j in range(i + 1, N):
        fm_circuit.cx(i, j)
        fm_circuit.rz(2.0 * (np.pi - X_train[0][i]) * (np.pi - X_train[0][j]), j)
        fm_circuit.cx(i, j)

fig_fm = fm_circuit.draw(output="mpl", style="iqp", fold=-1)
fig_fm.suptitle("ZZ Feature Map — Forward Pass U(x)",
                fontsize=14, fontweight="bold", y=1.02)
fig_fm.savefig("circuit_feature_map.png", dpi=300, bbox_inches="tight")
plt.show()

# Full kernel circuit: U(x1) followed by U†(x2)
def build_full_kernel_circuit(x1, x2):
    q  = QuantumRegister(N, name="q")
    c  = ClassicalRegister(N, name="c")
    qc = QuantumCircuit(q, c)
    # Forward U(x1)
    for i in range(N):
        qc.h(i); qc.rz(2.0 * x1[i], i)
    for i in range(N):
        for j in range(i + 1, N):
            qc.cx(i, j); qc.rz(2.0 * (np.pi - x1[i]) * (np.pi - x1[j]), j); qc.cx(i, j)
    qc.barrier(label="U(x1)  |  U†(x2)")
    # Adjoint U†(x2)
    pairs = [(i, j) for i in range(N) for j in range(i + 1, N)]
    for i, j in reversed(pairs):
        qc.cx(i, j); qc.rz(-2.0 * (np.pi - x2[i]) * (np.pi - x2[j]), j); qc.cx(i, j)
    for i in range(N):
        qc.rz(-2.0 * x2[i], i); qc.h(i)
    qc.barrier()
    qc.measure(q, c)
    return qc

full_circuit = build_full_kernel_circuit(X_train[0], X_train[1])
fig_full = full_circuit.draw(output="mpl", style="iqp", fold=-1)
fig_full.suptitle("Full Quantum Kernel Circuit — $|\\langle 0 | U^\\dagger(x_2) U(x_1) | 0 \\rangle|^2$",
                  fontsize=14, fontweight="bold", y=1.02)
fig_full.savefig("circuit_full_kernel.png", dpi=300, bbox_inches="tight")
plt.show()

print("Saved: circuit_feature_map.png, circuit_full_kernel.png")

attempt_log.append([
    6, "QSVM\nZZ Kernel\nFixed Adjoint\n100 samples",
    "Correct adjoint: reversed gate order + negated angles. 100 training samples.",
    f"Self-kernel: {k_self4:.4f}. Gap: {k_self4-k_cross4a:.4f}. QSVM test acc: 0.600, F1: 0.598. Classical SVM: 0.700.",
    "Partial"
])
show_summary()
# Out:
# === ZZ Kernel Discriminability (Fixed Adjoint) ===
# Self-kernel  K(x0,x0)  : 1.0000  (target ~1.0)
# Cross-kernel K(x0,x1)  : 0.2640
# Cross-kernel K(x0,x5)  : 0.0050
# Cross-kernel K(x0,x10) : 0.0257
# Discrimination gap     : 0.7360  (target > 0.15)
#
# === ZZ Feature Map Circuit (Forward + Adjoint) ===
#      ┌───┐ ┌────────────┐                                                                                             »
# q_0: ┤ H ├─┤ Rz(5.9861) ├──■───────────────────■────■────────────────────■────■────────────────────────────────────■──»
#      ├───┤┌┴────────────┤┌─┴─┐┌─────────────┐┌─┴─┐  │                    │    │                                    │  »
# q_1: ┤ H ├┤ Rz(0.95055) ├┤ X ├┤ Rz(0.79206) ├┤ X ├──┼────────────────────┼────┼──────────■─────────────────────────┼──»
#      ├───┤└┬────────────┤└───┘└─────────────┘└───┘┌─┴─┐┌──────────────┐┌─┴─┐  │        ┌─┴─┐      ┌─────────────┐  │  »
# q_2: ┤ H ├─┤ Rz(7.2196) ├─────────────────────────┤ X ├┤ Rz(-0.13908) ├┤ X ├──┼────────┤ X ├──────┤ Rz(-2.4967) ├──┼──»
#      ├───┤ ├────────────┤                         └───┘└──────────────┘└───┘┌─┴─┐┌─────┴───┴─────┐└─────────────┘┌─┴─┐»
# q_3: ┤ H ├─┤ Rz(6.8009) ├───────────────────────────────────────────────────┤ X ├┤ Rz(-0.076893) ├───────────────┤ X ├»
#      └───┘ └────────────┘                                                   └───┘└───────────────┘               └───┘»
# c: 4/═════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                       »
# «                                                             ZZ†(x2)                                              »
# «q_0: ───────────────────────────────────────────────────────────░─────────────────────────────────────────────────»
# «                                                                ░                                                 »
# «q_1: ──■────■───────────────────■───────────────────────────────░────────────────────────────────■────────────────»
# «     ┌─┴─┐  │                   │                               ░                                │                »
# «q_2: ┤ X ├──┼───────────────────┼────■───────────────────■──────░──────■────────────────────■────┼────────────────»
# «     └───┘┌─┴─┐┌─────────────┐┌─┴─┐┌─┴─┐┌─────────────┐┌─┴─┐    ░    ┌─┴─┐┌──────────────┐┌─┴─┐┌─┴─┐┌────────────┐»
# «q_3: ─────┤ X ├┤ Rz(-1.3803) ├┤ X ├┤ X ├┤ Rz(0.24238) ├┤ X ├────░────┤ X ├┤ Rz(-0.24238) ├┤ X ├┤ X ├┤ Rz(1.3803) ├»
# «          └───┘└─────────────┘└───┘└───┘└─────────────┘└───┘    ░    └───┘└──────────────┘└───┘└───┘└────────────┘»
# «c: 4/═════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                  »
# «                                                                                                                     »
# «q_0: ────────────■─────────────────────────■─────────■────────────────────────■─────────■─────────────────────────■──»
# «                 │                         │         │                        │       ┌─┴─┐     ┌──────────────┐┌─┴─┐»
# «q_1: ──■────■────┼────────────────────■────┼─────────┼────────────────────────┼───────┤ X ├─────┤ Rz(-0.79206) ├┤ X ├»
# «       │  ┌─┴─┐  │   ┌────────────┐ ┌─┴─┐  │       ┌─┴─┐     ┌─────────────┐┌─┴─┐┌────┴───┴────┐└────┬───┬─────┘└───┘»
# «q_2: ──┼──┤ X ├──┼───┤ Rz(2.4967) ├─┤ X ├──┼───────┤ X ├─────┤ Rz(0.13908) ├┤ X ├┤ Rz(-7.2196) ├─────┤ H ├───────────»
# «     ┌─┴─┐└───┘┌─┴─┐┌┴────────────┴┐└───┘┌─┴─┐┌────┴───┴────┐└────┬───┬────┘└───┘└─────────────┘     └───┘           »
# «q_3: ┤ X ├─────┤ X ├┤ Rz(0.076893) ├─────┤ X ├┤ Rz(-6.8009) ├─────┤ H ├──────────────────────────────────────────────»
# «     └───┘     └───┘└──────────────┘     └───┘└─────────────┘     └───┘                                              »
# «c: 4/════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                     »
# «     ┌─────────────┐ ┌───┐ ░ ┌─┐
# «q_0: ┤ Rz(-5.9861) ├─┤ H ├─░─┤M├─────────
# «     ├─────────────┴┐├───┤ ░ └╥┘┌─┐
# «q_1: ┤ Rz(-0.95055) ├┤ H ├─░──╫─┤M├──────
# «     └──────────────┘└───┘ ░  ║ └╥┘┌─┐
# «q_2: ──────────────────────░──╫──╫─┤M├───
# «                           ░  ║  ║ └╥┘┌─┐
# «q_3: ──────────────────────░──╫──╫──╫─┤M├
# «                           ░  ║  ║  ║ └╥┘
# «c: 4/═════════════════════════╩══╩══╩══╩═
# «                              0  1  2  3
#
# === ZZ Feature Map — Forward Pass Only ===
#      ┌───┐ ┌────────────┐ ZZ pairs                                                                          »
# q_0: ┤ H ├─┤ Rz(5.9861) ├────░───────■───────────────────■────■────────────────────■────■───────────────────»
#      ├───┤┌┴────────────┤    ░     ┌─┴─┐┌─────────────┐┌─┴─┐  │                    │    │                   »
# q_1: ┤ H ├┤ Rz(0.95055) ├────░─────┤ X ├┤ Rz(0.79206) ├┤ X ├──┼────────────────────┼────┼──────────■────────»
#      ├───┤└┬────────────┤    ░     └───┘└─────────────┘└───┘┌─┴─┐┌──────────────┐┌─┴─┐  │        ┌─┴─┐      »
# q_2: ┤ H ├─┤ Rz(7.2196) ├────░──────────────────────────────┤ X ├┤ Rz(-0.13908) ├┤ X ├──┼────────┤ X ├──────»
#      ├───┤ ├────────────┤    ░                              └───┘└──────────────┘└───┘┌─┴─┐┌─────┴───┴─────┐»
# q_3: ┤ H ├─┤ Rz(6.8009) ├────░────────────────────────────────────────────────────────┤ X ├┤ Rz(-0.076893) ├»
#      └───┘ └────────────┘    ░                                                        └───┘└───────────────┘»
# c: 4/═══════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                             »
# «                                                                                 ░ ┌─┐
# «q_0: ─────────────────■──────────────────────────────────────────────────────────░─┤M├─────────
# «                      │                                                          ░ └╥┘┌─┐
# «q_1: ─────────────────┼────■────■───────────────────■────────────────────────────░──╫─┤M├──────
# «     ┌─────────────┐  │  ┌─┴─┐  │                   │                            ░  ║ └╥┘┌─┐
# «q_2: ┤ Rz(-2.4967) ├──┼──┤ X ├──┼───────────────────┼────■───────────────────■───░──╫──╫─┤M├───
# «     └─────────────┘┌─┴─┐└───┘┌─┴─┐┌─────────────┐┌─┴─┐┌─┴─┐┌─────────────┐┌─┴─┐ ░  ║  ║ └╥┘┌─┐
# «q_3: ───────────────┤ X ├─────┤ X ├┤ Rz(-1.3803) ├┤ X ├┤ X ├┤ Rz(0.24238) ├┤ X ├─░──╫──╫──╫─┤M├
# «                    └───┘     └───┘└─────────────┘└───┘└───┘└─────────────┘└───┘ ░  ║  ║  ║ └╥┘
# «c: 4/═══════════════════════════════════════════════════════════════════════════════╩══╩══╩══╩═
# «                                                                                    0  1  2  3
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9535. Gap: 0.0465. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0622 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# === ZZ Kernel Discriminability (Fixed Adjoint) ===
# Self-kernel  K(x0,x0)  : 1.0000
# Cross-kernel K(x0,x1)  : 0.2640
# Discrimination gap     : 0.7360  (target > 0.15)
# Saved: circuit_feature_map.png, circuit_full_kernel.png
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9535. Gap: 0.0465. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0622 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700.             |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 14: Build Kernel Matrices (100 samples)

# %%
# Build kernel matrices for the 100-sample QSVM run

# Subset sizes: 100 train, 40 val, 60 test
# Total = 20,000 quantum kernel evaluations
N_tr, N_v, N_te = 100, 40, 60

# Slice features and labels using matching indices
X_tr_sub = X_train[:N_tr];  Y_tr_sub = Y_train[:N_tr]
X_v_sub  = X_val[:N_v];     Y_v_sub  = Y_val[:N_v]
X_te_sub = X_test[:N_te];   Y_te_sub = Y_test[:N_te]

# Train kernel is square; val and test kernels are rectangular (rows=eval, cols=train)
print("Building kernel matrices (100 samples) ...")
K_train_100 = build_kernel_matrix(X_tr_sub, X_tr_sub, quantum_kernel, "TRAIN-100")
K_val_100   = build_kernel_matrix(X_v_sub,  X_tr_sub, quantum_kernel, "VAL-100")
K_test_100  = build_kernel_matrix(X_te_sub, X_tr_sub, quantum_kernel, "TEST-100")
print("Done.")
# Out:
# Building kernel matrices (100 samples) ...
#   [TRAIN-100] 100/10000 | 1s elapsed | ETA 78s
#   [TRAIN-100] 200/10000 | 2s elapsed | ETA 78s
#   [TRAIN-100] 300/10000 | 2s elapsed | ETA 75s
#   [TRAIN-100] 400/10000 | 3s elapsed | ETA 73s
#   [TRAIN-100] 500/10000 | 4s elapsed | ETA 71s
#   [TRAIN-100] 600/10000 | 4s elapsed | ETA 70s
#   [TRAIN-100] 700/10000 | 5s elapsed | ETA 68s
#   [TRAIN-100] 800/10000 | 7s elapsed | ETA 76s
#   [TRAIN-100] 900/10000 | 7s elapsed | ETA 75s
#   [TRAIN-100] 1000/10000 | 8s elapsed | ETA 73s
#   [TRAIN-100] 1100/10000 | 9s elapsed | ETA 71s
#   [TRAIN-100] 1200/10000 | 10s elapsed | ETA 70s
#   [TRAIN-100] 1300/10000 | 10s elapsed | ETA 69s
#   [TRAIN-100] 1400/10000 | 11s elapsed | ETA 67s
#   [TRAIN-100] 1500/10000 | 12s elapsed | ETA 66s
#   [TRAIN-100] 1600/10000 | 12s elapsed | ETA 65s
#   [TRAIN-100] 1700/10000 | 13s elapsed | ETA 64s
#   [TRAIN-100] 1800/10000 | 14s elapsed | ETA 63s
#   [TRAIN-100] 1900/10000 | 15s elapsed | ETA 62s
#   [TRAIN-100] 2000/10000 | 15s elapsed | ETA 61s
#   [TRAIN-100] 2100/10000 | 16s elapsed | ETA 60s
#   [TRAIN-100] 2200/10000 | 17s elapsed | ETA 59s
#   [TRAIN-100] 2300/10000 | 17s elapsed | ETA 58s
#   [TRAIN-100] 2400/10000 | 18s elapsed | ETA 57s
#   [TRAIN-100] 2500/10000 | 19s elapsed | ETA 56s
#   [TRAIN-100] 2600/10000 | 20s elapsed | ETA 56s
#   [TRAIN-100] 2700/10000 | 20s elapsed | ETA 55s
#   [TRAIN-100] 2800/10000 | 21s elapsed | ETA 54s
#   [TRAIN-100] 2900/10000 | 22s elapsed | ETA 53s
#   [TRAIN-100] 3000/10000 | 22s elapsed | ETA 52s
#   [TRAIN-100] 3100/10000 | 23s elapsed | ETA 52s
#   [TRAIN-100] 3200/10000 | 24s elapsed | ETA 51s
#   [TRAIN-100] 3300/10000 | 25s elapsed | ETA 50s
#   [TRAIN-100] 3400/10000 | 25s elapsed | ETA 49s
#   [TRAIN-100] 3500/10000 | 26s elapsed | ETA 48s
#   [TRAIN-100] 3600/10000 | 27s elapsed | ETA 48s
#   [TRAIN-100] 3700/10000 | 28s elapsed | ETA 47s
#   [TRAIN-100] 3800/10000 | 28s elapsed | ETA 46s
#   [TRAIN-100] 3900/10000 | 29s elapsed | ETA 45s
#   [TRAIN-100] 4000/10000 | 30s elapsed | ETA 45s
#   [TRAIN-100] 4100/10000 | 30s elapsed | ETA 44s
#   [TRAIN-100] 4200/10000 | 31s elapsed | ETA 43s
#   [TRAIN-100] 4300/10000 | 32s elapsed | ETA 42s
#   [TRAIN-100] 4400/10000 | 33s elapsed | ETA 42s
#   [TRAIN-100] 4500/10000 | 33s elapsed | ETA 41s
#   [TRAIN-100] 4600/10000 | 34s elapsed | ETA 40s
#   [TRAIN-100] 4700/10000 | 35s elapsed | ETA 39s
#   [TRAIN-100] 4800/10000 | 36s elapsed | ETA 38s
#   [TRAIN-100] 4900/10000 | 36s elapsed | ETA 38s
#   [TRAIN-100] 5000/10000 | 37s elapsed | ETA 37s
#   [TRAIN-100] 5100/10000 | 38s elapsed | ETA 36s
#   [TRAIN-100] 5200/10000 | 38s elapsed | ETA 35s
#   [TRAIN-100] 5300/10000 | 39s elapsed | ETA 35s
#   [TRAIN-100] 5400/10000 | 40s elapsed | ETA 34s
#   [TRAIN-100] 5500/10000 | 41s elapsed | ETA 33s
#   [TRAIN-100] 5600/10000 | 41s elapsed | ETA 33s
#   [TRAIN-100] 5700/10000 | 42s elapsed | ETA 32s
#   [TRAIN-100] 5800/10000 | 43s elapsed | ETA 31s
#   [TRAIN-100] 5900/10000 | 44s elapsed | ETA 30s
#   [TRAIN-100] 6000/10000 | 44s elapsed | ETA 30s
#   [TRAIN-100] 6100/10000 | 45s elapsed | ETA 29s
#   [TRAIN-100] 6200/10000 | 46s elapsed | ETA 28s
#   [TRAIN-100] 6300/10000 | 46s elapsed | ETA 27s
#   [TRAIN-100] 6400/10000 | 47s elapsed | ETA 27s
#   [TRAIN-100] 6500/10000 | 48s elapsed | ETA 26s
#   [TRAIN-100] 6600/10000 | 49s elapsed | ETA 25s
#   [TRAIN-100] 6700/10000 | 49s elapsed | ETA 24s
#   [TRAIN-100] 6800/10000 | 50s elapsed | ETA 24s
#   [TRAIN-100] 6900/10000 | 51s elapsed | ETA 23s
#   [TRAIN-100] 7000/10000 | 51s elapsed | ETA 22s
#   [TRAIN-100] 7100/10000 | 52s elapsed | ETA 21s
#   [TRAIN-100] 7200/10000 | 53s elapsed | ETA 21s
#   [TRAIN-100] 7300/10000 | 54s elapsed | ETA 20s
#   [TRAIN-100] 7400/10000 | 54s elapsed | ETA 19s
#   [TRAIN-100] 7500/10000 | 55s elapsed | ETA 18s
#   [TRAIN-100] 7600/10000 | 56s elapsed | ETA 18s
#   [TRAIN-100] 7700/10000 | 57s elapsed | ETA 17s
#   [TRAIN-100] 7800/10000 | 57s elapsed | ETA 16s
#   [TRAIN-100] 7900/10000 | 58s elapsed | ETA 15s
#   [TRAIN-100] 8000/10000 | 59s elapsed | ETA 15s
#   [TRAIN-100] 8100/10000 | 60s elapsed | ETA 14s
#   [TRAIN-100] 8200/10000 | 60s elapsed | ETA 13s
#   [TRAIN-100] 8300/10000 | 61s elapsed | ETA 12s
#   [TRAIN-100] 8400/10000 | 62s elapsed | ETA 12s
#   [TRAIN-100] 8500/10000 | 62s elapsed | ETA 11s
#   [TRAIN-100] 8600/10000 | 63s elapsed | ETA 10s
#   [TRAIN-100] 8700/10000 | 64s elapsed | ETA 10s
#   [TRAIN-100] 8800/10000 | 65s elapsed | ETA 9s
#   [TRAIN-100] 8900/10000 | 65s elapsed | ETA 8s
#   [TRAIN-100] 9000/10000 | 66s elapsed | ETA 7s
#   [TRAIN-100] 9100/10000 | 67s elapsed | ETA 7s
#   [TRAIN-100] 9200/10000 | 67s elapsed | ETA 6s
#   [TRAIN-100] 9300/10000 | 68s elapsed | ETA 5s
#   [TRAIN-100] 9400/10000 | 69s elapsed | ETA 4s
#   [TRAIN-100] 9500/10000 | 70s elapsed | ETA 4s
#   [TRAIN-100] 9600/10000 | 70s elapsed | ETA 3s
#   [TRAIN-100] 9700/10000 | 71s elapsed | ETA 2s
#   [TRAIN-100] 9800/10000 | 72s elapsed | ETA 1s
#   [TRAIN-100] 9900/10000 | 73s elapsed | ETA 1s
#   [TRAIN-100] 10000/10000 | 73s elapsed | ETA 0s
#   [TRAIN-100] Done — 100x100 in 73s
#   [VAL-100] 100/4000 | 1s elapsed | ETA 28s
#   [VAL-100] 200/4000 | 1s elapsed | ETA 28s
#   [VAL-100] 300/4000 | 2s elapsed | ETA 27s
#   [VAL-100] 400/4000 | 3s elapsed | ETA 26s
#   [VAL-100] 500/4000 | 4s elapsed | ETA 25s
#   [VAL-100] 600/4000 | 4s elapsed | ETA 24s
#   [VAL-100] 700/4000 | 5s elapsed | ETA 24s
#   [VAL-100] 800/4000 | 6s elapsed | ETA 23s
#   [VAL-100] 900/4000 | 7s elapsed | ETA 23s
#   [VAL-100] 1000/4000 | 7s elapsed | ETA 22s
#   [VAL-100] 1100/4000 | 8s elapsed | ETA 21s
#   [VAL-100] 1200/4000 | 9s elapsed | ETA 21s
#   [VAL-100] 1300/4000 | 10s elapsed | ETA 20s
#   [VAL-100] 1400/4000 | 11s elapsed | ETA 20s
#   [VAL-100] 1500/4000 | 11s elapsed | ETA 19s
#   [VAL-100] 1600/4000 | 12s elapsed | ETA 18s
#   [VAL-100] 1700/4000 | 13s elapsed | ETA 17s
#   [VAL-100] 1800/4000 | 14s elapsed | ETA 17s
#   [VAL-100] 1900/4000 | 14s elapsed | ETA 16s
#   [VAL-100] 2000/4000 | 15s elapsed | ETA 15s
#   [VAL-100] 2100/4000 | 16s elapsed | ETA 15s
#   [VAL-100] 2200/4000 | 17s elapsed | ETA 14s
#   [VAL-100] 2300/4000 | 18s elapsed | ETA 13s
#   [VAL-100] 2400/4000 | 19s elapsed | ETA 12s
#   [VAL-100] 2500/4000 | 19s elapsed | ETA 12s
#   [VAL-100] 2600/4000 | 20s elapsed | ETA 11s
#   [VAL-100] 2700/4000 | 21s elapsed | ETA 10s
#   [VAL-100] 2800/4000 | 22s elapsed | ETA 9s
#   [VAL-100] 2900/4000 | 22s elapsed | ETA 8s
#   [VAL-100] 3000/4000 | 23s elapsed | ETA 8s
#   [VAL-100] 3100/4000 | 24s elapsed | ETA 7s
#   [VAL-100] 3200/4000 | 25s elapsed | ETA 6s
#   [VAL-100] 3300/4000 | 26s elapsed | ETA 5s
#   [VAL-100] 3400/4000 | 26s elapsed | ETA 5s
#   [VAL-100] 3500/4000 | 27s elapsed | ETA 4s
#   [VAL-100] 3600/4000 | 28s elapsed | ETA 3s
#   [VAL-100] 3700/4000 | 29s elapsed | ETA 2s
#   [VAL-100] 3800/4000 | 29s elapsed | ETA 2s
#   [VAL-100] 3900/4000 | 30s elapsed | ETA 1s
#   [VAL-100] 4000/4000 | 31s elapsed | ETA 0s
#   [VAL-100] Done — 40x100 in 31s
#   [TEST-100] 100/6000 | 1s elapsed | ETA 44s
#   [TEST-100] 200/6000 | 2s elapsed | ETA 44s
#   [TEST-100] 300/6000 | 2s elapsed | ETA 43s
#   [TEST-100] 400/6000 | 3s elapsed | ETA 42s
#   [TEST-100] 500/6000 | 4s elapsed | ETA 41s
#   [TEST-100] 600/6000 | 4s elapsed | ETA 40s
#   [TEST-100] 700/6000 | 5s elapsed | ETA 39s
#   [TEST-100] 800/6000 | 6s elapsed | ETA 39s
#   [TEST-100] 900/6000 | 7s elapsed | ETA 38s
#   [TEST-100] 1000/6000 | 7s elapsed | ETA 37s
#   [TEST-100] 1100/6000 | 8s elapsed | ETA 36s
#   [TEST-100] 1200/6000 | 9s elapsed | ETA 35s
#   [TEST-100] 1300/6000 | 10s elapsed | ETA 34s
#   [TEST-100] 1400/6000 | 10s elapsed | ETA 34s
#   [TEST-100] 1500/6000 | 11s elapsed | ETA 33s
#   [TEST-100] 1600/6000 | 12s elapsed | ETA 32s
#   [TEST-100] 1700/6000 | 12s elapsed | ETA 31s
#   [TEST-100] 1800/6000 | 13s elapsed | ETA 31s
#   [TEST-100] 1900/6000 | 14s elapsed | ETA 30s
#   [TEST-100] 2000/6000 | 15s elapsed | ETA 29s
#   [TEST-100] 2100/6000 | 15s elapsed | ETA 29s
#   [TEST-100] 2200/6000 | 16s elapsed | ETA 28s
#   [TEST-100] 2300/6000 | 17s elapsed | ETA 27s
#   [TEST-100] 2400/6000 | 18s elapsed | ETA 26s
#   [TEST-100] 2500/6000 | 18s elapsed | ETA 26s
#   [TEST-100] 2600/6000 | 19s elapsed | ETA 25s
#   [TEST-100] 2700/6000 | 20s elapsed | ETA 24s
#   [TEST-100] 2800/6000 | 21s elapsed | ETA 23s
#   [TEST-100] 2900/6000 | 21s elapsed | ETA 23s
#   [TEST-100] 3000/6000 | 22s elapsed | ETA 22s
#   [TEST-100] 3100/6000 | 23s elapsed | ETA 21s
#   [TEST-100] 3200/6000 | 23s elapsed | ETA 20s
#   [TEST-100] 3300/6000 | 24s elapsed | ETA 20s
#   [TEST-100] 3400/6000 | 25s elapsed | ETA 19s
#   [TEST-100] 3500/6000 | 26s elapsed | ETA 18s
#   [TEST-100] 3600/6000 | 26s elapsed | ETA 18s
#   [TEST-100] 3700/6000 | 27s elapsed | ETA 17s
#   [TEST-100] 3800/6000 | 28s elapsed | ETA 16s
#   [TEST-100] 3900/6000 | 28s elapsed | ETA 15s
#   [TEST-100] 4000/6000 | 29s elapsed | ETA 15s
#   [TEST-100] 4100/6000 | 30s elapsed | ETA 14s
#   [TEST-100] 4200/6000 | 31s elapsed | ETA 13s
#   [TEST-100] 4300/6000 | 31s elapsed | ETA 12s
#   [TEST-100] 4400/6000 | 32s elapsed | ETA 12s
#   [TEST-100] 4500/6000 | 33s elapsed | ETA 11s
#   [TEST-100] 4600/6000 | 33s elapsed | ETA 10s
#   [TEST-100] 4700/6000 | 34s elapsed | ETA 9s
#   [TEST-100] 4800/6000 | 35s elapsed | ETA 9s
#   [TEST-100] 4900/6000 | 36s elapsed | ETA 8s
#   [TEST-100] 5000/6000 | 36s elapsed | ETA 7s
#   [TEST-100] 5100/6000 | 37s elapsed | ETA 7s
#   [TEST-100] 5200/6000 | 38s elapsed | ETA 6s
#   [TEST-100] 5300/6000 | 39s elapsed | ETA 5s
#   [TEST-100] 5400/6000 | 39s elapsed | ETA 4s
#   [TEST-100] 5500/6000 | 40s elapsed | ETA 4s
#   [TEST-100] 5600/6000 | 41s elapsed | ETA 3s
#   [TEST-100] 5700/6000 | 41s elapsed | ETA 2s
#   [TEST-100] 5800/6000 | 42s elapsed | ETA 1s
#   [TEST-100] 5900/6000 | 43s elapsed | ETA 1s
#   [TEST-100] 6000/6000 | 44s elapsed | ETA 0s
#   [TEST-100] Done — 60x100 in 44s
# Done.

# %% [markdown]
# # Cell 15: Attempt 6 QSVM vs Classical SVM (100 samples)

# %%
# Train and evaluate QSVM on the 100-sample precomputed kernels
clf6, val_acc6, test_acc6, test_f16 = evaluate_qsvm(
    K_train_100, Y_tr_sub, K_val_100, Y_v_sub, K_test_100, Y_te_sub)
Y_pred6 = clf6.predict(K_test_100)

# Classical SVM baseline with RBF kernel on the same subset
svm6 = svm.SVC(kernel="rbf", probability=True, class_weight="balanced", random_state=42)
svm6.fit(X_tr_sub, Y_tr_sub)
svm_acc6 = accuracy_score(Y_te_sub, svm6.predict(X_te_sub))
svm_f16  = f1_score(Y_te_sub, svm6.predict(X_te_sub), average="weighted", zero_division=0)

# Report side-by-side comparison
print("=== 100 Samples ===")
print(f"QSVM    — Val: {val_acc6:.3f}  Test: {test_acc6:.3f}  F1: {test_f16:.3f}")
print(f"SVM     — Test: {svm_acc6:.3f}  F1: {svm_f16:.3f}")
# Out:
# === 100 Samples ===
# QSVM    — Val: 0.675  Test: 0.583  F1: 0.579
# SVM     — Test: 0.700  F1: 0.710

# %% [markdown]
# # Cell 16: Build Kernel Matrices (200 samples)

# %%
# Scale up to 200 training samples for attempt 7
# Total = 200*200 + 60*200 + 100*200 = 72,000 kernel evaluations
N_tr2, N_v2, N_te2 = 200, 60, 100

# Slice matching feature and label subsets
X_tr2 = X_train[:N_tr2];  Y_tr2 = Y_train[:N_tr2]
X_v2  = X_val[:N_v2];     Y_v2  = Y_val[:N_v2]
X_te2 = X_test[:N_te2];   Y_te2 = Y_test[:N_te2]

# Build train (square), val and test (rectangular) kernel matrices
print("Building kernel matrices (200 samples) — this takes ~30-50 min ...")
K_train_200 = build_kernel_matrix(X_tr2, X_tr2, quantum_kernel, "TRAIN-200")
K_val_200   = build_kernel_matrix(X_v2,  X_tr2, quantum_kernel, "VAL-200")
K_test_200  = build_kernel_matrix(X_te2, X_tr2, quantum_kernel, "TEST-200")
print("Done.")
# Out:
# Building kernel matrices (200 samples) — this takes ~30-50 min ...
#   [TRAIN-200] 100/40000 | 1s elapsed | ETA 336s
#   [TRAIN-200] 200/40000 | 2s elapsed | ETA 319s
#   [TRAIN-200] 300/40000 | 2s elapsed | ETA 313s
#   [TRAIN-200] 400/40000 | 3s elapsed | ETA 307s
#   [TRAIN-200] 500/40000 | 4s elapsed | ETA 303s
#   [TRAIN-200] 600/40000 | 5s elapsed | ETA 307s
#   [TRAIN-200] 700/40000 | 5s elapsed | ETA 307s
#   [TRAIN-200] 800/40000 | 6s elapsed | ETA 306s
#   [TRAIN-200] 900/40000 | 7s elapsed | ETA 303s
#   [TRAIN-200] 1000/40000 | 8s elapsed | ETA 300s
#   [TRAIN-200] 1100/40000 | 8s elapsed | ETA 298s
#   [TRAIN-200] 1200/40000 | 9s elapsed | ETA 296s
#   [TRAIN-200] 1300/40000 | 10s elapsed | ETA 294s
#   [TRAIN-200] 1400/40000 | 11s elapsed | ETA 293s
#   [TRAIN-200] 1500/40000 | 11s elapsed | ETA 292s
#   [TRAIN-200] 1600/40000 | 12s elapsed | ETA 290s
#   [TRAIN-200] 1700/40000 | 13s elapsed | ETA 289s
#   [TRAIN-200] 1800/40000 | 14s elapsed | ETA 288s
#   [TRAIN-200] 1900/40000 | 14s elapsed | ETA 286s
#   [TRAIN-200] 2000/40000 | 15s elapsed | ETA 285s
#   [TRAIN-200] 2100/40000 | 16s elapsed | ETA 284s
#   [TRAIN-200] 2200/40000 | 16s elapsed | ETA 283s
#   [TRAIN-200] 2300/40000 | 17s elapsed | ETA 282s
#   [TRAIN-200] 2400/40000 | 18s elapsed | ETA 281s
#   [TRAIN-200] 2500/40000 | 19s elapsed | ETA 280s
#   [TRAIN-200] 2600/40000 | 19s elapsed | ETA 279s
#   [TRAIN-200] 2700/40000 | 20s elapsed | ETA 278s
#   [TRAIN-200] 2800/40000 | 21s elapsed | ETA 278s
#   [TRAIN-200] 2900/40000 | 22s elapsed | ETA 278s
#   [TRAIN-200] 3000/40000 | 22s elapsed | ETA 277s
#   [TRAIN-200] 3100/40000 | 23s elapsed | ETA 276s
#   [TRAIN-200] 3200/40000 | 24s elapsed | ETA 275s
#   [TRAIN-200] 3300/40000 | 25s elapsed | ETA 274s
#   [TRAIN-200] 3400/40000 | 25s elapsed | ETA 273s
#   [TRAIN-200] 3500/40000 | 26s elapsed | ETA 273s
#   [TRAIN-200] 3600/40000 | 27s elapsed | ETA 272s
#   [TRAIN-200] 3700/40000 | 28s elapsed | ETA 271s
#   [TRAIN-200] 3800/40000 | 28s elapsed | ETA 270s
#   [TRAIN-200] 3900/40000 | 29s elapsed | ETA 269s
#   [TRAIN-200] 4000/40000 | 30s elapsed | ETA 268s
#   [TRAIN-200] 4100/40000 | 31s elapsed | ETA 267s
#   [TRAIN-200] 4200/40000 | 31s elapsed | ETA 267s
#   [TRAIN-200] 4300/40000 | 32s elapsed | ETA 266s
#   [TRAIN-200] 4400/40000 | 33s elapsed | ETA 265s
#   [TRAIN-200] 4500/40000 | 33s elapsed | ETA 264s
#   [TRAIN-200] 4600/40000 | 34s elapsed | ETA 263s
#   [TRAIN-200] 4700/40000 | 35s elapsed | ETA 263s
#   [TRAIN-200] 4800/40000 | 36s elapsed | ETA 262s
#   [TRAIN-200] 4900/40000 | 37s elapsed | ETA 263s
#   [TRAIN-200] 5000/40000 | 38s elapsed | ETA 263s
#   [TRAIN-200] 5100/40000 | 38s elapsed | ETA 262s
#   [TRAIN-200] 5200/40000 | 39s elapsed | ETA 261s
#   [TRAIN-200] 5300/40000 | 40s elapsed | ETA 260s
#   [TRAIN-200] 5400/40000 | 40s elapsed | ETA 259s
#   [TRAIN-200] 5500/40000 | 41s elapsed | ETA 258s
#   [TRAIN-200] 5600/40000 | 42s elapsed | ETA 258s
#   [TRAIN-200] 5700/40000 | 43s elapsed | ETA 257s
#   [TRAIN-200] 5800/40000 | 43s elapsed | ETA 256s
#   [TRAIN-200] 5900/40000 | 44s elapsed | ETA 255s
#   [TRAIN-200] 6000/40000 | 45s elapsed | ETA 254s
#   [TRAIN-200] 6100/40000 | 46s elapsed | ETA 254s
#   [TRAIN-200] 6200/40000 | 46s elapsed | ETA 253s
#   [TRAIN-200] 6300/40000 | 47s elapsed | ETA 252s
#   [TRAIN-200] 6400/40000 | 48s elapsed | ETA 251s
#   [TRAIN-200] 6500/40000 | 49s elapsed | ETA 250s
#   [TRAIN-200] 6600/40000 | 49s elapsed | ETA 249s
#   [TRAIN-200] 6700/40000 | 50s elapsed | ETA 249s
#   [TRAIN-200] 6800/40000 | 51s elapsed | ETA 248s
#   [TRAIN-200] 6900/40000 | 51s elapsed | ETA 247s
#   [TRAIN-200] 7000/40000 | 52s elapsed | ETA 246s
#   [TRAIN-200] 7100/40000 | 53s elapsed | ETA 245s
#   [TRAIN-200] 7200/40000 | 54s elapsed | ETA 245s
#   [TRAIN-200] 7300/40000 | 54s elapsed | ETA 244s
#   [TRAIN-200] 7400/40000 | 55s elapsed | ETA 243s
#   [TRAIN-200] 7500/40000 | 56s elapsed | ETA 242s
#   [TRAIN-200] 7600/40000 | 57s elapsed | ETA 241s
#   [TRAIN-200] 7700/40000 | 57s elapsed | ETA 241s
#   [TRAIN-200] 7800/40000 | 58s elapsed | ETA 240s
#   [TRAIN-200] 7900/40000 | 59s elapsed | ETA 239s
#   [TRAIN-200] 8000/40000 | 60s elapsed | ETA 238s
#   [TRAIN-200] 8100/40000 | 60s elapsed | ETA 238s
#   [TRAIN-200] 8200/40000 | 61s elapsed | ETA 237s
#   [TRAIN-200] 8300/40000 | 62s elapsed | ETA 236s
#   [TRAIN-200] 8400/40000 | 63s elapsed | ETA 235s
#   [TRAIN-200] 8500/40000 | 63s elapsed | ETA 234s
#   [TRAIN-200] 8600/40000 | 64s elapsed | ETA 234s
#   [TRAIN-200] 8700/40000 | 65s elapsed | ETA 233s
#   [TRAIN-200] 8800/40000 | 66s elapsed | ETA 232s
#   [TRAIN-200] 8900/40000 | 66s elapsed | ETA 231s
#   [TRAIN-200] 9000/40000 | 67s elapsed | ETA 231s
#   [TRAIN-200] 9100/40000 | 68s elapsed | ETA 230s
#   [TRAIN-200] 9200/40000 | 69s elapsed | ETA 230s
#   [TRAIN-200] 9300/40000 | 69s elapsed | ETA 229s
#   [TRAIN-200] 9400/40000 | 70s elapsed | ETA 228s
#   [TRAIN-200] 9500/40000 | 71s elapsed | ETA 228s
#   [TRAIN-200] 9600/40000 | 72s elapsed | ETA 227s
#   [TRAIN-200] 9700/40000 | 72s elapsed | ETA 226s
#   [TRAIN-200] 9800/40000 | 73s elapsed | ETA 225s
#   [TRAIN-200] 9900/40000 | 74s elapsed | ETA 225s
#   [TRAIN-200] 10000/40000 | 75s elapsed | ETA 224s
#   [TRAIN-200] 10100/40000 | 75s elapsed | ETA 223s
#   [TRAIN-200] 10200/40000 | 76s elapsed | ETA 222s
#   [TRAIN-200] 10300/40000 | 77s elapsed | ETA 221s
#   [TRAIN-200] 10400/40000 | 78s elapsed | ETA 221s
#   [TRAIN-200] 10500/40000 | 78s elapsed | ETA 220s
#   [TRAIN-200] 10600/40000 | 79s elapsed | ETA 219s
#   [TRAIN-200] 10700/40000 | 80s elapsed | ETA 218s
#   [TRAIN-200] 10800/40000 | 80s elapsed | ETA 218s
#   [TRAIN-200] 10900/40000 | 81s elapsed | ETA 217s
#   [TRAIN-200] 11000/40000 | 82s elapsed | ETA 216s
#   [TRAIN-200] 11100/40000 | 83s elapsed | ETA 215s
#   [TRAIN-200] 11200/40000 | 83s elapsed | ETA 214s
#   [TRAIN-200] 11300/40000 | 84s elapsed | ETA 214s
#   [TRAIN-200] 11400/40000 | 85s elapsed | ETA 213s
#   [TRAIN-200] 11500/40000 | 86s elapsed | ETA 212s
#   [TRAIN-200] 11600/40000 | 86s elapsed | ETA 212s
#   [TRAIN-200] 11700/40000 | 87s elapsed | ETA 211s
#   [TRAIN-200] 11800/40000 | 88s elapsed | ETA 210s
#   [TRAIN-200] 11900/40000 | 89s elapsed | ETA 209s
#   [TRAIN-200] 12000/40000 | 89s elapsed | ETA 208s
#   [TRAIN-200] 12100/40000 | 90s elapsed | ETA 208s
#   [TRAIN-200] 12200/40000 | 91s elapsed | ETA 207s
#   [TRAIN-200] 12300/40000 | 92s elapsed | ETA 206s
#   [TRAIN-200] 12400/40000 | 92s elapsed | ETA 205s
#   [TRAIN-200] 12500/40000 | 93s elapsed | ETA 205s
#   [TRAIN-200] 12600/40000 | 94s elapsed | ETA 204s
#   [TRAIN-200] 12700/40000 | 94s elapsed | ETA 203s
#   [TRAIN-200] 12800/40000 | 95s elapsed | ETA 202s
#   [TRAIN-200] 12900/40000 | 96s elapsed | ETA 202s
#   [TRAIN-200] 13000/40000 | 97s elapsed | ETA 201s
#   [TRAIN-200] 13100/40000 | 97s elapsed | ETA 200s
#   [TRAIN-200] 13200/40000 | 98s elapsed | ETA 199s
#   [TRAIN-200] 13300/40000 | 99s elapsed | ETA 198s
#   [TRAIN-200] 13400/40000 | 100s elapsed | ETA 198s
#   [TRAIN-200] 13500/40000 | 100s elapsed | ETA 197s
#   [TRAIN-200] 13600/40000 | 101s elapsed | ETA 196s
#   [TRAIN-200] 13700/40000 | 102s elapsed | ETA 196s
#   [TRAIN-200] 13800/40000 | 103s elapsed | ETA 195s
#   [TRAIN-200] 13900/40000 | 103s elapsed | ETA 194s
#   [TRAIN-200] 14000/40000 | 104s elapsed | ETA 193s
#   [TRAIN-200] 14100/40000 | 105s elapsed | ETA 193s
#   [TRAIN-200] 14200/40000 | 106s elapsed | ETA 192s
#   [TRAIN-200] 14300/40000 | 106s elapsed | ETA 191s
#   [TRAIN-200] 14400/40000 | 107s elapsed | ETA 191s
#   [TRAIN-200] 14500/40000 | 108s elapsed | ETA 190s
#   [TRAIN-200] 14600/40000 | 109s elapsed | ETA 189s
#   [TRAIN-200] 14700/40000 | 109s elapsed | ETA 188s
#   [TRAIN-200] 14800/40000 | 110s elapsed | ETA 188s
#   [TRAIN-200] 14900/40000 | 111s elapsed | ETA 187s
#   [TRAIN-200] 15000/40000 | 112s elapsed | ETA 186s
#   [TRAIN-200] 15100/40000 | 112s elapsed | ETA 185s
#   [TRAIN-200] 15200/40000 | 113s elapsed | ETA 184s
#   [TRAIN-200] 15300/40000 | 114s elapsed | ETA 184s
#   [TRAIN-200] 15400/40000 | 115s elapsed | ETA 183s
#   [TRAIN-200] 15500/40000 | 115s elapsed | ETA 182s
#   [TRAIN-200] 15600/40000 | 116s elapsed | ETA 181s
#   [TRAIN-200] 15700/40000 | 117s elapsed | ETA 181s
#   [TRAIN-200] 15800/40000 | 118s elapsed | ETA 180s
#   [TRAIN-200] 15900/40000 | 118s elapsed | ETA 179s
#   [TRAIN-200] 16000/40000 | 119s elapsed | ETA 178s
#   [TRAIN-200] 16100/40000 | 120s elapsed | ETA 178s
#   [TRAIN-200] 16200/40000 | 120s elapsed | ETA 177s
#   [TRAIN-200] 16300/40000 | 121s elapsed | ETA 176s
#   [TRAIN-200] 16400/40000 | 122s elapsed | ETA 175s
#   [TRAIN-200] 16500/40000 | 123s elapsed | ETA 175s
#   [TRAIN-200] 16600/40000 | 123s elapsed | ETA 174s
#   [TRAIN-200] 16700/40000 | 124s elapsed | ETA 173s
#   [TRAIN-200] 16800/40000 | 125s elapsed | ETA 172s
#   [TRAIN-200] 16900/40000 | 126s elapsed | ETA 172s
#   [TRAIN-200] 17000/40000 | 126s elapsed | ETA 171s
#   [TRAIN-200] 17100/40000 | 127s elapsed | ETA 170s
#   [TRAIN-200] 17200/40000 | 128s elapsed | ETA 169s
#   [TRAIN-200] 17300/40000 | 129s elapsed | ETA 169s
#   [TRAIN-200] 17400/40000 | 129s elapsed | ETA 168s
#   [TRAIN-200] 17500/40000 | 130s elapsed | ETA 167s
#   [TRAIN-200] 17600/40000 | 131s elapsed | ETA 166s
#   [TRAIN-200] 17700/40000 | 132s elapsed | ETA 166s
#   [TRAIN-200] 17800/40000 | 132s elapsed | ETA 165s
#   [TRAIN-200] 17900/40000 | 133s elapsed | ETA 164s
#   [TRAIN-200] 18000/40000 | 134s elapsed | ETA 164s
#   [TRAIN-200] 18100/40000 | 135s elapsed | ETA 163s
#   [TRAIN-200] 18200/40000 | 135s elapsed | ETA 162s
#   [TRAIN-200] 18300/40000 | 136s elapsed | ETA 161s
#   [TRAIN-200] 18400/40000 | 137s elapsed | ETA 161s
#   [TRAIN-200] 18500/40000 | 138s elapsed | ETA 160s
#   [TRAIN-200] 18600/40000 | 138s elapsed | ETA 159s
#   [TRAIN-200] 18700/40000 | 139s elapsed | ETA 158s
#   [TRAIN-200] 18800/40000 | 140s elapsed | ETA 158s
#   [TRAIN-200] 18900/40000 | 141s elapsed | ETA 157s
#   [TRAIN-200] 19000/40000 | 141s elapsed | ETA 156s
#   [TRAIN-200] 19100/40000 | 142s elapsed | ETA 155s
#   [TRAIN-200] 19200/40000 | 143s elapsed | ETA 155s
#   [TRAIN-200] 19300/40000 | 144s elapsed | ETA 154s
#   [TRAIN-200] 19400/40000 | 144s elapsed | ETA 153s
#   [TRAIN-200] 19500/40000 | 145s elapsed | ETA 152s
#   [TRAIN-200] 19600/40000 | 146s elapsed | ETA 152s
#   [TRAIN-200] 19700/40000 | 146s elapsed | ETA 151s
#   [TRAIN-200] 19800/40000 | 147s elapsed | ETA 150s
#   [TRAIN-200] 19900/40000 | 148s elapsed | ETA 149s
#   [TRAIN-200] 20000/40000 | 149s elapsed | ETA 149s
#   [TRAIN-200] 20100/40000 | 149s elapsed | ETA 148s
#   [TRAIN-200] 20200/40000 | 150s elapsed | ETA 147s
#   [TRAIN-200] 20300/40000 | 151s elapsed | ETA 146s
#   [TRAIN-200] 20400/40000 | 152s elapsed | ETA 146s
#   [TRAIN-200] 20500/40000 | 152s elapsed | ETA 145s
#   [TRAIN-200] 20600/40000 | 153s elapsed | ETA 144s
#   [TRAIN-200] 20700/40000 | 154s elapsed | ETA 143s
#   [TRAIN-200] 20800/40000 | 155s elapsed | ETA 143s
#   [TRAIN-200] 20900/40000 | 155s elapsed | ETA 142s
#   [TRAIN-200] 21000/40000 | 156s elapsed | ETA 141s
#   [TRAIN-200] 21100/40000 | 157s elapsed | ETA 140s
#   [TRAIN-200] 21200/40000 | 158s elapsed | ETA 140s
#   [TRAIN-200] 21300/40000 | 158s elapsed | ETA 139s
#   [TRAIN-200] 21400/40000 | 159s elapsed | ETA 138s
#   [TRAIN-200] 21500/40000 | 160s elapsed | ETA 137s
#   [TRAIN-200] 21600/40000 | 160s elapsed | ETA 137s
#   [TRAIN-200] 21700/40000 | 161s elapsed | ETA 136s
#   [TRAIN-200] 21800/40000 | 162s elapsed | ETA 135s
#   [TRAIN-200] 21900/40000 | 163s elapsed | ETA 134s
#   [TRAIN-200] 22000/40000 | 164s elapsed | ETA 134s
#   [TRAIN-200] 22100/40000 | 164s elapsed | ETA 133s
#   [TRAIN-200] 22200/40000 | 165s elapsed | ETA 132s
#   [TRAIN-200] 22300/40000 | 166s elapsed | ETA 132s
#   [TRAIN-200] 22400/40000 | 167s elapsed | ETA 131s
#   [TRAIN-200] 22500/40000 | 167s elapsed | ETA 130s
#   [TRAIN-200] 22600/40000 | 168s elapsed | ETA 129s
#   [TRAIN-200] 22700/40000 | 169s elapsed | ETA 129s
#   [TRAIN-200] 22800/40000 | 170s elapsed | ETA 128s
#   [TRAIN-200] 22900/40000 | 170s elapsed | ETA 127s
#   [TRAIN-200] 23000/40000 | 171s elapsed | ETA 127s
#   [TRAIN-200] 23100/40000 | 172s elapsed | ETA 126s
#   [TRAIN-200] 23200/40000 | 173s elapsed | ETA 125s
#   [TRAIN-200] 23300/40000 | 174s elapsed | ETA 125s
#   [TRAIN-200] 23400/40000 | 175s elapsed | ETA 124s
#   [TRAIN-200] 23500/40000 | 175s elapsed | ETA 123s
#   [TRAIN-200] 23600/40000 | 176s elapsed | ETA 122s
#   [TRAIN-200] 23700/40000 | 177s elapsed | ETA 122s
#   [TRAIN-200] 23800/40000 | 178s elapsed | ETA 121s
#   [TRAIN-200] 23900/40000 | 178s elapsed | ETA 120s
#   [TRAIN-200] 24000/40000 | 179s elapsed | ETA 119s
#   [TRAIN-200] 24100/40000 | 180s elapsed | ETA 119s
#   [TRAIN-200] 24200/40000 | 180s elapsed | ETA 118s
#   [TRAIN-200] 24300/40000 | 181s elapsed | ETA 117s
#   [TRAIN-200] 24400/40000 | 182s elapsed | ETA 116s
#   [TRAIN-200] 24500/40000 | 183s elapsed | ETA 116s
#   [TRAIN-200] 24600/40000 | 184s elapsed | ETA 115s
#   [TRAIN-200] 24700/40000 | 184s elapsed | ETA 114s
#   [TRAIN-200] 24800/40000 | 185s elapsed | ETA 113s
#   [TRAIN-200] 24900/40000 | 186s elapsed | ETA 113s
#   [TRAIN-200] 25000/40000 | 187s elapsed | ETA 112s
#   [TRAIN-200] 25100/40000 | 187s elapsed | ETA 111s
#   [TRAIN-200] 25200/40000 | 188s elapsed | ETA 111s
#   [TRAIN-200] 25300/40000 | 189s elapsed | ETA 110s
#   [TRAIN-200] 25400/40000 | 190s elapsed | ETA 109s
#   [TRAIN-200] 25500/40000 | 190s elapsed | ETA 108s
#   [TRAIN-200] 25600/40000 | 191s elapsed | ETA 108s
#   [TRAIN-200] 25700/40000 | 192s elapsed | ETA 107s
#   [TRAIN-200] 25800/40000 | 193s elapsed | ETA 106s
#   [TRAIN-200] 25900/40000 | 193s elapsed | ETA 105s
#   [TRAIN-200] 26000/40000 | 194s elapsed | ETA 105s
#   [TRAIN-200] 26100/40000 | 195s elapsed | ETA 104s
#   [TRAIN-200] 26200/40000 | 196s elapsed | ETA 103s
#   [TRAIN-200] 26300/40000 | 196s elapsed | ETA 102s
#   [TRAIN-200] 26400/40000 | 197s elapsed | ETA 102s
#   [TRAIN-200] 26500/40000 | 198s elapsed | ETA 101s
#   [TRAIN-200] 26600/40000 | 199s elapsed | ETA 100s
#   [TRAIN-200] 26700/40000 | 200s elapsed | ETA 99s
#   [TRAIN-200] 26800/40000 | 200s elapsed | ETA 99s
#   [TRAIN-200] 26900/40000 | 201s elapsed | ETA 98s
#   [TRAIN-200] 27000/40000 | 202s elapsed | ETA 97s
#   [TRAIN-200] 27100/40000 | 202s elapsed | ETA 96s
#   [TRAIN-200] 27200/40000 | 203s elapsed | ETA 96s
#   [TRAIN-200] 27300/40000 | 204s elapsed | ETA 95s
#   [TRAIN-200] 27400/40000 | 205s elapsed | ETA 94s
#   [TRAIN-200] 27500/40000 | 205s elapsed | ETA 93s
#   [TRAIN-200] 27600/40000 | 206s elapsed | ETA 93s
#   [TRAIN-200] 27700/40000 | 207s elapsed | ETA 92s
#   [TRAIN-200] 27800/40000 | 208s elapsed | ETA 91s
#   [TRAIN-200] 27900/40000 | 208s elapsed | ETA 90s
#   [TRAIN-200] 28000/40000 | 209s elapsed | ETA 90s
#   [TRAIN-200] 28100/40000 | 210s elapsed | ETA 89s
#   [TRAIN-200] 28200/40000 | 211s elapsed | ETA 88s
#   [TRAIN-200] 28300/40000 | 211s elapsed | ETA 87s
#   [TRAIN-200] 28400/40000 | 212s elapsed | ETA 87s
#   [TRAIN-200] 28500/40000 | 213s elapsed | ETA 86s
#   [TRAIN-200] 28600/40000 | 214s elapsed | ETA 85s
#   [TRAIN-200] 28700/40000 | 214s elapsed | ETA 84s
#   [TRAIN-200] 28800/40000 | 215s elapsed | ETA 84s
#   [TRAIN-200] 28900/40000 | 216s elapsed | ETA 83s
#   [TRAIN-200] 29000/40000 | 216s elapsed | ETA 82s
#   [TRAIN-200] 29100/40000 | 217s elapsed | ETA 81s
#   [TRAIN-200] 29200/40000 | 218s elapsed | ETA 81s
#   [TRAIN-200] 29300/40000 | 219s elapsed | ETA 80s
#   [TRAIN-200] 29400/40000 | 219s elapsed | ETA 79s
#   [TRAIN-200] 29500/40000 | 220s elapsed | ETA 78s
#   [TRAIN-200] 29600/40000 | 221s elapsed | ETA 78s
#   [TRAIN-200] 29700/40000 | 222s elapsed | ETA 77s
#   [TRAIN-200] 29800/40000 | 222s elapsed | ETA 76s
#   [TRAIN-200] 29900/40000 | 223s elapsed | ETA 75s
#   [TRAIN-200] 30000/40000 | 224s elapsed | ETA 75s
#   [TRAIN-200] 30100/40000 | 225s elapsed | ETA 74s
#   [TRAIN-200] 30200/40000 | 226s elapsed | ETA 73s
#   [TRAIN-200] 30300/40000 | 226s elapsed | ETA 72s
#   [TRAIN-200] 30400/40000 | 227s elapsed | ETA 72s
#   [TRAIN-200] 30500/40000 | 228s elapsed | ETA 71s
#   [TRAIN-200] 30600/40000 | 229s elapsed | ETA 70s
#   [TRAIN-200] 30700/40000 | 229s elapsed | ETA 70s
#   [TRAIN-200] 30800/40000 | 230s elapsed | ETA 69s
#   [TRAIN-200] 30900/40000 | 231s elapsed | ETA 68s
#   [TRAIN-200] 31000/40000 | 232s elapsed | ETA 67s
#   [TRAIN-200] 31100/40000 | 232s elapsed | ETA 67s
#   [TRAIN-200] 31200/40000 | 233s elapsed | ETA 66s
#   [TRAIN-200] 31300/40000 | 234s elapsed | ETA 65s
#   [TRAIN-200] 31400/40000 | 235s elapsed | ETA 64s
#   [TRAIN-200] 31500/40000 | 235s elapsed | ETA 64s
#   [TRAIN-200] 31600/40000 | 236s elapsed | ETA 63s
#   [TRAIN-200] 31700/40000 | 237s elapsed | ETA 62s
#   [TRAIN-200] 31800/40000 | 238s elapsed | ETA 61s
#   [TRAIN-200] 31900/40000 | 238s elapsed | ETA 61s
#   [TRAIN-200] 32000/40000 | 239s elapsed | ETA 60s
#   [TRAIN-200] 32100/40000 | 240s elapsed | ETA 59s
#   [TRAIN-200] 32200/40000 | 241s elapsed | ETA 58s
#   [TRAIN-200] 32300/40000 | 241s elapsed | ETA 58s
#   [TRAIN-200] 32400/40000 | 242s elapsed | ETA 57s
#   [TRAIN-200] 32500/40000 | 243s elapsed | ETA 56s
#   [TRAIN-200] 32600/40000 | 244s elapsed | ETA 55s
#   [TRAIN-200] 32700/40000 | 244s elapsed | ETA 55s
#   [TRAIN-200] 32800/40000 | 245s elapsed | ETA 54s
#   [TRAIN-200] 32900/40000 | 246s elapsed | ETA 53s
#   [TRAIN-200] 33000/40000 | 247s elapsed | ETA 52s
#   [TRAIN-200] 33100/40000 | 247s elapsed | ETA 52s
#   [TRAIN-200] 33200/40000 | 248s elapsed | ETA 51s
#   [TRAIN-200] 33300/40000 | 249s elapsed | ETA 50s
#   [TRAIN-200] 33400/40000 | 250s elapsed | ETA 49s
#   [TRAIN-200] 33500/40000 | 250s elapsed | ETA 49s
#   [TRAIN-200] 33600/40000 | 251s elapsed | ETA 48s
#   [TRAIN-200] 33700/40000 | 252s elapsed | ETA 47s
#   [TRAIN-200] 33800/40000 | 253s elapsed | ETA 46s
#   [TRAIN-200] 33900/40000 | 253s elapsed | ETA 46s
#   [TRAIN-200] 34000/40000 | 254s elapsed | ETA 45s
#   [TRAIN-200] 34100/40000 | 255s elapsed | ETA 44s
#   [TRAIN-200] 34200/40000 | 256s elapsed | ETA 43s
#   [TRAIN-200] 34300/40000 | 256s elapsed | ETA 43s
#   [TRAIN-200] 34400/40000 | 257s elapsed | ETA 42s
#   [TRAIN-200] 34500/40000 | 258s elapsed | ETA 41s
#   [TRAIN-200] 34600/40000 | 259s elapsed | ETA 40s
#   [TRAIN-200] 34700/40000 | 259s elapsed | ETA 40s
#   [TRAIN-200] 34800/40000 | 260s elapsed | ETA 39s
#   [TRAIN-200] 34900/40000 | 261s elapsed | ETA 38s
#   [TRAIN-200] 35000/40000 | 262s elapsed | ETA 37s
#   [TRAIN-200] 35100/40000 | 262s elapsed | ETA 37s
#   [TRAIN-200] 35200/40000 | 263s elapsed | ETA 36s
#   [TRAIN-200] 35300/40000 | 264s elapsed | ETA 35s
#   [TRAIN-200] 35400/40000 | 265s elapsed | ETA 34s
#   [TRAIN-200] 35500/40000 | 265s elapsed | ETA 34s
#   [TRAIN-200] 35600/40000 | 266s elapsed | ETA 33s
#   [TRAIN-200] 35700/40000 | 267s elapsed | ETA 32s
#   [TRAIN-200] 35800/40000 | 268s elapsed | ETA 31s
#   [TRAIN-200] 35900/40000 | 268s elapsed | ETA 31s
#   [TRAIN-200] 36000/40000 | 269s elapsed | ETA 30s
#   [TRAIN-200] 36100/40000 | 270s elapsed | ETA 29s
#   [TRAIN-200] 36200/40000 | 271s elapsed | ETA 28s
#   [TRAIN-200] 36300/40000 | 272s elapsed | ETA 28s
#   [TRAIN-200] 36400/40000 | 272s elapsed | ETA 27s
#   [TRAIN-200] 36500/40000 | 273s elapsed | ETA 26s
#   [TRAIN-200] 36600/40000 | 274s elapsed | ETA 25s
#   [TRAIN-200] 36700/40000 | 274s elapsed | ETA 25s
#   [TRAIN-200] 36800/40000 | 275s elapsed | ETA 24s
#   [TRAIN-200] 36900/40000 | 276s elapsed | ETA 23s
#   [TRAIN-200] 37000/40000 | 277s elapsed | ETA 22s
#   [TRAIN-200] 37100/40000 | 277s elapsed | ETA 22s
#   [TRAIN-200] 37200/40000 | 278s elapsed | ETA 21s
#   [TRAIN-200] 37300/40000 | 279s elapsed | ETA 20s
#   [TRAIN-200] 37400/40000 | 280s elapsed | ETA 19s
#   [TRAIN-200] 37500/40000 | 280s elapsed | ETA 19s
#   [TRAIN-200] 37600/40000 | 281s elapsed | ETA 18s
#   [TRAIN-200] 37700/40000 | 282s elapsed | ETA 17s
#   [TRAIN-200] 37800/40000 | 283s elapsed | ETA 16s
#   [TRAIN-200] 37900/40000 | 283s elapsed | ETA 16s
#   [TRAIN-200] 38000/40000 | 284s elapsed | ETA 15s
#   [TRAIN-200] 38100/40000 | 285s elapsed | ETA 14s
#   [TRAIN-200] 38200/40000 | 286s elapsed | ETA 13s
#   [TRAIN-200] 38300/40000 | 286s elapsed | ETA 13s
#   [TRAIN-200] 38400/40000 | 287s elapsed | ETA 12s
#   [TRAIN-200] 38500/40000 | 288s elapsed | ETA 11s
#   [TRAIN-200] 38600/40000 | 289s elapsed | ETA 10s
#   [TRAIN-200] 38700/40000 | 289s elapsed | ETA 10s
#   [TRAIN-200] 38800/40000 | 290s elapsed | ETA 9s
#   [TRAIN-200] 38900/40000 | 291s elapsed | ETA 8s
#   [TRAIN-200] 39000/40000 | 292s elapsed | ETA 7s
#   [TRAIN-200] 39100/40000 | 292s elapsed | ETA 7s
#   [TRAIN-200] 39200/40000 | 293s elapsed | ETA 6s
#   [TRAIN-200] 39300/40000 | 294s elapsed | ETA 5s
#   [TRAIN-200] 39400/40000 | 295s elapsed | ETA 4s
#   [TRAIN-200] 39500/40000 | 295s elapsed | ETA 4s
#   [TRAIN-200] 39600/40000 | 296s elapsed | ETA 3s
#   [TRAIN-200] 39700/40000 | 297s elapsed | ETA 2s
#   [TRAIN-200] 39800/40000 | 298s elapsed | ETA 1s
#   [TRAIN-200] 39900/40000 | 298s elapsed | ETA 1s
#   [TRAIN-200] 40000/40000 | 299s elapsed | ETA 0s
#   [TRAIN-200] Done — 200x200 in 299s
#   [VAL-200] 100/12000 | 1s elapsed | ETA 88s
#   [VAL-200] 200/12000 | 1s elapsed | ETA 87s
#   [VAL-200] 300/12000 | 2s elapsed | ETA 87s
#   [VAL-200] 400/12000 | 3s elapsed | ETA 86s
#   [VAL-200] 500/12000 | 4s elapsed | ETA 86s
#   [VAL-200] 600/12000 | 4s elapsed | ETA 85s
#   [VAL-200] 700/12000 | 5s elapsed | ETA 84s
#   [VAL-200] 800/12000 | 6s elapsed | ETA 83s
#   [VAL-200] 900/12000 | 7s elapsed | ETA 82s
#   [VAL-200] 1000/12000 | 7s elapsed | ETA 82s
#   [VAL-200] 1100/12000 | 8s elapsed | ETA 81s
#   [VAL-200] 1200/12000 | 9s elapsed | ETA 80s
#   [VAL-200] 1300/12000 | 10s elapsed | ETA 80s
#   [VAL-200] 1400/12000 | 10s elapsed | ETA 79s
#   [VAL-200] 1500/12000 | 11s elapsed | ETA 79s
#   [VAL-200] 1600/12000 | 12s elapsed | ETA 78s
#   [VAL-200] 1700/12000 | 13s elapsed | ETA 77s
#   [VAL-200] 1800/12000 | 13s elapsed | ETA 76s
#   [VAL-200] 1900/12000 | 14s elapsed | ETA 75s
#   [VAL-200] 2000/12000 | 15s elapsed | ETA 75s
#   [VAL-200] 2100/12000 | 16s elapsed | ETA 74s
#   [VAL-200] 2200/12000 | 16s elapsed | ETA 73s
#   [VAL-200] 2300/12000 | 17s elapsed | ETA 73s
#   [VAL-200] 2400/12000 | 18s elapsed | ETA 72s
#   [VAL-200] 2500/12000 | 19s elapsed | ETA 71s
#   [VAL-200] 2600/12000 | 19s elapsed | ETA 70s
#   [VAL-200] 2700/12000 | 20s elapsed | ETA 70s
#   [VAL-200] 2800/12000 | 21s elapsed | ETA 69s
#   [VAL-200] 2900/12000 | 22s elapsed | ETA 68s
#   [VAL-200] 3000/12000 | 22s elapsed | ETA 67s
#   [VAL-200] 3100/12000 | 23s elapsed | ETA 66s
#   [VAL-200] 3200/12000 | 24s elapsed | ETA 66s
#   [VAL-200] 3300/12000 | 25s elapsed | ETA 65s
#   [VAL-200] 3400/12000 | 26s elapsed | ETA 65s
#   [VAL-200] 3500/12000 | 26s elapsed | ETA 64s
#   [VAL-200] 3600/12000 | 27s elapsed | ETA 63s
#   [VAL-200] 3700/12000 | 28s elapsed | ETA 62s
#   [VAL-200] 3800/12000 | 29s elapsed | ETA 62s
#   [VAL-200] 3900/12000 | 29s elapsed | ETA 61s
#   [VAL-200] 4000/12000 | 30s elapsed | ETA 60s
#   [VAL-200] 4100/12000 | 31s elapsed | ETA 59s
#   [VAL-200] 4200/12000 | 32s elapsed | ETA 59s
#   [VAL-200] 4300/12000 | 32s elapsed | ETA 58s
#   [VAL-200] 4400/12000 | 33s elapsed | ETA 57s
#   [VAL-200] 4500/12000 | 34s elapsed | ETA 56s
#   [VAL-200] 4600/12000 | 35s elapsed | ETA 56s
#   [VAL-200] 4700/12000 | 35s elapsed | ETA 55s
#   [VAL-200] 4800/12000 | 36s elapsed | ETA 54s
#   [VAL-200] 4900/12000 | 37s elapsed | ETA 53s
#   [VAL-200] 5000/12000 | 37s elapsed | ETA 52s
#   [VAL-200] 5100/12000 | 38s elapsed | ETA 52s
#   [VAL-200] 5200/12000 | 39s elapsed | ETA 51s
#   [VAL-200] 5300/12000 | 40s elapsed | ETA 50s
#   [VAL-200] 5400/12000 | 40s elapsed | ETA 49s
#   [VAL-200] 5500/12000 | 41s elapsed | ETA 49s
#   [VAL-200] 5600/12000 | 42s elapsed | ETA 48s
#   [VAL-200] 5700/12000 | 43s elapsed | ETA 47s
#   [VAL-200] 5800/12000 | 43s elapsed | ETA 46s
#   [VAL-200] 5900/12000 | 44s elapsed | ETA 46s
#   [VAL-200] 6000/12000 | 45s elapsed | ETA 45s
#   [VAL-200] 6100/12000 | 46s elapsed | ETA 44s
#   [VAL-200] 6200/12000 | 46s elapsed | ETA 43s
#   [VAL-200] 6300/12000 | 47s elapsed | ETA 43s
#   [VAL-200] 6400/12000 | 48s elapsed | ETA 42s
#   [VAL-200] 6500/12000 | 49s elapsed | ETA 41s
#   [VAL-200] 6600/12000 | 49s elapsed | ETA 40s
#   [VAL-200] 6700/12000 | 50s elapsed | ETA 40s
#   [VAL-200] 6800/12000 | 51s elapsed | ETA 39s
#   [VAL-200] 6900/12000 | 52s elapsed | ETA 38s
#   [VAL-200] 7000/12000 | 52s elapsed | ETA 37s
#   [VAL-200] 7100/12000 | 53s elapsed | ETA 37s
#   [VAL-200] 7200/12000 | 54s elapsed | ETA 36s
#   [VAL-200] 7300/12000 | 55s elapsed | ETA 35s
#   [VAL-200] 7400/12000 | 55s elapsed | ETA 34s
#   [VAL-200] 7500/12000 | 56s elapsed | ETA 34s
#   [VAL-200] 7600/12000 | 57s elapsed | ETA 33s
#   [VAL-200] 7700/12000 | 58s elapsed | ETA 32s
#   [VAL-200] 7800/12000 | 59s elapsed | ETA 32s
#   [VAL-200] 7900/12000 | 59s elapsed | ETA 31s
#   [VAL-200] 8000/12000 | 60s elapsed | ETA 30s
#   [VAL-200] 8100/12000 | 61s elapsed | ETA 29s
#   [VAL-200] 8200/12000 | 62s elapsed | ETA 29s
#   [VAL-200] 8300/12000 | 62s elapsed | ETA 28s
#   [VAL-200] 8400/12000 | 63s elapsed | ETA 27s
#   [VAL-200] 8500/12000 | 64s elapsed | ETA 26s
#   [VAL-200] 8600/12000 | 65s elapsed | ETA 26s
#   [VAL-200] 8700/12000 | 65s elapsed | ETA 25s
#   [VAL-200] 8800/12000 | 66s elapsed | ETA 24s
#   [VAL-200] 8900/12000 | 67s elapsed | ETA 23s
#   [VAL-200] 9000/12000 | 68s elapsed | ETA 23s
#   [VAL-200] 9100/12000 | 68s elapsed | ETA 22s
#   [VAL-200] 9200/12000 | 69s elapsed | ETA 21s
#   [VAL-200] 9300/12000 | 70s elapsed | ETA 20s
#   [VAL-200] 9400/12000 | 70s elapsed | ETA 19s
#   [VAL-200] 9500/12000 | 71s elapsed | ETA 19s
#   [VAL-200] 9600/12000 | 72s elapsed | ETA 18s
#   [VAL-200] 9700/12000 | 73s elapsed | ETA 17s
#   [VAL-200] 9800/12000 | 73s elapsed | ETA 16s
#   [VAL-200] 9900/12000 | 74s elapsed | ETA 16s
#   [VAL-200] 10000/12000 | 75s elapsed | ETA 15s
#   [VAL-200] 10100/12000 | 76s elapsed | ETA 14s
#   [VAL-200] 10200/12000 | 76s elapsed | ETA 13s
#   [VAL-200] 10300/12000 | 77s elapsed | ETA 13s
#   [VAL-200] 10400/12000 | 78s elapsed | ETA 12s
#   [VAL-200] 10500/12000 | 79s elapsed | ETA 11s
#   [VAL-200] 10600/12000 | 79s elapsed | ETA 10s
#   [VAL-200] 10700/12000 | 80s elapsed | ETA 10s
#   [VAL-200] 10800/12000 | 81s elapsed | ETA 9s
#   [VAL-200] 10900/12000 | 82s elapsed | ETA 8s
#   [VAL-200] 11000/12000 | 82s elapsed | ETA 7s
#   [VAL-200] 11100/12000 | 83s elapsed | ETA 7s
#   [VAL-200] 11200/12000 | 84s elapsed | ETA 6s
#   [VAL-200] 11300/12000 | 85s elapsed | ETA 5s
#   [VAL-200] 11400/12000 | 85s elapsed | ETA 4s
#   [VAL-200] 11500/12000 | 86s elapsed | ETA 4s
#   [VAL-200] 11600/12000 | 87s elapsed | ETA 3s
#   [VAL-200] 11700/12000 | 88s elapsed | ETA 2s
#   [VAL-200] 11800/12000 | 88s elapsed | ETA 1s
#   [VAL-200] 11900/12000 | 89s elapsed | ETA 1s
#   [VAL-200] 12000/12000 | 90s elapsed | ETA 0s
#   [VAL-200] Done — 60x200 in 90s
#   [TEST-200] 100/20000 | 1s elapsed | ETA 158s
#   [TEST-200] 200/20000 | 2s elapsed | ETA 153s
#   [TEST-200] 300/20000 | 2s elapsed | ETA 150s
#   [TEST-200] 400/20000 | 3s elapsed | ETA 149s
#   [TEST-200] 500/20000 | 4s elapsed | ETA 148s
#   [TEST-200] 600/20000 | 5s elapsed | ETA 146s
#   [TEST-200] 700/20000 | 5s elapsed | ETA 146s
#   [TEST-200] 800/20000 | 6s elapsed | ETA 144s
#   [TEST-200] 900/20000 | 7s elapsed | ETA 144s
#   [TEST-200] 1000/20000 | 8s elapsed | ETA 143s
#   [TEST-200] 1100/20000 | 8s elapsed | ETA 142s
#   [TEST-200] 1200/20000 | 9s elapsed | ETA 141s
#   [TEST-200] 1300/20000 | 10s elapsed | ETA 141s
#   [TEST-200] 1400/20000 | 11s elapsed | ETA 140s
#   [TEST-200] 1500/20000 | 11s elapsed | ETA 139s
#   [TEST-200] 1600/20000 | 12s elapsed | ETA 138s
#   [TEST-200] 1700/20000 | 13s elapsed | ETA 138s
#   [TEST-200] 1800/20000 | 14s elapsed | ETA 137s
#   [TEST-200] 1900/20000 | 14s elapsed | ETA 136s
#   [TEST-200] 2000/20000 | 15s elapsed | ETA 135s
#   [TEST-200] 2100/20000 | 16s elapsed | ETA 135s
#   [TEST-200] 2200/20000 | 17s elapsed | ETA 135s
#   [TEST-200] 2300/20000 | 17s elapsed | ETA 134s
#   [TEST-200] 2400/20000 | 18s elapsed | ETA 133s
#   [TEST-200] 2500/20000 | 19s elapsed | ETA 132s
#   [TEST-200] 2600/20000 | 20s elapsed | ETA 131s
#   [TEST-200] 2700/20000 | 20s elapsed | ETA 130s
#   [TEST-200] 2800/20000 | 21s elapsed | ETA 130s
#   [TEST-200] 2900/20000 | 22s elapsed | ETA 129s
#   [TEST-200] 3000/20000 | 23s elapsed | ETA 128s
#   [TEST-200] 17400/20000 | 134s elapsed | ETA 20s
#   [TEST-200] 17500/20000 | 134s elapsed | ETA 19s
#   [TEST-200] 17600/20000 | 135s elapsed | ETA 18s
#   [TEST-200] 17700/20000 | 136s elapsed | ETA 18s
#   [TEST-200] 17800/20000 | 137s elapsed | ETA 17s
#   [TEST-200] 17900/20000 | 137s elapsed | ETA 16s
#   [TEST-200] 18000/20000 | 138s elapsed | ETA 15s
#   [TEST-200] 18100/20000 | 139s elapsed | ETA 15s
#   [TEST-200] 18200/20000 | 140s elapsed | ETA 14s
#   [TEST-200] 18300/20000 | 140s elapsed | ETA 13s
#   [TEST-200] 18400/20000 | 141s elapsed | ETA 12s
#   [TEST-200] 18500/20000 | 142s elapsed | ETA 11s
#   [TEST-200] 18600/20000 | 143s elapsed | ETA 11s
#   [TEST-200] 18700/20000 | 143s elapsed | ETA 10s
#   [TEST-200] 18800/20000 | 144s elapsed | ETA 9s
#   [TEST-200] 18900/20000 | 145s elapsed | ETA 8s
#   [TEST-200] 19000/20000 | 146s elapsed | ETA 8s
#   [TEST-200] 19100/20000 | 146s elapsed | ETA 7s
#   [TEST-200] 19200/20000 | 147s elapsed | ETA 6s
#   [TEST-200] 19300/20000 | 148s elapsed | ETA 5s
#   [TEST-200] 19400/20000 | 149s elapsed | ETA 5s
#   [TEST-200] 19500/20000 | 149s elapsed | ETA 4s
#   [TEST-200] 19600/20000 | 150s elapsed | ETA 3s
#   [TEST-200] 19700/20000 | 151s elapsed | ETA 2s
#   [TEST-200] 19800/20000 | 152s elapsed | ETA 2s
#   [TEST-200] 19900/20000 | 152s elapsed | ETA 1s
#   [TEST-200] 20000/20000 | 153s elapsed | ETA 0s
#   [TEST-200] Done — 100x200 in 153s
# Done.

# %% [markdown]
# # Cell 17: Attempt 7: Final QSVM (200 samples)

# %%
# Train and evaluate QSVM on the 200-sample precomputed kernels
clf7, val_acc7, test_acc7, test_f17 = evaluate_qsvm(
    K_train_200, Y_tr2, K_val_200, Y_v2, K_test_200, Y_te2)
Y_pred7 = clf7.predict(K_test_200)

# Classical SVM baseline (RBF) on the same subset
svm7 = svm.SVC(kernel="rbf", probability=True, class_weight="balanced", random_state=42)
svm7.fit(X_tr2, Y_tr2)
svm_pred7 = svm7.predict(X_te2)
svm_acc7  = accuracy_score(Y_te2, svm_pred7)
svm_f17   = f1_score(Y_te2, svm_pred7, average="weighted", zero_division=0)

# Report QSVM metrics and per-class breakdown
print("=== QSVM Results (200 samples) ===")
print(f"Val Accuracy  : {val_acc7:.3f}")
print(f"Test Accuracy : {test_acc7:.3f}")
print(f"Test F1       : {test_f17:.3f}")
print(classification_report(Y_te2, Y_pred7,
      target_names=["Upward","Downward","Flat"], zero_division=0))

# Report classical SVM metrics for direct comparison
print("=== Classical SVM Results (200 samples) ===")
print(f"Test Accuracy : {svm_acc7:.3f}")
print(f"Test F1       : {svm_f17:.3f}")
print(classification_report(Y_te2, svm_pred7,
      target_names=["Upward","Downward","Flat"], zero_division=0))

# Log final attempt: QSVM beats classical SVM with fixed adjoint and larger training set
attempt_log.append([
    7, "QSVM\nZZ Kernel\nFixed Adjoint\n200 samples",
    "Increased training subset to 200 samples. 200x200 kernel matrix = 40,000 circuit evaluations.",
    f"QSVM test acc: {test_acc7:.3f}, F1: {test_f17:.3f}. SVM test acc: {svm_acc7:.3f}, F1: {svm_f17:.3f}. QSVM wins on every metric.",
    "Success"
])
show_summary()
# Out:
# === QSVM Results (200 samples) ===
# Val Accuracy  : 0.800
# Test Accuracy : 0.730
# Test F1       : 0.726
#               precision    recall  f1-score   support
#
#       Upward       0.73      0.88      0.80        34
#     Downward       0.71      0.69      0.70        36
#         Flat       0.75      0.60      0.67        30
#
#     accuracy                           0.73       100
#    macro avg       0.73      0.73      0.72       100
# weighted avg       0.73      0.73      0.73       100
#
# === Classical SVM Results (200 samples) ===
# Test Accuracy : 0.720
# Test F1       : 0.723
#               precision    recall  f1-score   support
#
#       Upward       0.88      0.85      0.87        34
#     Downward       0.74      0.72      0.73        36
#         Flat       0.53      0.57      0.55        30
#
#     accuracy                           0.72       100
#    macro avg       0.72      0.71      0.72       100
# weighted avg       0.73      0.72      0.72       100
#
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9535. Gap: 0.0465. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0622 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700.             |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 7  |QSVM ZZ Kernel  |Increased training subset to 200  |QSVM test acc: 0.730, F1: 0.726.  |✓ Success |
# |    |Fixed Adjoint   |samples. 200x200 kernel matrix =  |SVM test acc: 0.720, F1: 0.723.   |          |
# |    |200 samples     |40,000 circuit evaluations.       |QSVM wins on every metric.        |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 18: Output Figures (Success Attempt)

# %%
# Final results figure: 2x2 grid summarizing QSVM vs classical SVM at 200 samples
# Plot 1: kernel matrix heatmap | Plot 2: QSVM confusion matrix
# Plot 3: per-class F1 comparison | Plot 4: accuracy crossover by sample size

fig, axes = plt.subplots(2, 2, figsize=(14, 11))
fig.suptitle("QSVM vs Classical SVM — Final Results (200 Training Samples)",
             fontsize=16, fontweight="bold", color="#1F4E79")

# Class label names used across all subplots
class_names = ["Upward", "Downward", "Flat"]


# ── Plot 1: Kernel Matrix Heatmap ────────────────────────────────

# Show the first 50x50 block of the training kernel matrix
# A healthy kernel has bright diagonal (k(x,x)~1) and varied off-diagonal structure
# Block patterns indicate the kernel is grouping similar samples together
ax = axes[0, 0]
sns.heatmap(K_train_200[:50, :50], cmap="viridis", ax=ax,
            xticklabels=False, yticklabels=False,
            cbar_kws={"label": "Kernel Value"})
ax.set_title("Quantum Kernel Matrix\n(first 50x50 of training set)", fontweight="bold")
ax.set_xlabel("Sample i")
ax.set_ylabel("Sample j")


# ── Plot 2: Confusion Matrices ───────────────────────────────────

# Compute raw confusion matrices for both models
ax = axes[0, 1]
cm_q  = confusion_matrix(Y_te2, Y_pred7)
cm_s  = confusion_matrix(Y_te2, svm_pred7)

# Normalize QSVM confusion matrix by row (per-class recall)
# Cells show raw counts but color reflects recall percentage
cm_q_norm = cm_q.astype(float) / cm_q.sum(axis=1, keepdims=True)
sns.heatmap(cm_q_norm, annot=cm_q, fmt="d", cmap="Oranges",
            xticklabels=class_names, yticklabels=class_names,
            ax=ax, linewidths=0.5, cbar=False)

# Highlight diagonal (correct predictions) with green borders
for i in range(3):
    ax.add_patch(plt.Rectangle((i, i), 1, 1, fill=False,
                                edgecolor="green", linewidth=2.5))
ax.set_title(f"QSVM Confusion Matrix\nTest Accuracy: {test_acc7:.3f}", fontweight="bold", color="#C0392B")
ax.set_xlabel("Predicted")
ax.set_ylabel("Actual")


# ── Plot 3: Per-class F1 ─────────────────────────────────────────

# Extract per-class and weighted-average F1 scores from sklearn reports
ax = axes[1, 0]
rep_q = classification_report(Y_te2, Y_pred7, output_dict=True, zero_division=0)
rep_s = classification_report(Y_te2, svm_pred7, output_dict=True, zero_division=0)

# Build parallel F1 lists for both models in the same class order
labels_f1 = ["Upward", "Downward", "Flat", "Overall"]
f1_q = [rep_q["0"]["f1-score"], rep_q["1"]["f1-score"],
        rep_q["2"]["f1-score"], rep_q["weighted avg"]["f1-score"]]
f1_s = [rep_s["0"]["f1-score"], rep_s["1"]["f1-score"],
        rep_s["2"]["f1-score"], rep_s["weighted avg"]["f1-score"]]

# Side-by-side grouped bar chart: classical SVM on left, QSVM on right per class
x     = np.arange(len(labels_f1))
width = 0.35
b1 = ax.bar(x - width/2, f1_s, width, color="#1F4E79", alpha=0.85, label="Classical SVM")
b2 = ax.bar(x + width/2, f1_q, width, color="#C0392B", alpha=0.85, label="QSVM")

# Annotate each bar with its F1 value above the bar
for bar in b1:
    ax.text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.008,
            f"{bar.get_height():.2f}", ha="center", fontsize=16, color="#1F4E79", fontweight="bold")
for bar in b2:
    ax.text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.008,
            f"{bar.get_height():.2f}", ha="center", fontsize=16, color="#C0392B", fontweight="bold")

# Axis and legend formatting
ax.set_xticks(x, labels=labels_f1, fontsize=14)
ax.tick_params(axis="y", labelsize=14)
ax.set_ylim(0, 1.0)
ax.set_ylabel("F1 Score", fontsize=16)
ax.set_title("Per-Class F1 Score Comparison", fontweight="bold")
ax.legend(fontsize=14)
ax.grid(True, alpha=0.3, axis="y")


# ── Plot 4: Sample Size Crossover ────────────────────────────────

# Pull accuracies from attempt 6 (100 samples) and attempt 7 (200 samples)
ax = axes[1, 1]
sizes    = [100, 200]
q_accs   = [test_acc6, test_acc7]
svm_accs = [svm_acc6,  svm_acc7]

# Plot QSVM vs classical SVM accuracy as a function of training size
# This is the key result: QSVM crosses over and surpasses classical at 200 samples
ax.plot(sizes, q_accs,   "o-", color="#C0392B", linewidth=2.5,
        markersize=10, label="QSVM")
ax.plot(sizes, svm_accs, "s-", color="#1F4E79", linewidth=2.5,
        markersize=10, label="Classical SVM")

# Annotate each point with its numeric accuracy
for s, q, sv in zip(sizes, q_accs, svm_accs):
    ax.annotate(f"{q:.3f}", (s, q),   xytext=(0, 20),  textcoords="offset points",
                fontsize=16, color="#C0392B", fontweight="bold")
    ax.annotate(f"{sv:.3f}", (s, sv), xytext=(0, -20), textcoords="offset points",
                fontsize=16, color="#1F4E79", fontweight="bold")

# Light green band marks the region where QSVM overtakes classical SVM
ax.axvspan(140, 210, alpha=0.07, color="#1A7A4A")

# Tick and axis formatting
ax.tick_params(axis="y", labelsize=14)
ax.set_xticks(sizes, labels=[f"{s} samples" for s in sizes], fontsize=14)
ax.set_xlabel("Training Samples", fontsize=16)
ax.set_ylabel("Test Accuracy", fontsize=16)
ax.set_title("Sample-Size Crossover", fontweight="bold")
ax.set_ylim(0.50, 0.82)
ax.legend(fontsize=14)
ax.grid(True, alpha=0.3)


# Tighten layout, save high-res PNG, and display
plt.tight_layout()
plt.savefig("qsvm_results.png", dpi=150, bbox_inches="tight")
plt.show()
print("Figure saved as qsvm_results.png")
# Out:
# Figure saved as qsvm_results.png

# %% [markdown]
# # Cell 19: Classical SVM Confusion Matrix Side by Side

# %%
# Side-by-side confusion matrices for the final 200-sample comparison
# Left: classical SVM (Blues), Right: QSVM (Oranges)
# Cells show raw counts; color intensity reflects per-class recall (row-normalized)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))
fig.suptitle("Confusion Matrices: QSVM vs Classical SVM (200 Training Samples)",
             fontsize=15, color="#1F4E79")

# Loop over both axes, applying the same formatting to each panel
# Each tuple binds an axis to its confusion matrix, predictions, title, and colormap
for ax, cm, pred, title, cmap in zip(
    [ax1, ax2],
    [cm_s, cm_q],
    [svm_pred7, Y_pred7],
    [f"Classical SVM — Accuracy: {svm_acc7:.3f}", f"QSVM — Accuracy: {test_acc7:.3f}"],
    ["Blues", "Oranges"]
):
    # Row-normalize so colors reflect recall per true class
    # Annotations still show raw counts for transparency
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    # Heatmap with shared color scale [0, 1] so both panels are directly comparable
    sns.heatmap(cm_norm, annot=cm, fmt="d", cmap=cmap,
                xticklabels=class_names, yticklabels=class_names,
                ax=ax, linewidths=0.5, linecolor="white",
                vmin=0, vmax=1,
                annot_kws={"size": 18},
                cbar_kws={"label": "Proportion", "ticks": [0, 0.5, 1],
                          "format": "%.0f%%", "shrink": 0.6, "pad": 0.02})

    # Title and axis labels
    ax.set_title(title, fontsize=16, fontweight="bold")
    ax.set_xlabel("Predicted Label", fontsize=14)
    ax.set_ylabel("True Label", fontsize=14)

    # Larger tick fonts for poster readability
    ax.tick_params(axis="x", labelsize=14)
    ax.tick_params(axis="y", labelsize=14)

    # Tweak the colorbar tick and label sizes to match the rest of the figure
    cbar = ax.collections[0].colorbar
    cbar.ax.tick_params(labelsize=12)
    cbar.ax.yaxis.label.set_size(12)

    # Outline the diagonal in green to highlight correct predictions
    for i in range(3):
        ax.add_patch(plt.Rectangle((i, i), 1, 1, fill=False,
                                    edgecolor="green", linewidth=2.5))

# Tighten layout, save at high DPI for print, and display
plt.tight_layout()
plt.savefig("confusion_matrices.png", dpi=300, bbox_inches="tight")
plt.show()
print("Figure saved as confusion_matrices.png")
# Out:
# Figure saved as confusion_matrices.png

# %% [markdown]
# # Cell 20: Final Summary Print

# %%
# Final comparison table summarizing all three models on the test set

# Header bar and column labels
print("=" * 65)
print(f"{'Model':<22} {'Val Acc':<12} {'Test Acc':<12} {'Test F1'}")
print("=" * 65)

# Row 1: classical SVM baseline (no validation accuracy was tracked)
print(f"{'Classical SVM':<22} {'—':<12} {svm_acc7:<12.3f} {svm_f17:.3f}")

# Row 2: QSVM with 100 training samples (attempt 6, partial success)
print(f"{'QSVM (100 samples)':<22} {val_acc6:<12.3f} {test_acc6:<12.3f} {test_f16:.3f}")

# Row 3: QSVM with 200 training samples (attempt 7, headline result)
print(f"{'QSVM (200 samples)':<22} {val_acc7:<12.3f} {test_acc7:<12.3f} {test_f17:.3f}")
print("=" * 65)

# Highlight the QSVM advantage at 200 samples in absolute terms
print(f"\nQSVM gain over Classical SVM (200 samples):")
print(f"  Accuracy : +{test_acc7 - svm_acc7:.3f}")
print(f"  F1 Score : +{test_f17  - svm_f17:.3f}")

# Print the full attempt log so the final table appears alongside the summary
show_summary()
# Out:
# =================================================================
# Model                  Val Acc      Test Acc     Test F1
# =================================================================
# Classical SVM          —            0.720        0.723
# QSVM (100 samples)     0.675        0.583        0.579
# QSVM (200 samples)     0.800        0.730        0.726
# =================================================================
#
# QSVM gain over Classical SVM (200 samples):
#   Accuracy : +0.010
#   F1 Score : +0.003
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9535. Gap: 0.0465. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0622 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700.             |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 7  |QSVM ZZ Kernel  |Increased training subset to 200  |QSVM test acc: 0.730, F1: 0.726.  |✓ Success |
# |    |Fixed Adjoint   |samples. 200x200 kernel matrix =  |SVM test acc: 0.720, F1: 0.723.   |          |
# |    |200 samples     |40,000 circuit evaluations.       |QSVM wins on every metric.        |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 21: Build kernel matrices for 300 samples

# %%
# Scale up to 300 training samples for attempt 8
# Total = 300*300 + 80*300 + 140*300 = 156,000 kernel evaluations
# Expect 60-90 min on a laptop CPU
N_tr3, N_v3, N_te3 = 300, 80, 140

# Slice matching feature and label subsets
X_tr3 = X_train[:N_tr3];  Y_tr3 = Y_train[:N_tr3]
X_v3  = X_val[:N_v3];     Y_v3  = Y_val[:N_v3]
X_te3 = X_test[:N_te3];   Y_te3 = Y_test[:N_te3]

# Build train (square), val and test (rectangular) kernel matrices
print("Building kernel matrices (300 samples) — this takes ~60-90 min ...")
K_train_300 = build_kernel_matrix(X_tr3, X_tr3, quantum_kernel, "TRAIN-300")
K_val_300   = build_kernel_matrix(X_v3,  X_tr3, quantum_kernel, "VAL-300")
K_test_300  = build_kernel_matrix(X_te3, X_tr3, quantum_kernel, "TEST-300")
print("Done.")
# Out:
# Building kernel matrices (300 samples) — this takes ~60-90 min ...
#   [TRAIN-300] 100/90000 | 1s elapsed | ETA 781s
#   [TRAIN-300] 200/90000 | 2s elapsed | ETA 731s
#   [TRAIN-300] 300/90000 | 2s elapsed | ETA 708s
#   [TRAIN-300] 400/90000 | 3s elapsed | ETA 695s
#   [TRAIN-300] 500/90000 | 4s elapsed | ETA 687s
#   [TRAIN-300] 600/90000 | 5s elapsed | ETA 758s
#   [TRAIN-300] 700/90000 | 6s elapsed | ETA 755s
#   [TRAIN-300] 800/90000 | 7s elapsed | ETA 742s
#   [TRAIN-300] 900/90000 | 7s elapsed | ETA 734s
#   [TRAIN-300] 1000/90000 | 8s elapsed | ETA 725s
#   [TRAIN-300] 1100/90000 | 9s elapsed | ETA 723s
#   [TRAIN-300] 1200/90000 | 10s elapsed | ETA 716s
#   [TRAIN-300] 1300/90000 | 10s elapsed | ETA 710s
#   [TRAIN-300] 1400/90000 | 11s elapsed | ETA 705s
#   [TRAIN-300] 1500/90000 | 12s elapsed | ETA 700s
#   [TRAIN-300] 1600/90000 | 13s elapsed | ETA 697s
#   [TRAIN-300] 1700/90000 | 13s elapsed | ETA 693s
#   [TRAIN-300] 1800/90000 | 14s elapsed | ETA 690s
#   [TRAIN-300] 1900/90000 | 15s elapsed | ETA 686s
#   [TRAIN-300] 2000/90000 | 16s elapsed | ETA 684s
#   [TRAIN-300] 2100/90000 | 16s elapsed | ETA 681s
#   [TRAIN-300] 2200/90000 | 17s elapsed | ETA 679s
#   [TRAIN-300] 2300/90000 | 18s elapsed | ETA 678s
#   [TRAIN-300] 2400/90000 | 19s elapsed | ETA 676s
#   [TRAIN-300] 2500/90000 | 19s elapsed | ETA 673s
#   [TRAIN-300] 2600/90000 | 20s elapsed | ETA 671s
#   [TRAIN-300] 2700/90000 | 21s elapsed | ETA 671s
#   [TRAIN-300] 2800/90000 | 21s elapsed | ETA 669s
#   [TRAIN-300] 2900/90000 | 22s elapsed | ETA 668s
#   [TRAIN-300] 3000/90000 | 23s elapsed | ETA 666s
#   [TRAIN-300] 3100/90000 | 24s elapsed | ETA 665s
#   [TRAIN-300] 3200/90000 | 24s elapsed | ETA 663s
#   [TRAIN-300] 3300/90000 | 25s elapsed | ETA 661s
#   [TRAIN-300] 3400/90000 | 26s elapsed | ETA 660s
#   [TRAIN-300] 3500/90000 | 27s elapsed | ETA 659s
#   [TRAIN-300] 3600/90000 | 27s elapsed | ETA 657s
#   [TRAIN-300] 3700/90000 | 28s elapsed | ETA 656s
#   [TRAIN-300] 3800/90000 | 29s elapsed | ETA 655s
#   [TRAIN-300] 3900/90000 | 30s elapsed | ETA 653s
#   [TRAIN-300] 4000/90000 | 30s elapsed | ETA 652s
#   [TRAIN-300] 4100/90000 | 31s elapsed | ETA 651s
#   [TRAIN-300] 4200/90000 | 32s elapsed | ETA 649s
#   [TRAIN-300] 4300/90000 | 33s elapsed | ETA 648s
#   [TRAIN-300] 4400/90000 | 33s elapsed | ETA 647s
#   [TRAIN-300] 4500/90000 | 34s elapsed | ETA 646s
#   [TRAIN-300] 4600/90000 | 35s elapsed | ETA 648s
#   [TRAIN-300] 4700/90000 | 36s elapsed | ETA 646s
#   [TRAIN-300] 4800/90000 | 36s elapsed | ETA 646s
#   [TRAIN-300] 4900/90000 | 37s elapsed | ETA 645s
#   [TRAIN-300] 5000/90000 | 38s elapsed | ETA 644s
#   [TRAIN-300] 5100/90000 | 39s elapsed | ETA 643s
#   [TRAIN-300] 5200/90000 | 39s elapsed | ETA 642s
#   [TRAIN-300] 5300/90000 | 40s elapsed | ETA 640s
#   [TRAIN-300] 5400/90000 | 41s elapsed | ETA 639s
#   [TRAIN-300] 5500/90000 | 42s elapsed | ETA 638s
#   [TRAIN-300] 5600/90000 | 42s elapsed | ETA 637s
#   [TRAIN-300] 5700/90000 | 43s elapsed | ETA 636s
#   [TRAIN-300] 5800/90000 | 44s elapsed | ETA 635s
#   [TRAIN-300] 5900/90000 | 44s elapsed | ETA 634s
#   [TRAIN-300] 6000/90000 | 45s elapsed | ETA 633s
#   [TRAIN-300] 6100/90000 | 46s elapsed | ETA 632s
#   [TRAIN-300] 6200/90000 | 47s elapsed | ETA 631s
#   [TRAIN-300] 6300/90000 | 47s elapsed | ETA 630s
#   [TRAIN-300] 6400/90000 | 48s elapsed | ETA 629s
#   [TRAIN-300] 6500/90000 | 49s elapsed | ETA 629s
#   [TRAIN-300] 6600/90000 | 50s elapsed | ETA 628s
#   [TRAIN-300] 6700/90000 | 50s elapsed | ETA 627s
#   [TRAIN-300] 6800/90000 | 51s elapsed | ETA 626s
#   [TRAIN-300] 6900/90000 | 52s elapsed | ETA 625s
#   [TRAIN-300] 7000/90000 | 53s elapsed | ETA 624s
#   [TRAIN-300] 7100/90000 | 53s elapsed | ETA 624s
#   [TRAIN-300] 7200/90000 | 54s elapsed | ETA 623s
#   [TRAIN-300] 7300/90000 | 55s elapsed | ETA 622s
#   [TRAIN-300] 7400/90000 | 56s elapsed | ETA 621s
#   [TRAIN-300] 7500/90000 | 56s elapsed | ETA 620s
#   [TRAIN-300] 7600/90000 | 57s elapsed | ETA 619s
#   [TRAIN-300] 7700/90000 | 58s elapsed | ETA 618s
#   [TRAIN-300] 7800/90000 | 59s elapsed | ETA 617s
#   [TRAIN-300] 7900/90000 | 59s elapsed | ETA 616s
#   [TRAIN-300] 8000/90000 | 60s elapsed | ETA 615s
#   [TRAIN-300] 8100/90000 | 61s elapsed | ETA 614s
#   [TRAIN-300] 8200/90000 | 61s elapsed | ETA 613s
#   [TRAIN-300] 8300/90000 | 62s elapsed | ETA 612s
#   [TRAIN-300] 8400/90000 | 63s elapsed | ETA 612s
#   [TRAIN-300] 8500/90000 | 64s elapsed | ETA 611s
#   [TRAIN-300] 8600/90000 | 64s elapsed | ETA 610s
#   [TRAIN-300] 8700/90000 | 65s elapsed | ETA 609s
#   [TRAIN-300] 8800/90000 | 66s elapsed | ETA 608s
#   [TRAIN-300] 8900/90000 | 67s elapsed | ETA 607s
#   [TRAIN-300] 9000/90000 | 67s elapsed | ETA 606s
#   [TRAIN-300] 9100/90000 | 68s elapsed | ETA 605s
#   [TRAIN-300] 9200/90000 | 69s elapsed | ETA 606s
#   [TRAIN-300] 9300/90000 | 70s elapsed | ETA 606s
#   [TRAIN-300] 9400/90000 | 71s elapsed | ETA 605s
#   [TRAIN-300] 9500/90000 | 71s elapsed | ETA 604s
#   [TRAIN-300] 9600/90000 | 72s elapsed | ETA 603s
#   [TRAIN-300] 9700/90000 | 73s elapsed | ETA 602s
#   [TRAIN-300] 9800/90000 | 73s elapsed | ETA 601s
#   [TRAIN-300] 9900/90000 | 74s elapsed | ETA 600s
#   [TRAIN-300] 10000/90000 | 75s elapsed | ETA 599s
#   [TRAIN-300] 10100/90000 | 76s elapsed | ETA 599s
#   [TRAIN-300] 10200/90000 | 76s elapsed | ETA 598s
#   [TRAIN-300] 10300/90000 | 77s elapsed | ETA 597s
#   [TRAIN-300] 10400/90000 | 78s elapsed | ETA 596s
#   [TRAIN-300] 10500/90000 | 79s elapsed | ETA 595s
#   [TRAIN-300] 10600/90000 | 79s elapsed | ETA 594s
#   [TRAIN-300] 10700/90000 | 80s elapsed | ETA 594s
#   [TRAIN-300] 10800/90000 | 81s elapsed | ETA 593s
#   [TRAIN-300] 10900/90000 | 82s elapsed | ETA 592s
#   [TRAIN-300] 11000/90000 | 82s elapsed | ETA 591s
#   [TRAIN-300] 11100/90000 | 83s elapsed | ETA 590s
#   [TRAIN-300] 11200/90000 | 84s elapsed | ETA 589s
#   [TRAIN-300] 11300/90000 | 85s elapsed | ETA 589s
#   [TRAIN-300] 11400/90000 | 85s elapsed | ETA 588s
#   [TRAIN-300] 11500/90000 | 86s elapsed | ETA 587s
#   [TRAIN-300] 11600/90000 | 87s elapsed | ETA 586s
#   [TRAIN-300] 11700/90000 | 88s elapsed | ETA 586s
#   [TRAIN-300] 11800/90000 | 88s elapsed | ETA 585s
#   [TRAIN-300] 11900/90000 | 89s elapsed | ETA 584s
#   [TRAIN-300] 12000/90000 | 90s elapsed | ETA 583s
#   [TRAIN-300] 12100/90000 | 90s elapsed | ETA 582s
#   [TRAIN-300] 12200/90000 | 91s elapsed | ETA 581s
#   [TRAIN-300] 12300/90000 | 92s elapsed | ETA 581s
#   [TRAIN-300] 12400/90000 | 93s elapsed | ETA 580s
#   [TRAIN-300] 12500/90000 | 93s elapsed | ETA 579s
#   [TRAIN-300] 12600/90000 | 94s elapsed | ETA 578s
#   [TRAIN-300] 12700/90000 | 95s elapsed | ETA 577s
#   [TRAIN-300] 12800/90000 | 96s elapsed | ETA 576s
#   [TRAIN-300] 12900/90000 | 96s elapsed | ETA 576s
#   [TRAIN-300] 13000/90000 | 97s elapsed | ETA 575s
#   [TRAIN-300] 13100/90000 | 98s elapsed | ETA 574s
#   [TRAIN-300] 13200/90000 | 99s elapsed | ETA 573s
#   [TRAIN-300] 13300/90000 | 99s elapsed | ETA 572s
#   [TRAIN-300] 13400/90000 | 100s elapsed | ETA 572s
#   [TRAIN-300] 13500/90000 | 101s elapsed | ETA 571s
#   [TRAIN-300] 13600/90000 | 102s elapsed | ETA 570s
#   [TRAIN-300] 13700/90000 | 102s elapsed | ETA 570s
#   [TRAIN-300] 13800/90000 | 103s elapsed | ETA 569s
#   [TRAIN-300] 13900/90000 | 104s elapsed | ETA 568s
#   [TRAIN-300] 14000/90000 | 105s elapsed | ETA 568s
#   [TRAIN-300] 14100/90000 | 105s elapsed | ETA 567s
#   [TRAIN-300] 14200/90000 | 106s elapsed | ETA 566s
#   [TRAIN-300] 14300/90000 | 107s elapsed | ETA 565s
#   [TRAIN-300] 14400/90000 | 108s elapsed | ETA 565s
#   [TRAIN-300] 14500/90000 | 108s elapsed | ETA 564s
#   [TRAIN-300] 14600/90000 | 109s elapsed | ETA 563s
#   [TRAIN-300] 14700/90000 | 110s elapsed | ETA 562s
#   [TRAIN-300] 14800/90000 | 110s elapsed | ETA 561s
#   [TRAIN-300] 14900/90000 | 111s elapsed | ETA 560s
#   [TRAIN-300] 15000/90000 | 112s elapsed | ETA 560s
#   [TRAIN-300] 15100/90000 | 113s elapsed | ETA 559s
#   [TRAIN-300] 15200/90000 | 113s elapsed | ETA 558s
#   [TRAIN-300] 15300/90000 | 114s elapsed | ETA 557s
#   [TRAIN-300] 15400/90000 | 115s elapsed | ETA 556s
#   [TRAIN-300] 15500/90000 | 116s elapsed | ETA 556s
#   [TRAIN-300] 15600/90000 | 116s elapsed | ETA 555s
#   [TRAIN-300] 15700/90000 | 117s elapsed | ETA 554s
#   [TRAIN-300] 15800/90000 | 118s elapsed | ETA 554s
#   [TRAIN-300] 15900/90000 | 119s elapsed | ETA 553s
#   [TRAIN-300] 16000/90000 | 119s elapsed | ETA 552s
#   [TRAIN-300] 16100/90000 | 120s elapsed | ETA 551s
#   [TRAIN-300] 16200/90000 | 121s elapsed | ETA 550s
#   [TRAIN-300] 16300/90000 | 122s elapsed | ETA 550s
#   [TRAIN-300] 16400/90000 | 122s elapsed | ETA 549s
#   [TRAIN-300] 16500/90000 | 123s elapsed | ETA 548s
#   [TRAIN-300] 16600/90000 | 124s elapsed | ETA 547s
#   [TRAIN-300] 16700/90000 | 124s elapsed | ETA 546s
#   [TRAIN-300] 16800/90000 | 125s elapsed | ETA 546s
#   [TRAIN-300] 16900/90000 | 126s elapsed | ETA 545s
#   [TRAIN-300] 17000/90000 | 127s elapsed | ETA 544s
#   [TRAIN-300] 17100/90000 | 127s elapsed | ETA 543s
#   [TRAIN-300] 17200/90000 | 128s elapsed | ETA 542s
#   [TRAIN-300] 17300/90000 | 129s elapsed | ETA 542s
#   [TRAIN-300] 17400/90000 | 130s elapsed | ETA 541s
#   [TRAIN-300] 17500/90000 | 130s elapsed | ETA 540s
#   [TRAIN-300] 17600/90000 | 131s elapsed | ETA 539s
#   [TRAIN-300] 17700/90000 | 132s elapsed | ETA 538s
#   [TRAIN-300] 17800/90000 | 133s elapsed | ETA 538s
#   [TRAIN-300] 17900/90000 | 133s elapsed | ETA 537s
#   [TRAIN-300] 18000/90000 | 134s elapsed | ETA 537s
#   [TRAIN-300] 18100/90000 | 135s elapsed | ETA 536s
#   [TRAIN-300] 18200/90000 | 136s elapsed | ETA 535s
#   [TRAIN-300] 18300/90000 | 136s elapsed | ETA 535s
#   [TRAIN-300] 18400/90000 | 137s elapsed | ETA 534s
#   [TRAIN-300] 18500/90000 | 138s elapsed | ETA 534s
#   [TRAIN-300] 18600/90000 | 139s elapsed | ETA 533s
#   [TRAIN-300] 18700/90000 | 140s elapsed | ETA 532s
#   [TRAIN-300] 18800/90000 | 140s elapsed | ETA 532s
#   [TRAIN-300] 18900/90000 | 141s elapsed | ETA 531s
#   [TRAIN-300] 19000/90000 | 142s elapsed | ETA 530s
#   [TRAIN-300] 19100/90000 | 143s elapsed | ETA 529s
#   [TRAIN-300] 19200/90000 | 143s elapsed | ETA 528s
#   [TRAIN-300] 19300/90000 | 144s elapsed | ETA 528s
#   [TRAIN-300] 19400/90000 | 145s elapsed | ETA 527s
#   [TRAIN-300] 19500/90000 | 145s elapsed | ETA 526s
#   [TRAIN-300] 19600/90000 | 146s elapsed | ETA 525s
#   [TRAIN-300] 19700/90000 | 147s elapsed | ETA 524s
#   [TRAIN-300] 19800/90000 | 148s elapsed | ETA 524s
#   [TRAIN-300] 19900/90000 | 148s elapsed | ETA 523s
#   [TRAIN-300] 20000/90000 | 149s elapsed | ETA 522s
#   [TRAIN-300] 20100/90000 | 150s elapsed | ETA 521s
#   [TRAIN-300] 20200/90000 | 151s elapsed | ETA 521s
#   [TRAIN-300] 20300/90000 | 151s elapsed | ETA 520s
#   [TRAIN-300] 20400/90000 | 152s elapsed | ETA 519s
#   [TRAIN-300] 20500/90000 | 153s elapsed | ETA 518s
#   [TRAIN-300] 20600/90000 | 154s elapsed | ETA 518s
#   [TRAIN-300] 20700/90000 | 154s elapsed | ETA 517s
#   [TRAIN-300] 20800/90000 | 155s elapsed | ETA 516s
#   [TRAIN-300] 20900/90000 | 156s elapsed | ETA 515s
#   [TRAIN-300] 21000/90000 | 157s elapsed | ETA 514s
#   [TRAIN-300] 21100/90000 | 157s elapsed | ETA 514s
#   [TRAIN-300] 21200/90000 | 158s elapsed | ETA 513s
#   [TRAIN-300] 21300/90000 | 159s elapsed | ETA 512s
#   [TRAIN-300] 21400/90000 | 159s elapsed | ETA 511s
#   [TRAIN-300] 21500/90000 | 160s elapsed | ETA 510s
#   [TRAIN-300] 21600/90000 | 161s elapsed | ETA 510s
#   [TRAIN-300] 21700/90000 | 162s elapsed | ETA 509s
#   [TRAIN-300] 21800/90000 | 162s elapsed | ETA 508s
#   [TRAIN-300] 21900/90000 | 163s elapsed | ETA 507s
#   [TRAIN-300] 22000/90000 | 164s elapsed | ETA 506s
#   [TRAIN-300] 22100/90000 | 165s elapsed | ETA 506s
#   [TRAIN-300] 22200/90000 | 165s elapsed | ETA 505s
#   [TRAIN-300] 22300/90000 | 166s elapsed | ETA 504s
#   [TRAIN-300] 22400/90000 | 167s elapsed | ETA 504s
#   [TRAIN-300] 22500/90000 | 168s elapsed | ETA 503s
#   [TRAIN-300] 22600/90000 | 168s elapsed | ETA 502s
#   [TRAIN-300] 22700/90000 | 169s elapsed | ETA 501s
#   [TRAIN-300] 22800/90000 | 170s elapsed | ETA 501s
#   [TRAIN-300] 22900/90000 | 171s elapsed | ETA 500s
#   [TRAIN-300] 23000/90000 | 171s elapsed | ETA 499s
#   [TRAIN-300] 23100/90000 | 172s elapsed | ETA 498s
#   [TRAIN-300] 23200/90000 | 173s elapsed | ETA 498s
#   [TRAIN-300] 23300/90000 | 174s elapsed | ETA 497s
#   [TRAIN-300] 23400/90000 | 174s elapsed | ETA 496s
#   [TRAIN-300] 23500/90000 | 175s elapsed | ETA 495s
#   [TRAIN-300] 23600/90000 | 176s elapsed | ETA 495s
#   [TRAIN-300] 23700/90000 | 177s elapsed | ETA 494s
#   [TRAIN-300] 23800/90000 | 177s elapsed | ETA 493s
#   [TRAIN-300] 23900/90000 | 178s elapsed | ETA 492s
#   [TRAIN-300] 24000/90000 | 179s elapsed | ETA 491s
#   [TRAIN-300] 24100/90000 | 179s elapsed | ETA 491s
#   [TRAIN-300] 24200/90000 | 180s elapsed | ETA 490s
#   [TRAIN-300] 24300/90000 | 181s elapsed | ETA 489s
#   [TRAIN-300] 24400/90000 | 182s elapsed | ETA 488s
#   [TRAIN-300] 24500/90000 | 182s elapsed | ETA 488s
#   [TRAIN-300] 24600/90000 | 183s elapsed | ETA 487s
#   [TRAIN-300] 24700/90000 | 184s elapsed | ETA 486s
#   [TRAIN-300] 24800/90000 | 185s elapsed | ETA 485s
#   [TRAIN-300] 24900/90000 | 185s elapsed | ETA 485s
#   [TRAIN-300] 25000/90000 | 186s elapsed | ETA 484s
#   [TRAIN-300] 25100/90000 | 187s elapsed | ETA 483s
#   [TRAIN-300] 25200/90000 | 188s elapsed | ETA 482s
#   [TRAIN-300] 25300/90000 | 188s elapsed | ETA 482s
#   [TRAIN-300] 25400/90000 | 189s elapsed | ETA 481s
#   [TRAIN-300] 25500/90000 | 190s elapsed | ETA 480s
#   [TRAIN-300] 25600/90000 | 191s elapsed | ETA 479s
#   [TRAIN-300] 25700/90000 | 191s elapsed | ETA 478s
#   [TRAIN-300] 25800/90000 | 192s elapsed | ETA 478s
#   [TRAIN-300] 25900/90000 | 193s elapsed | ETA 477s
#   [TRAIN-300] 26000/90000 | 194s elapsed | ETA 476s
#   [TRAIN-300] 26100/90000 | 194s elapsed | ETA 476s
#   [TRAIN-300] 26200/90000 | 195s elapsed | ETA 475s
#   [TRAIN-300] 26300/90000 | 196s elapsed | ETA 474s
#   [TRAIN-300] 26400/90000 | 197s elapsed | ETA 473s
#   [TRAIN-300] 26500/90000 | 197s elapsed | ETA 473s
#   [TRAIN-300] 26600/90000 | 198s elapsed | ETA 472s
#   [TRAIN-300] 26700/90000 | 199s elapsed | ETA 471s
#   [TRAIN-300] 26800/90000 | 200s elapsed | ETA 470s
#   [TRAIN-300] 26900/90000 | 200s elapsed | ETA 470s
#   [TRAIN-300] 27000/90000 | 201s elapsed | ETA 469s
#   [TRAIN-300] 27100/90000 | 202s elapsed | ETA 468s
#   [TRAIN-300] 27200/90000 | 202s elapsed | ETA 467s
#   [TRAIN-300] 27300/90000 | 203s elapsed | ETA 467s
#   [TRAIN-300] 27400/90000 | 204s elapsed | ETA 466s
#   [TRAIN-300] 27500/90000 | 205s elapsed | ETA 465s
#   [TRAIN-300] 27600/90000 | 206s elapsed | ETA 465s
#   [TRAIN-300] 27700/90000 | 206s elapsed | ETA 464s
#   [TRAIN-300] 27800/90000 | 207s elapsed | ETA 463s
#   [TRAIN-300] 27900/90000 | 208s elapsed | ETA 462s
#   [TRAIN-300] 28000/90000 | 208s elapsed | ETA 462s
#   [TRAIN-300] 28100/90000 | 209s elapsed | ETA 461s
#   [TRAIN-300] 28200/90000 | 210s elapsed | ETA 460s
#   [TRAIN-300] 28300/90000 | 211s elapsed | ETA 459s
#   [TRAIN-300] 28400/90000 | 211s elapsed | ETA 458s
#   [TRAIN-300] 28500/90000 | 212s elapsed | ETA 458s
#   [TRAIN-300] 28600/90000 | 213s elapsed | ETA 457s
#   [TRAIN-300] 28700/90000 | 214s elapsed | ETA 456s
#   [TRAIN-300] 28800/90000 | 214s elapsed | ETA 456s
#   [TRAIN-300] 28900/90000 | 215s elapsed | ETA 455s
#   [TRAIN-300] 29000/90000 | 216s elapsed | ETA 454s
#   [TRAIN-300] 29100/90000 | 217s elapsed | ETA 453s
#   [TRAIN-300] 29200/90000 | 217s elapsed | ETA 453s
#   [TRAIN-300] 29300/90000 | 218s elapsed | ETA 452s
#   [TRAIN-300] 29400/90000 | 219s elapsed | ETA 451s
#   [TRAIN-300] 29500/90000 | 220s elapsed | ETA 450s
#   [TRAIN-300] 29600/90000 | 220s elapsed | ETA 449s
#   [TRAIN-300] 29700/90000 | 221s elapsed | ETA 449s
#   [TRAIN-300] 29800/90000 | 222s elapsed | ETA 448s
#   [TRAIN-300] 29900/90000 | 222s elapsed | ETA 447s
#   [TRAIN-300] 30000/90000 | 223s elapsed | ETA 446s
#   [TRAIN-300] 30100/90000 | 224s elapsed | ETA 446s
#   [TRAIN-300] 30200/90000 | 225s elapsed | ETA 445s
#   [TRAIN-300] 30300/90000 | 225s elapsed | ETA 444s
#   [TRAIN-300] 30400/90000 | 226s elapsed | ETA 443s
#   [TRAIN-300] 30500/90000 | 227s elapsed | ETA 443s
#   [TRAIN-300] 30600/90000 | 228s elapsed | ETA 442s
#   [TRAIN-300] 30700/90000 | 228s elapsed | ETA 441s
#   [TRAIN-300] 30800/90000 | 229s elapsed | ETA 440s
#   [TRAIN-300] 30900/90000 | 230s elapsed | ETA 440s
#   [TRAIN-300] 31000/90000 | 231s elapsed | ETA 439s
#   [TRAIN-300] 31100/90000 | 231s elapsed | ETA 438s
#   [TRAIN-300] 31200/90000 | 232s elapsed | ETA 437s
#   [TRAIN-300] 31300/90000 | 233s elapsed | ETA 436s
#   [TRAIN-300] 31400/90000 | 233s elapsed | ETA 436s
#   [TRAIN-300] 31500/90000 | 234s elapsed | ETA 435s
#   [TRAIN-300] 31600/90000 | 235s elapsed | ETA 434s
#   [TRAIN-300] 31700/90000 | 236s elapsed | ETA 433s
#   [TRAIN-300] 31800/90000 | 236s elapsed | ETA 433s
#   [TRAIN-300] 31900/90000 | 237s elapsed | ETA 432s
#   [TRAIN-300] 32000/90000 | 238s elapsed | ETA 431s
#   [TRAIN-300] 32100/90000 | 239s elapsed | ETA 431s
#   [TRAIN-300] 32200/90000 | 239s elapsed | ETA 430s
#   [TRAIN-300] 32300/90000 | 240s elapsed | ETA 429s
#   [TRAIN-300] 32400/90000 | 241s elapsed | ETA 428s
#   [TRAIN-300] 32500/90000 | 242s elapsed | ETA 428s
#   [TRAIN-300] 32600/90000 | 242s elapsed | ETA 427s
#   [TRAIN-300] 32700/90000 | 243s elapsed | ETA 426s
#   [TRAIN-300] 32800/90000 | 244s elapsed | ETA 425s
#   [TRAIN-300] 32900/90000 | 245s elapsed | ETA 425s
#   [TRAIN-300] 33000/90000 | 245s elapsed | ETA 424s
#   [TRAIN-300] 33100/90000 | 246s elapsed | ETA 423s
#   [TRAIN-300] 33200/90000 | 247s elapsed | ETA 422s
#   [TRAIN-300] 33300/90000 | 248s elapsed | ETA 422s
#   [TRAIN-300] 33400/90000 | 248s elapsed | ETA 421s
#   [TRAIN-300] 33500/90000 | 249s elapsed | ETA 420s
#   [TRAIN-300] 33600/90000 | 250s elapsed | ETA 419s
#   [TRAIN-300] 33700/90000 | 251s elapsed | ETA 419s
#   [TRAIN-300] 33800/90000 | 251s elapsed | ETA 418s
#   [TRAIN-300] 33900/90000 | 252s elapsed | ETA 417s
#   [TRAIN-300] 34000/90000 | 253s elapsed | ETA 416s
#   [TRAIN-300] 34100/90000 | 253s elapsed | ETA 416s
#   [TRAIN-300] 34200/90000 | 254s elapsed | ETA 415s
#   [TRAIN-300] 34300/90000 | 255s elapsed | ETA 414s
#   [TRAIN-300] 34400/90000 | 256s elapsed | ETA 413s
#   [TRAIN-300] 34500/90000 | 256s elapsed | ETA 412s
#   [TRAIN-300] 34600/90000 | 257s elapsed | ETA 412s
#   [TRAIN-300] 34700/90000 | 258s elapsed | ETA 411s
#   [TRAIN-300] 34800/90000 | 259s elapsed | ETA 410s
#   [TRAIN-300] 34900/90000 | 259s elapsed | ETA 409s
#   [TRAIN-300] 35000/90000 | 260s elapsed | ETA 409s
#   [TRAIN-300] 35100/90000 | 261s elapsed | ETA 408s
#   [TRAIN-300] 35200/90000 | 262s elapsed | ETA 407s
#   [TRAIN-300] 35300/90000 | 262s elapsed | ETA 406s
#   [TRAIN-300] 35400/90000 | 263s elapsed | ETA 406s
#   [TRAIN-300] 35500/90000 | 264s elapsed | ETA 405s
#   [TRAIN-300] 35600/90000 | 265s elapsed | ETA 404s
#   [TRAIN-300] 35700/90000 | 265s elapsed | ETA 403s
#   [TRAIN-300] 35800/90000 | 266s elapsed | ETA 403s
#   [TRAIN-300] 35900/90000 | 267s elapsed | ETA 402s
#   [TRAIN-300] 36000/90000 | 267s elapsed | ETA 401s
#   [TRAIN-300] 36100/90000 | 268s elapsed | ETA 400s
#   [TRAIN-300] 36200/90000 | 269s elapsed | ETA 400s
#   [TRAIN-300] 36300/90000 | 270s elapsed | ETA 399s
#   [TRAIN-300] 36400/90000 | 270s elapsed | ETA 398s
#   [TRAIN-300] 36500/90000 | 271s elapsed | ETA 397s
#   [TRAIN-300] 36600/90000 | 272s elapsed | ETA 397s
#   [TRAIN-300] 36700/90000 | 273s elapsed | ETA 396s
#   [TRAIN-300] 36800/90000 | 273s elapsed | ETA 395s
#   [TRAIN-300] 36900/90000 | 274s elapsed | ETA 395s
#   [TRAIN-300] 37000/90000 | 275s elapsed | ETA 394s
#   [TRAIN-300] 37100/90000 | 276s elapsed | ETA 393s
#   [TRAIN-300] 37200/90000 | 276s elapsed | ETA 392s
#   [TRAIN-300] 37300/90000 | 277s elapsed | ETA 392s
#   [TRAIN-300] 37400/90000 | 278s elapsed | ETA 391s
#   [TRAIN-300] 37500/90000 | 279s elapsed | ETA 390s
#   [TRAIN-300] 37600/90000 | 279s elapsed | ETA 389s
#   [TRAIN-300] 37700/90000 | 280s elapsed | ETA 389s
#   [TRAIN-300] 37800/90000 | 281s elapsed | ETA 388s
#   [TRAIN-300] 37900/90000 | 282s elapsed | ETA 387s
#   [TRAIN-300] 38000/90000 | 282s elapsed | ETA 386s
#   [TRAIN-300] 38100/90000 | 283s elapsed | ETA 385s
#   [TRAIN-300] 38200/90000 | 284s elapsed | ETA 385s
#   [TRAIN-300] 38300/90000 | 284s elapsed | ETA 384s
#   [TRAIN-300] 38400/90000 | 285s elapsed | ETA 383s
#   [TRAIN-300] 38500/90000 | 286s elapsed | ETA 382s
#   [TRAIN-300] 38600/90000 | 287s elapsed | ETA 382s
#   [TRAIN-300] 38700/90000 | 287s elapsed | ETA 381s
#   [TRAIN-300] 38800/90000 | 288s elapsed | ETA 380s
#   [TRAIN-300] 38900/90000 | 289s elapsed | ETA 379s
#   [TRAIN-300] 39000/90000 | 290s elapsed | ETA 379s
#   [TRAIN-300] 39100/90000 | 290s elapsed | ETA 378s
#   [TRAIN-300] 39200/90000 | 291s elapsed | ETA 377s
#   [TRAIN-300] 39300/90000 | 292s elapsed | ETA 376s
#   [TRAIN-300] 39400/90000 | 293s elapsed | ETA 376s
#   [TRAIN-300] 39500/90000 | 293s elapsed | ETA 375s
#   [TRAIN-300] 39600/90000 | 294s elapsed | ETA 374s
#   [TRAIN-300] 39700/90000 | 295s elapsed | ETA 373s
#   [TRAIN-300] 39800/90000 | 295s elapsed | ETA 373s
#   [TRAIN-300] 39900/90000 | 296s elapsed | ETA 372s
#   [TRAIN-300] 40000/90000 | 297s elapsed | ETA 371s
#   [TRAIN-300] 40100/90000 | 298s elapsed | ETA 370s
#   [TRAIN-300] 40200/90000 | 298s elapsed | ETA 370s
#   [TRAIN-300] 40300/90000 | 299s elapsed | ETA 369s
#   [TRAIN-300] 40400/90000 | 300s elapsed | ETA 368s
#   [TRAIN-300] 40500/90000 | 301s elapsed | ETA 367s
#   [TRAIN-300] 40600/90000 | 301s elapsed | ETA 367s
#   [TRAIN-300] 40700/90000 | 302s elapsed | ETA 366s
#   [TRAIN-300] 40800/90000 | 303s elapsed | ETA 365s
#   [TRAIN-300] 40900/90000 | 304s elapsed | ETA 364s
#   [TRAIN-300] 41000/90000 | 304s elapsed | ETA 364s
#   [TRAIN-300] 41100/90000 | 305s elapsed | ETA 363s
#   [TRAIN-300] 41200/90000 | 306s elapsed | ETA 362s
#   [TRAIN-300] 41300/90000 | 307s elapsed | ETA 361s
#   [TRAIN-300] 41400/90000 | 307s elapsed | ETA 361s
#   [TRAIN-300] 41500/90000 | 308s elapsed | ETA 360s
#   [TRAIN-300] 41600/90000 | 309s elapsed | ETA 359s
#   [TRAIN-300] 41700/90000 | 310s elapsed | ETA 359s
#   [TRAIN-300] 41800/90000 | 310s elapsed | ETA 358s
#   [TRAIN-300] 41900/90000 | 311s elapsed | ETA 357s
#   [TRAIN-300] 42000/90000 | 312s elapsed | ETA 356s
#   [TRAIN-300] 42100/90000 | 312s elapsed | ETA 356s
#   [TRAIN-300] 42200/90000 | 313s elapsed | ETA 355s
#   [TRAIN-300] 42300/90000 | 314s elapsed | ETA 354s
#   [TRAIN-300] 42400/90000 | 315s elapsed | ETA 353s
#   [TRAIN-300] 42500/90000 | 315s elapsed | ETA 352s
#   [TRAIN-300] 42600/90000 | 316s elapsed | ETA 352s
#   [TRAIN-300] 42700/90000 | 317s elapsed | ETA 351s
#   [TRAIN-300] 42800/90000 | 318s elapsed | ETA 350s
#   [TRAIN-300] 42900/90000 | 318s elapsed | ETA 349s
#   [TRAIN-300] 43000/90000 | 319s elapsed | ETA 349s
#   [TRAIN-300] 43100/90000 | 320s elapsed | ETA 348s
#   [TRAIN-300] 43200/90000 | 321s elapsed | ETA 347s
#   [TRAIN-300] 43300/90000 | 321s elapsed | ETA 346s
#   [TRAIN-300] 43400/90000 | 322s elapsed | ETA 346s
#   [TRAIN-300] 43500/90000 | 323s elapsed | ETA 345s
#   [TRAIN-300] 43600/90000 | 323s elapsed | ETA 344s
#   [TRAIN-300] 43700/90000 | 324s elapsed | ETA 343s
#   [TRAIN-300] 43800/90000 | 325s elapsed | ETA 343s
#   [TRAIN-300] 43900/90000 | 326s elapsed | ETA 342s
#   [TRAIN-300] 44000/90000 | 326s elapsed | ETA 341s
#   [TRAIN-300] 44100/90000 | 327s elapsed | ETA 341s
#   [TRAIN-300] 44200/90000 | 328s elapsed | ETA 340s
#   [TRAIN-300] 44300/90000 | 329s elapsed | ETA 339s
#   [TRAIN-300] 44400/90000 | 329s elapsed | ETA 338s
#   [TRAIN-300] 44500/90000 | 330s elapsed | ETA 338s
#   [TRAIN-300] 44600/90000 | 331s elapsed | ETA 337s
#   [TRAIN-300] 44700/90000 | 332s elapsed | ETA 336s
#   [TRAIN-300] 44800/90000 | 332s elapsed | ETA 335s
#   [TRAIN-300] 44900/90000 | 333s elapsed | ETA 335s
#   [TRAIN-300] 45000/90000 | 334s elapsed | ETA 334s
#   [TRAIN-300] 45100/90000 | 335s elapsed | ETA 333s
#   [TRAIN-300] 45200/90000 | 335s elapsed | ETA 332s
#   [TRAIN-300] 45300/90000 | 336s elapsed | ETA 332s
#   [TRAIN-300] 45400/90000 | 337s elapsed | ETA 331s
#   [TRAIN-300] 45500/90000 | 337s elapsed | ETA 330s
#   [TRAIN-300] 45600/90000 | 338s elapsed | ETA 329s
#   [TRAIN-300] 45700/90000 | 339s elapsed | ETA 329s
#   [TRAIN-300] 45800/90000 | 340s elapsed | ETA 328s
#   [TRAIN-300] 45900/90000 | 341s elapsed | ETA 327s
#   [TRAIN-300] 46000/90000 | 341s elapsed | ETA 326s
#   [TRAIN-300] 46100/90000 | 342s elapsed | ETA 326s
#   [TRAIN-300] 46200/90000 | 343s elapsed | ETA 325s
#   [TRAIN-300] 46300/90000 | 344s elapsed | ETA 324s
#   [TRAIN-300] 46400/90000 | 344s elapsed | ETA 323s
#   [TRAIN-300] 46500/90000 | 345s elapsed | ETA 323s
#   [TRAIN-300] 46600/90000 | 346s elapsed | ETA 322s
#   [TRAIN-300] 46700/90000 | 346s elapsed | ETA 321s
#   [TRAIN-300] 46800/90000 | 347s elapsed | ETA 320s
#   [TRAIN-300] 46900/90000 | 348s elapsed | ETA 320s
#   [TRAIN-300] 47000/90000 | 349s elapsed | ETA 319s
#   [TRAIN-300] 47100/90000 | 349s elapsed | ETA 318s
#   [TRAIN-300] 47200/90000 | 350s elapsed | ETA 317s
#   [TRAIN-300] 47300/90000 | 351s elapsed | ETA 317s
#   [TRAIN-300] 47400/90000 | 352s elapsed | ETA 316s
#   [TRAIN-300] 47500/90000 | 352s elapsed | ETA 315s
#   [TRAIN-300] 47600/90000 | 353s elapsed | ETA 314s
#   [TRAIN-300] 47700/90000 | 354s elapsed | ETA 314s
#   [TRAIN-300] 47800/90000 | 354s elapsed | ETA 313s
#   [TRAIN-300] 47900/90000 | 355s elapsed | ETA 312s
#   [TRAIN-300] 48000/90000 | 356s elapsed | ETA 311s
#   [TRAIN-300] 48100/90000 | 357s elapsed | ETA 311s
#   [TRAIN-300] 48200/90000 | 357s elapsed | ETA 310s
#   [TRAIN-300] 48300/90000 | 358s elapsed | ETA 309s
#   [TRAIN-300] 48400/90000 | 359s elapsed | ETA 308s
#   [TRAIN-300] 48500/90000 | 360s elapsed | ETA 308s
#   [TRAIN-300] 48600/90000 | 360s elapsed | ETA 307s
#   [TRAIN-300] 48700/90000 | 361s elapsed | ETA 306s
#   [TRAIN-300] 48800/90000 | 362s elapsed | ETA 305s
#   [TRAIN-300] 48900/90000 | 363s elapsed | ETA 305s
#   [TRAIN-300] 49000/90000 | 363s elapsed | ETA 304s
#   [TRAIN-300] 49100/90000 | 364s elapsed | ETA 303s
#   [TRAIN-300] 49200/90000 | 365s elapsed | ETA 303s
#   [TRAIN-300] 49300/90000 | 366s elapsed | ETA 302s
#   [TRAIN-300] 49400/90000 | 366s elapsed | ETA 301s
#   [TRAIN-300] 49500/90000 | 367s elapsed | ETA 300s
#   [TRAIN-300] 49600/90000 | 368s elapsed | ETA 300s
#   [TRAIN-300] 49700/90000 | 369s elapsed | ETA 299s
#   [TRAIN-300] 49800/90000 | 369s elapsed | ETA 298s
#   [TRAIN-300] 49900/90000 | 370s elapsed | ETA 297s
#   [TRAIN-300] 50000/90000 | 371s elapsed | ETA 297s
#   [TRAIN-300] 50100/90000 | 371s elapsed | ETA 296s
#   [TRAIN-300] 50200/90000 | 372s elapsed | ETA 295s
#   [TRAIN-300] 50300/90000 | 373s elapsed | ETA 295s
#   [TRAIN-300] 50400/90000 | 374s elapsed | ETA 294s
#   [TRAIN-300] 50500/90000 | 375s elapsed | ETA 293s
#   [TRAIN-300] 50600/90000 | 375s elapsed | ETA 292s
#   [TRAIN-300] 50700/90000 | 376s elapsed | ETA 291s
#   [TRAIN-300] 50800/90000 | 377s elapsed | ETA 291s
#   [TRAIN-300] 50900/90000 | 378s elapsed | ETA 290s
#   [TRAIN-300] 51000/90000 | 378s elapsed | ETA 289s
#   [TRAIN-300] 51100/90000 | 379s elapsed | ETA 288s
#   [TRAIN-300] 51200/90000 | 380s elapsed | ETA 288s
#   [TRAIN-300] 51300/90000 | 380s elapsed | ETA 287s
#   [TRAIN-300] 51400/90000 | 381s elapsed | ETA 286s
#   [TRAIN-300] 51500/90000 | 382s elapsed | ETA 285s
#   [TRAIN-300] 51600/90000 | 383s elapsed | ETA 285s
#   [TRAIN-300] 51700/90000 | 383s elapsed | ETA 284s
#   [TRAIN-300] 51800/90000 | 384s elapsed | ETA 283s
#   [TRAIN-300] 51900/90000 | 385s elapsed | ETA 282s
#   [TRAIN-300] 52000/90000 | 386s elapsed | ETA 282s
#   [TRAIN-300] 52100/90000 | 386s elapsed | ETA 281s
#   [TRAIN-300] 52200/90000 | 387s elapsed | ETA 280s
#   [TRAIN-300] 52300/90000 | 388s elapsed | ETA 279s
#   [TRAIN-300] 52400/90000 | 388s elapsed | ETA 279s
#   [TRAIN-300] 52500/90000 | 389s elapsed | ETA 278s
#   [TRAIN-300] 52600/90000 | 390s elapsed | ETA 277s
#   [TRAIN-300] 52700/90000 | 391s elapsed | ETA 277s
#   [TRAIN-300] 52800/90000 | 391s elapsed | ETA 276s
#   [TRAIN-300] 52900/90000 | 392s elapsed | ETA 275s
#   [TRAIN-300] 53000/90000 | 393s elapsed | ETA 274s
#   [TRAIN-300] 53100/90000 | 394s elapsed | ETA 274s
#   [TRAIN-300] 53200/90000 | 394s elapsed | ETA 273s
#   [TRAIN-300] 53300/90000 | 395s elapsed | ETA 272s
#   [TRAIN-300] 53400/90000 | 396s elapsed | ETA 271s
#   [TRAIN-300] 53500/90000 | 397s elapsed | ETA 271s
#   [TRAIN-300] 53600/90000 | 397s elapsed | ETA 270s
#   [TRAIN-300] 53700/90000 | 398s elapsed | ETA 269s
#   [TRAIN-300] 53800/90000 | 399s elapsed | ETA 268s
#   [TRAIN-300] 53900/90000 | 399s elapsed | ETA 268s
#   [TRAIN-300] 54000/90000 | 400s elapsed | ETA 267s
#   [TRAIN-300] 54100/90000 | 401s elapsed | ETA 266s
#   [TRAIN-300] 54200/90000 | 402s elapsed | ETA 265s
#   [TRAIN-300] 54300/90000 | 402s elapsed | ETA 265s
#   [TRAIN-300] 54400/90000 | 403s elapsed | ETA 264s
#   [TRAIN-300] 54500/90000 | 404s elapsed | ETA 263s
#   [TRAIN-300] 54600/90000 | 405s elapsed | ETA 262s
#   [TRAIN-300] 54700/90000 | 405s elapsed | ETA 262s
#   [TRAIN-300] 54800/90000 | 406s elapsed | ETA 261s
#   [TRAIN-300] 54900/90000 | 407s elapsed | ETA 260s
#   [TRAIN-300] 55000/90000 | 408s elapsed | ETA 259s
#   [TRAIN-300] 55100/90000 | 409s elapsed | ETA 259s
#   [TRAIN-300] 55200/90000 | 409s elapsed | ETA 258s
#   [TRAIN-300] 55300/90000 | 410s elapsed | ETA 257s
#   [TRAIN-300] 55400/90000 | 411s elapsed | ETA 256s
#   [TRAIN-300] 55500/90000 | 411s elapsed | ETA 256s
#   [TRAIN-300] 55600/90000 | 412s elapsed | ETA 255s
#   [TRAIN-300] 55700/90000 | 413s elapsed | ETA 254s
#   [TRAIN-300] 55800/90000 | 414s elapsed | ETA 253s
#   [TRAIN-300] 55900/90000 | 414s elapsed | ETA 253s
#   [TRAIN-300] 56000/90000 | 415s elapsed | ETA 252s
#   [TRAIN-300] 56100/90000 | 416s elapsed | ETA 251s
#   [TRAIN-300] 56200/90000 | 417s elapsed | ETA 250s
#   [TRAIN-300] 56300/90000 | 417s elapsed | ETA 250s
#   [TRAIN-300] 56400/90000 | 418s elapsed | ETA 249s
#   [TRAIN-300] 56500/90000 | 419s elapsed | ETA 248s
#   [TRAIN-300] 56600/90000 | 419s elapsed | ETA 248s
#   [TRAIN-300] 56700/90000 | 420s elapsed | ETA 247s
#   [TRAIN-300] 56800/90000 | 421s elapsed | ETA 246s
#   [TRAIN-300] 56900/90000 | 422s elapsed | ETA 245s
#   [TRAIN-300] 57000/90000 | 422s elapsed | ETA 245s
#   [TRAIN-300] 57100/90000 | 423s elapsed | ETA 244s
#   [TRAIN-300] 57200/90000 | 424s elapsed | ETA 243s
#   [TRAIN-300] 57300/90000 | 425s elapsed | ETA 242s
#   [TRAIN-300] 57400/90000 | 425s elapsed | ETA 242s
#   [TRAIN-300] 57500/90000 | 426s elapsed | ETA 241s
#   [TRAIN-300] 57600/90000 | 427s elapsed | ETA 240s
#   [TRAIN-300] 57700/90000 | 428s elapsed | ETA 239s
#   [TRAIN-300] 57800/90000 | 428s elapsed | ETA 239s
#   [TRAIN-300] 57900/90000 | 429s elapsed | ETA 238s
#   [TRAIN-300] 58000/90000 | 430s elapsed | ETA 237s
#   [TRAIN-300] 58100/90000 | 430s elapsed | ETA 236s
#   [TRAIN-300] 58200/90000 | 431s elapsed | ETA 236s
#   [TRAIN-300] 58300/90000 | 432s elapsed | ETA 235s
#   [TRAIN-300] 58400/90000 | 433s elapsed | ETA 234s
#   [TRAIN-300] 58500/90000 | 433s elapsed | ETA 233s
#   [TRAIN-300] 58600/90000 | 434s elapsed | ETA 233s
#   [TRAIN-300] 58700/90000 | 435s elapsed | ETA 232s
#   [TRAIN-300] 58800/90000 | 436s elapsed | ETA 231s
#   [TRAIN-300] 58900/90000 | 436s elapsed | ETA 230s
#   [TRAIN-300] 59000/90000 | 437s elapsed | ETA 230s
#   [TRAIN-300] 59100/90000 | 438s elapsed | ETA 229s
#   [TRAIN-300] 59200/90000 | 439s elapsed | ETA 228s
#   [TRAIN-300] 59300/90000 | 439s elapsed | ETA 227s
#   [TRAIN-300] 59400/90000 | 440s elapsed | ETA 227s
#   [TRAIN-300] 59500/90000 | 441s elapsed | ETA 226s
#   [TRAIN-300] 59600/90000 | 442s elapsed | ETA 225s
#   [TRAIN-300] 59700/90000 | 442s elapsed | ETA 225s
#   [TRAIN-300] 59800/90000 | 443s elapsed | ETA 224s
#   [TRAIN-300] 59900/90000 | 444s elapsed | ETA 223s
#   [TRAIN-300] 60000/90000 | 445s elapsed | ETA 222s
#   [TRAIN-300] 60100/90000 | 445s elapsed | ETA 222s
#   [TRAIN-300] 60200/90000 | 446s elapsed | ETA 221s
#   [TRAIN-300] 60300/90000 | 447s elapsed | ETA 220s
#   [TRAIN-300] 60400/90000 | 447s elapsed | ETA 219s
#   [TRAIN-300] 60500/90000 | 448s elapsed | ETA 219s
#   [TRAIN-300] 60600/90000 | 449s elapsed | ETA 218s
#   [TRAIN-300] 60700/90000 | 450s elapsed | ETA 217s
#   [TRAIN-300] 60800/90000 | 450s elapsed | ETA 216s
#   [TRAIN-300] 60900/90000 | 451s elapsed | ETA 216s
#   [TRAIN-300] 61000/90000 | 452s elapsed | ETA 215s
#   [TRAIN-300] 61100/90000 | 453s elapsed | ETA 214s
#   [TRAIN-300] 61200/90000 | 453s elapsed | ETA 213s
#   [TRAIN-300] 61300/90000 | 454s elapsed | ETA 213s
#   [TRAIN-300] 61400/90000 | 455s elapsed | ETA 212s
#   [TRAIN-300] 61500/90000 | 456s elapsed | ETA 211s
#   [TRAIN-300] 61600/90000 | 456s elapsed | ETA 210s
#   [TRAIN-300] 61700/90000 | 457s elapsed | ETA 210s
#   [TRAIN-300] 61800/90000 | 458s elapsed | ETA 209s
#   [TRAIN-300] 61900/90000 | 459s elapsed | ETA 208s
#   [TRAIN-300] 62000/90000 | 459s elapsed | ETA 207s
#   [TRAIN-300] 62100/90000 | 460s elapsed | ETA 207s
#   [TRAIN-300] 62200/90000 | 461s elapsed | ETA 206s
#   [TRAIN-300] 62300/90000 | 461s elapsed | ETA 205s
#   [TRAIN-300] 62400/90000 | 462s elapsed | ETA 204s
#   [TRAIN-300] 62500/90000 | 463s elapsed | ETA 204s
#   [TRAIN-300] 62600/90000 | 464s elapsed | ETA 203s
#   [TRAIN-300] 62700/90000 | 464s elapsed | ETA 202s
#   [TRAIN-300] 62800/90000 | 465s elapsed | ETA 201s
#   [TRAIN-300] 62900/90000 | 466s elapsed | ETA 201s
#   [TRAIN-300] 63000/90000 | 467s elapsed | ETA 200s
#   [TRAIN-300] 63100/90000 | 468s elapsed | ETA 199s
#   [TRAIN-300] 63200/90000 | 469s elapsed | ETA 199s
#   [TRAIN-300] 63300/90000 | 470s elapsed | ETA 198s
#   [TRAIN-300] 63400/90000 | 470s elapsed | ETA 197s
#   [TRAIN-300] 63500/90000 | 471s elapsed | ETA 197s
#   [TRAIN-300] 63600/90000 | 472s elapsed | ETA 196s
#   [TRAIN-300] 63700/90000 | 472s elapsed | ETA 195s
#   [TRAIN-300] 63800/90000 | 473s elapsed | ETA 194s
#   [TRAIN-300] 63900/90000 | 474s elapsed | ETA 194s
#   [TRAIN-300] 64000/90000 | 475s elapsed | ETA 193s
#   [TRAIN-300] 64100/90000 | 476s elapsed | ETA 192s
#   [TRAIN-300] 64200/90000 | 476s elapsed | ETA 191s
#   [TRAIN-300] 64300/90000 | 477s elapsed | ETA 191s
#   [TRAIN-300] 64400/90000 | 478s elapsed | ETA 190s
#   [TRAIN-300] 64500/90000 | 479s elapsed | ETA 189s
#   [TRAIN-300] 64600/90000 | 479s elapsed | ETA 188s
#   [TRAIN-300] 64700/90000 | 480s elapsed | ETA 188s
#   [TRAIN-300] 64800/90000 | 481s elapsed | ETA 187s
#   [TRAIN-300] 64900/90000 | 482s elapsed | ETA 186s
#   [TRAIN-300] 65000/90000 | 482s elapsed | ETA 185s
#   [TRAIN-300] 65100/90000 | 483s elapsed | ETA 185s
#   [TRAIN-300] 65200/90000 | 484s elapsed | ETA 184s
#   [TRAIN-300] 65300/90000 | 484s elapsed | ETA 183s
#   [TRAIN-300] 65400/90000 | 485s elapsed | ETA 183s
#   [TRAIN-300] 65500/90000 | 486s elapsed | ETA 182s
#   [TRAIN-300] 65600/90000 | 487s elapsed | ETA 181s
#   [TRAIN-300] 65700/90000 | 487s elapsed | ETA 180s
#   [TRAIN-300] 65800/90000 | 488s elapsed | ETA 180s
#   [TRAIN-300] 65900/90000 | 489s elapsed | ETA 179s
#   [TRAIN-300] 66000/90000 | 490s elapsed | ETA 178s
#   [TRAIN-300] 66100/90000 | 490s elapsed | ETA 177s
#   [TRAIN-300] 66200/90000 | 491s elapsed | ETA 177s
#   [TRAIN-300] 66300/90000 | 492s elapsed | ETA 176s
#   [TRAIN-300] 66400/90000 | 493s elapsed | ETA 175s
#   [TRAIN-300] 66500/90000 | 493s elapsed | ETA 174s
#   [TRAIN-300] 66600/90000 | 494s elapsed | ETA 174s
#   [TRAIN-300] 66700/90000 | 495s elapsed | ETA 173s
#   [TRAIN-300] 66800/90000 | 496s elapsed | ETA 172s
#   [TRAIN-300] 66900/90000 | 496s elapsed | ETA 171s
#   [TRAIN-300] 67000/90000 | 497s elapsed | ETA 171s
#   [TRAIN-300] 67100/90000 | 498s elapsed | ETA 170s
#   [TRAIN-300] 67200/90000 | 498s elapsed | ETA 169s
#   [TRAIN-300] 67300/90000 | 499s elapsed | ETA 168s
#   [TRAIN-300] 67400/90000 | 500s elapsed | ETA 168s
#   [TRAIN-300] 67500/90000 | 501s elapsed | ETA 167s
#   [TRAIN-300] 67600/90000 | 501s elapsed | ETA 166s
#   [TRAIN-300] 67700/90000 | 502s elapsed | ETA 165s
#   [TRAIN-300] 67800/90000 | 503s elapsed | ETA 165s
#   [TRAIN-300] 67900/90000 | 504s elapsed | ETA 164s
#   [TRAIN-300] 68000/90000 | 504s elapsed | ETA 163s
#   [TRAIN-300] 68100/90000 | 505s elapsed | ETA 162s
#   [TRAIN-300] 68200/90000 | 506s elapsed | ETA 162s
#   [TRAIN-300] 68300/90000 | 507s elapsed | ETA 161s
#   [TRAIN-300] 68400/90000 | 507s elapsed | ETA 160s
#   [TRAIN-300] 68500/90000 | 508s elapsed | ETA 159s
#   [TRAIN-300] 68600/90000 | 509s elapsed | ETA 159s
#   [TRAIN-300] 68700/90000 | 510s elapsed | ETA 158s
#   [TRAIN-300] 68800/90000 | 510s elapsed | ETA 157s
#   [TRAIN-300] 68900/90000 | 511s elapsed | ETA 157s
#   [TRAIN-300] 69000/90000 | 512s elapsed | ETA 156s
#   [TRAIN-300] 69100/90000 | 513s elapsed | ETA 155s
#   [TRAIN-300] 69200/90000 | 513s elapsed | ETA 154s
#   [TRAIN-300] 69300/90000 | 514s elapsed | ETA 154s
#   [TRAIN-300] 69400/90000 | 515s elapsed | ETA 153s
#   [TRAIN-300] 69500/90000 | 515s elapsed | ETA 152s
#   [TRAIN-300] 69600/90000 | 516s elapsed | ETA 151s
#   [TRAIN-300] 69700/90000 | 517s elapsed | ETA 151s
#   [TRAIN-300] 69800/90000 | 518s elapsed | ETA 150s
#   [TRAIN-300] 69900/90000 | 518s elapsed | ETA 149s
#   [TRAIN-300] 70000/90000 | 519s elapsed | ETA 148s
#   [TRAIN-300] 70100/90000 | 520s elapsed | ETA 148s
#   [TRAIN-300] 70200/90000 | 521s elapsed | ETA 147s
#   [TRAIN-300] 70300/90000 | 521s elapsed | ETA 146s
#   [TRAIN-300] 70400/90000 | 522s elapsed | ETA 145s
#   [TRAIN-300] 70500/90000 | 523s elapsed | ETA 145s
#   [TRAIN-300] 70600/90000 | 524s elapsed | ETA 144s
#   [TRAIN-300] 70700/90000 | 524s elapsed | ETA 143s
#   [TRAIN-300] 70800/90000 | 525s elapsed | ETA 142s
#   [TRAIN-300] 70900/90000 | 526s elapsed | ETA 142s
#   [TRAIN-300] 71000/90000 | 527s elapsed | ETA 141s
#   [TRAIN-300] 71100/90000 | 527s elapsed | ETA 140s
#   [TRAIN-300] 71200/90000 | 528s elapsed | ETA 139s
#   [TRAIN-300] 71300/90000 | 529s elapsed | ETA 139s
#   [TRAIN-300] 71400/90000 | 529s elapsed | ETA 138s
#   [TRAIN-300] 71500/90000 | 530s elapsed | ETA 137s
#   [TRAIN-300] 71600/90000 | 531s elapsed | ETA 136s
#   [TRAIN-300] 71700/90000 | 532s elapsed | ETA 136s
#   [TRAIN-300] 71800/90000 | 532s elapsed | ETA 135s
#   [TRAIN-300] 71900/90000 | 533s elapsed | ETA 134s
#   [TRAIN-300] 72000/90000 | 534s elapsed | ETA 133s
#   [TRAIN-300] 72100/90000 | 535s elapsed | ETA 133s
#   [TRAIN-300] 72200/90000 | 535s elapsed | ETA 132s
#   [TRAIN-300] 72300/90000 | 536s elapsed | ETA 131s
#   [TRAIN-300] 72400/90000 | 537s elapsed | ETA 131s
#   [TRAIN-300] 72500/90000 | 538s elapsed | ETA 130s
#   [TRAIN-300] 72600/90000 | 538s elapsed | ETA 129s
#   [TRAIN-300] 72700/90000 | 539s elapsed | ETA 128s
#   [TRAIN-300] 72800/90000 | 540s elapsed | ETA 128s
#   [TRAIN-300] 72900/90000 | 541s elapsed | ETA 127s
#   [TRAIN-300] 73000/90000 | 541s elapsed | ETA 126s
#   [TRAIN-300] 73100/90000 | 542s elapsed | ETA 125s
#   [TRAIN-300] 73200/90000 | 543s elapsed | ETA 125s
#   [TRAIN-300] 73300/90000 | 544s elapsed | ETA 124s
#   [TRAIN-300] 73400/90000 | 544s elapsed | ETA 123s
#   [TRAIN-300] 73500/90000 | 545s elapsed | ETA 122s
#   [TRAIN-300] 73600/90000 | 546s elapsed | ETA 122s
#   [TRAIN-300] 73700/90000 | 546s elapsed | ETA 121s
#   [TRAIN-300] 73800/90000 | 547s elapsed | ETA 120s
#   [TRAIN-300] 73900/90000 | 548s elapsed | ETA 119s
#   [TRAIN-300] 74000/90000 | 549s elapsed | ETA 119s
#   [TRAIN-300] 74100/90000 | 549s elapsed | ETA 118s
#   [TRAIN-300] 74200/90000 | 550s elapsed | ETA 117s
#   [TRAIN-300] 74300/90000 | 551s elapsed | ETA 116s
#   [TRAIN-300] 74400/90000 | 552s elapsed | ETA 116s
#   [TRAIN-300] 74500/90000 | 552s elapsed | ETA 115s
#   [TRAIN-300] 74600/90000 | 553s elapsed | ETA 114s
#   [TRAIN-300] 74700/90000 | 554s elapsed | ETA 113s
#   [TRAIN-300] 74800/90000 | 555s elapsed | ETA 113s
#   [TRAIN-300] 74900/90000 | 555s elapsed | ETA 112s
#   [TRAIN-300] 75000/90000 | 556s elapsed | ETA 111s
#   [TRAIN-300] 75100/90000 | 557s elapsed | ETA 110s
#   [TRAIN-300] 75200/90000 | 558s elapsed | ETA 110s
#   [TRAIN-300] 75300/90000 | 558s elapsed | ETA 109s
#   [TRAIN-300] 75400/90000 | 559s elapsed | ETA 108s
#   [TRAIN-300] 75500/90000 | 560s elapsed | ETA 108s
#   [TRAIN-300] 75600/90000 | 561s elapsed | ETA 107s
#   [TRAIN-300] 75700/90000 | 561s elapsed | ETA 106s
#   [TRAIN-300] 75800/90000 | 562s elapsed | ETA 105s
#   [TRAIN-300] 75900/90000 | 563s elapsed | ETA 105s
#   [TRAIN-300] 76000/90000 | 563s elapsed | ETA 104s
#   [TRAIN-300] 76100/90000 | 564s elapsed | ETA 103s
#   [TRAIN-300] 76200/90000 | 565s elapsed | ETA 102s
#   [TRAIN-300] 76300/90000 | 566s elapsed | ETA 102s
#   [TRAIN-300] 76400/90000 | 566s elapsed | ETA 101s
#   [TRAIN-300] 76500/90000 | 567s elapsed | ETA 100s
#   [TRAIN-300] 76600/90000 | 568s elapsed | ETA 99s
#   [TRAIN-300] 76700/90000 | 569s elapsed | ETA 99s
#   [TRAIN-300] 76800/90000 | 569s elapsed | ETA 98s
#   [TRAIN-300] 76900/90000 | 570s elapsed | ETA 97s
#   [TRAIN-300] 77000/90000 | 571s elapsed | ETA 96s
#   [TRAIN-300] 77100/90000 | 572s elapsed | ETA 96s
#   [TRAIN-300] 77200/90000 | 572s elapsed | ETA 95s
#   [TRAIN-300] 77300/90000 | 573s elapsed | ETA 94s
#   [TRAIN-300] 77400/90000 | 574s elapsed | ETA 93s
#   [TRAIN-300] 77500/90000 | 575s elapsed | ETA 93s
#   [TRAIN-300] 77600/90000 | 576s elapsed | ETA 92s
#   [TRAIN-300] 77700/90000 | 576s elapsed | ETA 91s
#   [TRAIN-300] 77800/90000 | 577s elapsed | ETA 90s
#   [TRAIN-300] 77900/90000 | 578s elapsed | ETA 90s
#   [TRAIN-300] 78000/90000 | 578s elapsed | ETA 89s
#   [TRAIN-300] 78100/90000 | 579s elapsed | ETA 88s
#   [TRAIN-300] 78200/90000 | 580s elapsed | ETA 88s
#   [TRAIN-300] 78300/90000 | 581s elapsed | ETA 87s
#   [TRAIN-300] 78400/90000 | 581s elapsed | ETA 86s
#   [TRAIN-300] 78500/90000 | 582s elapsed | ETA 85s
#   [TRAIN-300] 78600/90000 | 583s elapsed | ETA 85s
#   [TRAIN-300] 78700/90000 | 584s elapsed | ETA 84s
#   [TRAIN-300] 78800/90000 | 584s elapsed | ETA 83s
#   [TRAIN-300] 78900/90000 | 585s elapsed | ETA 82s
#   [TRAIN-300] 79000/90000 | 586s elapsed | ETA 82s
#   [TRAIN-300] 79100/90000 | 587s elapsed | ETA 81s
#   [TRAIN-300] 79200/90000 | 587s elapsed | ETA 80s
#   [TRAIN-300] 79300/90000 | 588s elapsed | ETA 79s
#   [TRAIN-300] 79400/90000 | 589s elapsed | ETA 79s
#   [TRAIN-300] 79500/90000 | 590s elapsed | ETA 78s
#   [TRAIN-300] 79600/90000 | 590s elapsed | ETA 77s
#   [TRAIN-300] 79700/90000 | 591s elapsed | ETA 76s
#   [TRAIN-300] 79800/90000 | 592s elapsed | ETA 76s
#   [TRAIN-300] 79900/90000 | 592s elapsed | ETA 75s
#   [TRAIN-300] 80000/90000 | 593s elapsed | ETA 74s
#   [TRAIN-300] 80100/90000 | 594s elapsed | ETA 73s
#   [TRAIN-300] 80200/90000 | 595s elapsed | ETA 73s
#   [TRAIN-300] 80300/90000 | 595s elapsed | ETA 72s
#   [TRAIN-300] 80400/90000 | 596s elapsed | ETA 71s
#   [TRAIN-300] 80500/90000 | 597s elapsed | ETA 70s
#   [TRAIN-300] 80600/90000 | 598s elapsed | ETA 70s
#   [TRAIN-300] 80700/90000 | 598s elapsed | ETA 69s
#   [TRAIN-300] 80800/90000 | 599s elapsed | ETA 68s
#   [TRAIN-300] 80900/90000 | 600s elapsed | ETA 67s
#   [TRAIN-300] 81000/90000 | 601s elapsed | ETA 67s
#   [TRAIN-300] 81100/90000 | 601s elapsed | ETA 66s
#   [TRAIN-300] 81200/90000 | 602s elapsed | ETA 65s
#   [TRAIN-300] 81300/90000 | 603s elapsed | ETA 65s
#   [TRAIN-300] 81400/90000 | 604s elapsed | ETA 64s
#   [TRAIN-300] 81500/90000 | 604s elapsed | ETA 63s
#   [TRAIN-300] 81600/90000 | 605s elapsed | ETA 62s
#   [TRAIN-300] 81700/90000 | 606s elapsed | ETA 62s
#   [TRAIN-300] 81800/90000 | 607s elapsed | ETA 61s
#   [TRAIN-300] 81900/90000 | 607s elapsed | ETA 60s
#   [TRAIN-300] 82000/90000 | 608s elapsed | ETA 59s
#   [TRAIN-300] 82100/90000 | 609s elapsed | ETA 59s
#   [TRAIN-300] 82200/90000 | 610s elapsed | ETA 58s
#   [TRAIN-300] 82300/90000 | 610s elapsed | ETA 57s
#   [TRAIN-300] 82400/90000 | 611s elapsed | ETA 56s
#   [TRAIN-300] 82500/90000 | 612s elapsed | ETA 56s
#   [TRAIN-300] 82600/90000 | 613s elapsed | ETA 55s
#   [TRAIN-300] 82700/90000 | 613s elapsed | ETA 54s
#   [TRAIN-300] 82800/90000 | 614s elapsed | ETA 53s
#   [TRAIN-300] 82900/90000 | 615s elapsed | ETA 53s
#   [TRAIN-300] 83000/90000 | 616s elapsed | ETA 52s
#   [TRAIN-300] 83100/90000 | 616s elapsed | ETA 51s
#   [TRAIN-300] 83200/90000 | 617s elapsed | ETA 50s
#   [TRAIN-300] 83300/90000 | 618s elapsed | ETA 50s
#   [TRAIN-300] 83400/90000 | 618s elapsed | ETA 49s
#   [TRAIN-300] 83500/90000 | 619s elapsed | ETA 48s
#   [TRAIN-300] 83600/90000 | 620s elapsed | ETA 47s
#   [TRAIN-300] 83700/90000 | 621s elapsed | ETA 47s
#   [TRAIN-300] 83800/90000 | 621s elapsed | ETA 46s
#   [TRAIN-300] 83900/90000 | 622s elapsed | ETA 45s
#   [TRAIN-300] 84000/90000 | 623s elapsed | ETA 44s
#   [TRAIN-300] 84100/90000 | 624s elapsed | ETA 44s
#   [TRAIN-300] 84200/90000 | 625s elapsed | ETA 43s
#   [TRAIN-300] 84300/90000 | 626s elapsed | ETA 42s
#   [TRAIN-300] 84400/90000 | 626s elapsed | ETA 42s
#   [TRAIN-300] 84500/90000 | 627s elapsed | ETA 41s
#   [TRAIN-300] 84600/90000 | 628s elapsed | ETA 40s
#   [TRAIN-300] 84700/90000 | 629s elapsed | ETA 39s
#   [TRAIN-300] 84800/90000 | 630s elapsed | ETA 39s
#   [TRAIN-300] 84900/90000 | 631s elapsed | ETA 38s
#   [TRAIN-300] 85000/90000 | 631s elapsed | ETA 37s
#   [TRAIN-300] 85100/90000 | 632s elapsed | ETA 36s
#   [TRAIN-300] 85200/90000 | 633s elapsed | ETA 36s
#   [TRAIN-300] 85300/90000 | 634s elapsed | ETA 35s
#   [TRAIN-300] 85400/90000 | 634s elapsed | ETA 34s
#   [TRAIN-300] 85500/90000 | 635s elapsed | ETA 33s
#   [TRAIN-300] 85600/90000 | 636s elapsed | ETA 33s
#   [TRAIN-300] 85700/90000 | 636s elapsed | ETA 32s
#   [TRAIN-300] 85800/90000 | 637s elapsed | ETA 31s
#   [TRAIN-300] 85900/90000 | 638s elapsed | ETA 30s
#   [TRAIN-300] 86000/90000 | 639s elapsed | ETA 30s
#   [TRAIN-300] 86100/90000 | 640s elapsed | ETA 29s
#   [TRAIN-300] 86200/90000 | 640s elapsed | ETA 28s
#   [TRAIN-300] 86300/90000 | 641s elapsed | ETA 27s
#   [TRAIN-300] 86400/90000 | 642s elapsed | ETA 27s
#   [TRAIN-300] 86500/90000 | 643s elapsed | ETA 26s
#   [TRAIN-300] 86600/90000 | 643s elapsed | ETA 25s
#   [TRAIN-300] 86700/90000 | 644s elapsed | ETA 25s
#   [TRAIN-300] 86800/90000 | 645s elapsed | ETA 24s
#   [TRAIN-300] 86900/90000 | 646s elapsed | ETA 23s
#   [TRAIN-300] 87000/90000 | 647s elapsed | ETA 22s
#   [TRAIN-300] 87100/90000 | 647s elapsed | ETA 22s
#   [TRAIN-300] 87200/90000 | 648s elapsed | ETA 21s
#   [TRAIN-300] 87300/90000 | 649s elapsed | ETA 20s
#   [TRAIN-300] 87400/90000 | 650s elapsed | ETA 19s
#   [TRAIN-300] 87500/90000 | 650s elapsed | ETA 19s
#   [TRAIN-300] 87600/90000 | 651s elapsed | ETA 18s
#   [TRAIN-300] 87700/90000 | 652s elapsed | ETA 17s
#   [TRAIN-300] 87800/90000 | 652s elapsed | ETA 16s
#   [TRAIN-300] 87900/90000 | 653s elapsed | ETA 16s
#   [TRAIN-300] 88000/90000 | 654s elapsed | ETA 15s
#   [TRAIN-300] 88100/90000 | 655s elapsed | ETA 14s
#   [TRAIN-300] 88200/90000 | 655s elapsed | ETA 13s
#   [TRAIN-300] 88300/90000 | 656s elapsed | ETA 13s
#   [TRAIN-300] 88400/90000 | 657s elapsed | ETA 12s
#   [TRAIN-300] 88500/90000 | 658s elapsed | ETA 11s
#   [TRAIN-300] 88600/90000 | 658s elapsed | ETA 10s
#   [TRAIN-300] 88700/90000 | 659s elapsed | ETA 10s
#   [TRAIN-300] 88800/90000 | 660s elapsed | ETA 9s
#   [TRAIN-300] 88900/90000 | 661s elapsed | ETA 8s
#   [TRAIN-300] 89000/90000 | 661s elapsed | ETA 7s
#   [TRAIN-300] 89100/90000 | 662s elapsed | ETA 7s
#   [TRAIN-300] 89200/90000 | 663s elapsed | ETA 6s
#   [TRAIN-300] 89300/90000 | 664s elapsed | ETA 5s
#   [TRAIN-300] 89400/90000 | 664s elapsed | ETA 4s
#   [TRAIN-300] 89500/90000 | 665s elapsed | ETA 4s
#   [TRAIN-300] 89600/90000 | 666s elapsed | ETA 3s
#   [TRAIN-300] 89700/90000 | 667s elapsed | ETA 2s
#   [TRAIN-300] 89800/90000 | 667s elapsed | ETA 1s
#   [TRAIN-300] 89900/90000 | 668s elapsed | ETA 1s
#   [TRAIN-300] 90000/90000 | 669s elapsed | ETA 0s
#   [TRAIN-300] Done — 300x300 in 669s
#   [VAL-300] 100/24000 | 1s elapsed | ETA 174s
#   [VAL-300] 200/24000 | 1s elapsed | ETA 173s
#   [VAL-300] 300/24000 | 2s elapsed | ETA 173s
#   [VAL-300] 400/24000 | 3s elapsed | ETA 174s
#   [VAL-300] 500/24000 | 4s elapsed | ETA 173s
#   [VAL-300] 600/24000 | 4s elapsed | ETA 172s
#   [VAL-300] 700/24000 | 5s elapsed | ETA 171s
#   [VAL-300] 800/24000 | 6s elapsed | ETA 171s
#   [VAL-300] 900/24000 | 7s elapsed | ETA 170s
#   [VAL-300] 1000/24000 | 7s elapsed | ETA 169s
#   [VAL-300] 1100/24000 | 8s elapsed | ETA 170s
#   [VAL-300] 1200/24000 | 9s elapsed | ETA 169s
#   [VAL-300] 1300/24000 | 10s elapsed | ETA 170s
#   [VAL-300] 1400/24000 | 10s elapsed | ETA 169s
#   [VAL-300] 1500/24000 | 11s elapsed | ETA 168s
#   [VAL-300] 1600/24000 | 12s elapsed | ETA 167s
#   [VAL-300] 1700/24000 | 13s elapsed | ETA 166s
#   [VAL-300] 1800/24000 | 13s elapsed | ETA 166s
#   [VAL-300] 1900/24000 | 14s elapsed | ETA 165s
#   [VAL-300] 2000/24000 | 15s elapsed | ETA 165s
#   [TEST-300] 38100/42000 | 283s elapsed | ETA 29s
#   [TEST-300] 38200/42000 | 284s elapsed | ETA 28s
#   [TEST-300] 38300/42000 | 285s elapsed | ETA 28s
#   [TEST-300] 38400/42000 | 285s elapsed | ETA 27s
#   [TEST-300] 38500/42000 | 286s elapsed | ETA 26s
#   [TEST-300] 38600/42000 | 287s elapsed | ETA 25s
#   [TEST-300] 38700/42000 | 288s elapsed | ETA 25s
#   [TEST-300] 38800/42000 | 288s elapsed | ETA 24s
#   [TEST-300] 38900/42000 | 289s elapsed | ETA 23s
#   [TEST-300] 39000/42000 | 290s elapsed | ETA 22s
#   [TEST-300] 39100/42000 | 291s elapsed | ETA 22s
#   [TEST-300] 39200/42000 | 291s elapsed | ETA 21s
#   [TEST-300] 39300/42000 | 292s elapsed | ETA 20s
#   [TEST-300] 39400/42000 | 293s elapsed | ETA 19s
#   [TEST-300] 39500/42000 | 293s elapsed | ETA 19s
#   [TEST-300] 39600/42000 | 294s elapsed | ETA 18s
#   [TEST-300] 39700/42000 | 295s elapsed | ETA 17s
#   [TEST-300] 39800/42000 | 296s elapsed | ETA 16s
#   [TEST-300] 39900/42000 | 296s elapsed | ETA 16s
#   [TEST-300] 40000/42000 | 297s elapsed | ETA 15s
#   [TEST-300] 40100/42000 | 298s elapsed | ETA 14s
#   [TEST-300] 40200/42000 | 299s elapsed | ETA 13s
#   [TEST-300] 40300/42000 | 299s elapsed | ETA 13s
#   [TEST-300] 40400/42000 | 300s elapsed | ETA 12s
#   [TEST-300] 40500/42000 | 301s elapsed | ETA 11s
#   [TEST-300] 40600/42000 | 302s elapsed | ETA 10s
#   [TEST-300] 40700/42000 | 302s elapsed | ETA 10s
#   [TEST-300] 40800/42000 | 303s elapsed | ETA 9s
#   [TEST-300] 40900/42000 | 304s elapsed | ETA 8s
#   [TEST-300] 41000/42000 | 305s elapsed | ETA 7s
#   [TEST-300] 41100/42000 | 305s elapsed | ETA 7s
#   [TEST-300] 41200/42000 | 306s elapsed | ETA 6s
#   [TEST-300] 41300/42000 | 307s elapsed | ETA 5s
#   [TEST-300] 41400/42000 | 308s elapsed | ETA 4s
#   [TEST-300] 41500/42000 | 308s elapsed | ETA 4s
#   [TEST-300] 41600/42000 | 309s elapsed | ETA 3s
#   [TEST-300] 41700/42000 | 310s elapsed | ETA 2s
#   [TEST-300] 41800/42000 | 311s elapsed | ETA 1s
#   [TEST-300] 41900/42000 | 311s elapsed | ETA 1s
#   [TEST-300] 42000/42000 | 312s elapsed | ETA 0s
#   [TEST-300] Done — 140x300 in 312s
# Done.

# %% [markdown]
# # Cell 22 — Train and evaluate QSVM at 300 samples

# %%
# Train and evaluate QSVM on the 300-sample precomputed kernels
clf8, val_acc8, test_acc8, test_f18 = evaluate_qsvm(
    K_train_300, Y_tr3, K_val_300, Y_v3, K_test_300, Y_te3)
Y_pred8 = clf8.predict(K_test_300)

# Classical SVM baseline (RBF) on the same subset
svm8 = svm.SVC(kernel="rbf", probability=True, class_weight="balanced", random_state=42)
svm8.fit(X_tr3, Y_tr3)
svm_pred8 = svm8.predict(X_te3)
svm_acc8  = accuracy_score(Y_te3, svm_pred8)
svm_f18   = f1_score(Y_te3, svm_pred8, average="weighted", zero_division=0)

# Report QSVM metrics and per-class breakdown
print("=== QSVM Results (300 samples) ===")
print(f"Val Accuracy  : {val_acc8:.3f}")
print(f"Test Accuracy : {test_acc8:.3f}")
print(f"Test F1       : {test_f18:.3f}")
print(classification_report(Y_te3, Y_pred8,
      target_names=["Upward","Downward","Flat"], zero_division=0))

# Report classical SVM metrics for direct comparison
print("=== Classical SVM Results (300 samples) ===")
print(f"Test Accuracy : {svm_acc8:.3f}")
print(f"Test F1       : {svm_f18:.3f}")
print(classification_report(Y_te3, svm_pred8,
      target_names=["Upward","Downward","Flat"], zero_division=0))

# Log attempt 8: largest training set, expected to widen the QSVM advantage
attempt_log.append([
    8, "QSVM\nZZ Kernel\nFixed Adjoint\n300 samples",
    "Scaled training subset to 300 samples. 300x300 kernel matrix = 90,000 circuit evaluations.",
    f"QSVM test acc: {test_acc8:.3f}, F1: {test_f18:.3f}. SVM test acc: {svm_acc8:.3f}, F1: {svm_f18:.3f}.",
    "Success"
])
show_summary()
# Out:
# === QSVM Results (300 samples) ===
# Val Accuracy  : 0.738
# Test Accuracy : 0.821
# Test F1       : 0.820
#               precision    recall  f1-score   support
#
#       Upward       0.75      0.94      0.83        48
#     Downward       0.85      0.80      0.82        49
#         Flat       0.91      0.72      0.81        43
#
#     accuracy                           0.82       140
#    macro avg       0.84      0.82      0.82       140
# weighted avg       0.83      0.82      0.82       140
#
# === Classical SVM Results (300 samples) ===
# Test Accuracy : 0.821
# Test F1       : 0.823
#               precision    recall  f1-score   support
#
#       Upward       0.95      0.88      0.91        48
#     Downward       0.81      0.86      0.83        49
#         Flat       0.70      0.72      0.71        43
#
#     accuracy                           0.82       140
#    macro avg       0.82      0.82      0.82       140
# weighted avg       0.83      0.82      0.82       140
#
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9535. Gap: 0.0465. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0622 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700.             |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 7  |QSVM ZZ Kernel  |Increased training subset to 200  |QSVM test acc: 0.730, F1: 0.726.  |✓ Success |
# |    |Fixed Adjoint   |samples. 200x200 kernel matrix =  |SVM test acc: 0.720, F1: 0.723.   |          |
# |    |200 samples     |40,000 circuit evaluations.       |QSVM wins on every metric.        |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 8  |QSVM ZZ Kernel  |Scaled training subset to 300     |QSVM test acc: 0.821, F1: 0.820.  |✓ Success |
# |    |Fixed Adjoint   |samples. 300x300 kernel matrix =  |SVM test acc: 0.821, F1: 0.823.   |          |
# |    |300 samples     |90,000 circuit evaluations.       |                                  |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 23 — Build kernel matrices for 500 samples

# %%
# Scale up to 500 training samples for attempt 9
# Total = 500*500 + 130*500 + 230*500 = 430,000 kernel evaluations
# Expect 3-4 hours on a laptop CPU — run on a desktop if possible
N_tr4, N_v4, N_te4 = 500, 130, 230

# Slice matching feature and label subsets
X_tr4 = X_train[:N_tr4];  Y_tr4 = Y_train[:N_tr4]
X_v4  = X_val[:N_v4];     Y_v4  = Y_val[:N_v4]
X_te4 = X_test[:N_te4];   Y_te4 = Y_test[:N_te4]

# Build train (square), val and test (rectangular) kernel matrices
print("Building kernel matrices (500 samples) — this takes ~3-4 hours ...")
K_train_500 = build_kernel_matrix(X_tr4, X_tr4, quantum_kernel, "TRAIN-500")
K_val_500   = build_kernel_matrix(X_v4,  X_tr4, quantum_kernel, "VAL-500")
K_test_500  = build_kernel_matrix(X_te4, X_tr4, quantum_kernel, "TEST-500")
print("Done.")
# Out:
# Building kernel matrices (500 samples) — this takes ~3-4 hours ...
#   [TRAIN-500] 100/250000 | 1s elapsed | ETA 2046s
#   [TRAIN-500] 200/250000 | 2s elapsed | ETA 1977s
#   [TRAIN-500] 300/250000 | 2s elapsed | ETA 1926s
#   [TRAIN-500] 400/250000 | 3s elapsed | ETA 1901s
#   [TRAIN-500] 500/250000 | 4s elapsed | ETA 1885s
#   [TRAIN-500] 600/250000 | 5s elapsed | ETA 1873s
#   [TRAIN-500] 700/250000 | 5s elapsed | ETA 1864s
#   [TRAIN-500] 800/250000 | 6s elapsed | ETA 1858s
#   [TRAIN-500] 900/250000 | 7s elapsed | ETA 1852s
#   [TRAIN-500] 1000/250000 | 7s elapsed | ETA 1849s
#   [TRAIN-500] 1100/250000 | 8s elapsed | ETA 1846s
#   [TRAIN-500] 1200/250000 | 9s elapsed | ETA 1844s
#   [TRAIN-500] 1300/250000 | 10s elapsed | ETA 1842s
#   [TRAIN-500] 1400/250000 | 10s elapsed | ETA 1840s
#   [TRAIN-500] 1500/250000 | 11s elapsed | ETA 1839s
#   [TRAIN-500] 1600/250000 | 12s elapsed | ETA 1837s
#   [TRAIN-500] 1700/250000 | 13s elapsed | ETA 1835s
#   [TRAIN-500] 1800/250000 | 13s elapsed | ETA 1833s
#   [TRAIN-500] 1900/250000 | 14s elapsed | ETA 1836s
#   [TRAIN-500] 2000/250000 | 15s elapsed | ETA 1834s
#   [TRAIN-500] 2100/250000 | 16s elapsed | ETA 1838s
#   [TRAIN-500] 2200/250000 | 16s elapsed | ETA 1838s
#   [TRAIN-500] 2300/250000 | 17s elapsed | ETA 1836s
#   [TRAIN-500] 2400/250000 | 18s elapsed | ETA 1835s
#   [TRAIN-500] 2500/250000 | 19s elapsed | ETA 1833s
#   [TRAIN-500] 2600/250000 | 19s elapsed | ETA 1832s
#   [TRAIN-500] 2700/250000 | 20s elapsed | ETA 1830s
#   [TRAIN-500] 2800/250000 | 21s elapsed | ETA 1829s
#   [TRAIN-500] 2900/250000 | 21s elapsed | ETA 1827s
#   [TRAIN-500] 3000/250000 | 22s elapsed | ETA 1826s
#   [TRAIN-500] 3100/250000 | 23s elapsed | ETA 1824s
#   [TRAIN-500] 3200/250000 | 24s elapsed | ETA 1823s
#   [TRAIN-500] 3300/250000 | 24s elapsed | ETA 1822s
#   [TRAIN-500] 3400/250000 | 25s elapsed | ETA 1820s
#   [TRAIN-500] 3500/250000 | 26s elapsed | ETA 1819s
#   [TRAIN-500] 3600/250000 | 27s elapsed | ETA 1818s
#   [TRAIN-500] 3700/250000 | 27s elapsed | ETA 1817s
#   [TRAIN-500] 3800/250000 | 28s elapsed | ETA 1824s
#   [TRAIN-500] 47700/250000 | 354s elapsed | ETA 1502s
#   [TRAIN-500] 47800/250000 | 355s elapsed | ETA 1501s
#   [TRAIN-500] 47900/250000 | 356s elapsed | ETA 1500s
#   [TRAIN-500] 48000/250000 | 356s elapsed | ETA 1499s
#   [TRAIN-500] 48100/250000 | 357s elapsed | ETA 1499s
#   [TRAIN-500] 48200/250000 | 358s elapsed | ETA 1498s
#   [TRAIN-500] 48300/250000 | 359s elapsed | ETA 1497s
#   [TRAIN-500] 48400/250000 | 359s elapsed | ETA 1497s
#   [TRAIN-500] 48500/250000 | 360s elapsed | ETA 1496s
#   [TRAIN-500] 48600/250000 | 361s elapsed | ETA 1495s
#   [TRAIN-500] 48700/250000 | 362s elapsed | ETA 1495s
#   [TRAIN-500] 48800/250000 | 362s elapsed | ETA 1494s
#   [TRAIN-500] 48900/250000 | 363s elapsed | ETA 1493s
#   [TRAIN-500] 49000/250000 | 364s elapsed | ETA 1492s
#   [TRAIN-500] 49100/250000 | 365s elapsed | ETA 1492s
#   [TRAIN-500] 49200/250000 | 365s elapsed | ETA 1491s
#   [TRAIN-500] 49300/250000 | 366s elapsed | ETA 1490s
#   [TRAIN-500] 49400/250000 | 367s elapsed | ETA 1489s
#   [TRAIN-500] 49500/250000 | 368s elapsed | ETA 1489s
#   [TRAIN-500] 49600/250000 | 368s elapsed | ETA 1489s
#   [TRAIN-500] 49700/250000 | 369s elapsed | ETA 1488s
#   [TRAIN-500] 49800/250000 | 370s elapsed | ETA 1487s
#   [TRAIN-500] 49900/250000 | 371s elapsed | ETA 1486s
#   [TRAIN-500] 50000/250000 | 371s elapsed | ETA 1486s
#   [TRAIN-500] 50100/250000 | 372s elapsed | ETA 1485s
#   [TRAIN-500] 50200/250000 | 373s elapsed | ETA 1484s
#   [TRAIN-500] 50300/250000 | 374s elapsed | ETA 1483s
#   [TRAIN-500] 50400/250000 | 374s elapsed | ETA 1482s
#   [TRAIN-500] 50500/250000 | 375s elapsed | ETA 1482s
#   [TRAIN-500] 50600/250000 | 376s elapsed | ETA 1481s
#   [TRAIN-500] 50700/250000 | 377s elapsed | ETA 1480s
#   [TRAIN-500] 50800/250000 | 377s elapsed | ETA 1479s
#   [TRAIN-500] 50900/250000 | 378s elapsed | ETA 1478s
#   [TRAIN-500] 51000/250000 | 379s elapsed | ETA 1478s
#   [TRAIN-500] 51100/250000 | 379s elapsed | ETA 1477s
#   [TRAIN-500] 51200/250000 | 380s elapsed | ETA 1476s
#   [TRAIN-500] 51300/250000 | 381s elapsed | ETA 1475s
#   [TRAIN-500] 51400/250000 | 382s elapsed | ETA 1475s
#   [TRAIN-500] 51500/250000 | 382s elapsed | ETA 1474s
#   [TRAIN-500] 51600/250000 | 383s elapsed | ETA 1473s
#   [TRAIN-500] 51700/250000 | 384s elapsed | ETA 1472s
#   [TRAIN-500] 51800/250000 | 385s elapsed | ETA 1472s
#   [TRAIN-500] 51900/250000 | 385s elapsed | ETA 1471s
#   [TRAIN-500] 65200/250000 | 485s elapsed | ETA 1376s
#   [TRAIN-500] 65300/250000 | 486s elapsed | ETA 1375s
#   [TRAIN-500] 65400/250000 | 487s elapsed | ETA 1374s
#   [TRAIN-500] 65500/250000 | 488s elapsed | ETA 1373s
#   [TRAIN-500] 65600/250000 | 488s elapsed | ETA 1373s
#   [TRAIN-500] 65700/250000 | 489s elapsed | ETA 1372s
#   [TRAIN-500] 65800/250000 | 490s elapsed | ETA 1371s
#   [TRAIN-500] 65900/250000 | 491s elapsed | ETA 1370s
#   [TRAIN-500] 66000/250000 | 491s elapsed | ETA 1370s
#   [TRAIN-500] 66100/250000 | 492s elapsed | ETA 1369s
#   [TRAIN-500] 66200/250000 | 493s elapsed | ETA 1368s
#   [TRAIN-500] 66300/250000 | 493s elapsed | ETA 1367s
#   [TRAIN-500] 66400/250000 | 495s elapsed | ETA 1369s
#   [TRAIN-500] 66500/250000 | 496s elapsed | ETA 1368s
#   [TRAIN-500] 66600/250000 | 497s elapsed | ETA 1368s
#   [TRAIN-500] 66700/250000 | 497s elapsed | ETA 1367s
#   [TRAIN-500] 66800/250000 | 498s elapsed | ETA 1366s
#   [TRAIN-500] 66900/250000 | 499s elapsed | ETA 1365s
#   [TRAIN-500] 67000/250000 | 500s elapsed | ETA 1365s
#   [TRAIN-500] 67100/250000 | 500s elapsed | ETA 1364s
#   [TRAIN-500] 67200/250000 | 501s elapsed | ETA 1363s
#   [TRAIN-500] 67300/250000 | 502s elapsed | ETA 1362s
#   [TRAIN-500] 67400/250000 | 503s elapsed | ETA 1361s
#   [TRAIN-500] 67500/250000 | 503s elapsed | ETA 1361s
#   [TRAIN-500] 67600/250000 | 504s elapsed | ETA 1360s
#   [TRAIN-500] 67700/250000 | 505s elapsed | ETA 1360s
#   [TRAIN-500] 67800/250000 | 506s elapsed | ETA 1359s
#   [TRAIN-500] 67900/250000 | 506s elapsed | ETA 1358s
#   [TRAIN-500] 68000/250000 | 507s elapsed | ETA 1357s
#   [TRAIN-500] 68100/250000 | 508s elapsed | ETA 1356s
#   [TRAIN-500] 68200/250000 | 509s elapsed | ETA 1356s
#   [TRAIN-500] 68300/250000 | 509s elapsed | ETA 1355s
#   [TRAIN-500] 68400/250000 | 510s elapsed | ETA 1354s
#   [TRAIN-500] 68500/250000 | 511s elapsed | ETA 1353s
#   [TRAIN-500] 68600/250000 | 512s elapsed | ETA 1353s
#   [TRAIN-500] 68700/250000 | 512s elapsed | ETA 1352s
#   [TRAIN-500] 68800/250000 | 513s elapsed | ETA 1351s
#   [TRAIN-500] 68900/250000 | 514s elapsed | ETA 1351s
#   [TRAIN-500] 69000/250000 | 515s elapsed | ETA 1350s
#   [TRAIN-500] 69100/250000 | 515s elapsed | ETA 1349s
#   [TRAIN-500] 69200/250000 | 516s elapsed | ETA 1348s
#   [TRAIN-500] 69300/250000 | 517s elapsed | ETA 1348s
#   [TRAIN-500] 69400/250000 | 518s elapsed | ETA 1347s
#   [TRAIN-500] 73900/250000 | 554s elapsed | ETA 1321s
#   [TRAIN-500] 74000/250000 | 555s elapsed | ETA 1320s
#   [TRAIN-500] 74100/250000 | 556s elapsed | ETA 1319s
#   [TRAIN-500] 74200/250000 | 556s elapsed | ETA 1318s
#   [TRAIN-500] 74300/250000 | 557s elapsed | ETA 1318s
#   [TRAIN-500] 74400/250000 | 558s elapsed | ETA 1317s
#   [TRAIN-500] 74500/250000 | 559s elapsed | ETA 1316s
#   [TRAIN-500] 74600/250000 | 559s elapsed | ETA 1315s
#   [TRAIN-500] 74700/250000 | 560s elapsed | ETA 1314s
#   [TRAIN-500] 74800/250000 | 561s elapsed | ETA 1314s
#   [TRAIN-500] 74900/250000 | 562s elapsed | ETA 1313s
#   [TRAIN-500] 75000/250000 | 562s elapsed | ETA 1312s
#   [TRAIN-500] 75100/250000 | 563s elapsed | ETA 1311s
#   [TRAIN-500] 75200/250000 | 564s elapsed | ETA 1311s
#   [TRAIN-500] 75300/250000 | 565s elapsed | ETA 1310s
#   [TRAIN-500] 75400/250000 | 565s elapsed | ETA 1309s
#   [TRAIN-500] 75500/250000 | 566s elapsed | ETA 1308s
#   [TRAIN-500] 75600/250000 | 567s elapsed | ETA 1307s
#   [TRAIN-500] 75700/250000 | 567s elapsed | ETA 1307s
#   [TRAIN-500] 75800/250000 | 568s elapsed | ETA 1306s
#   [TRAIN-500] 75900/250000 | 569s elapsed | ETA 1305s
#   [TRAIN-500] 76000/250000 | 570s elapsed | ETA 1304s
#   [TRAIN-500] 76100/250000 | 570s elapsed | ETA 1303s
#   [TRAIN-500] 76200/250000 | 571s elapsed | ETA 1302s
#   [TRAIN-500] 76300/250000 | 572s elapsed | ETA 1302s
#   [TRAIN-500] 76400/250000 | 572s elapsed | ETA 1301s
#   [TRAIN-500] 76500/250000 | 573s elapsed | ETA 1300s
#   [TRAIN-500] 76600/250000 | 574s elapsed | ETA 1299s
#   [TRAIN-500] 76700/250000 | 575s elapsed | ETA 1299s
#   [TRAIN-500] 76800/250000 | 576s elapsed | ETA 1298s
#   [TRAIN-500] 76900/250000 | 576s elapsed | ETA 1298s
#   [TRAIN-500] 77000/250000 | 577s elapsed | ETA 1297s
#   [TRAIN-500] 77100/250000 | 578s elapsed | ETA 1296s
#   [TRAIN-500] 77200/250000 | 579s elapsed | ETA 1295s
#   [TRAIN-500] 77300/250000 | 579s elapsed | ETA 1294s
#   [TRAIN-500] 77400/250000 | 580s elapsed | ETA 1294s
#   [TRAIN-500] 77500/250000 | 581s elapsed | ETA 1293s
#   [TRAIN-500] 77600/250000 | 582s elapsed | ETA 1292s
#   [TRAIN-500] 77700/250000 | 582s elapsed | ETA 1291s
#   [TRAIN-500] 77800/250000 | 583s elapsed | ETA 1290s
#   [TRAIN-500] 77900/250000 | 584s elapsed | ETA 1289s
#   [TRAIN-500] 78000/250000 | 584s elapsed | ETA 1289s
#   [TRAIN-500] 78100/250000 | 585s elapsed | ETA 1288s
#   [TRAIN-500] 78200/250000 | 586s elapsed | ETA 1287s
#   [TRAIN-500] 78300/250000 | 587s elapsed | ETA 1286s
#   [TRAIN-500] 78400/250000 | 587s elapsed | ETA 1285s
#   [TRAIN-500] 78500/250000 | 588s elapsed | ETA 1285s
#   [TRAIN-500] 78600/250000 | 589s elapsed | ETA 1284s
#   [TRAIN-500] 78700/250000 | 589s elapsed | ETA 1283s
#   [TRAIN-500] 78800/250000 | 590s elapsed | ETA 1282s
#   [TRAIN-500] 78900/250000 | 591s elapsed | ETA 1282s
#   [TRAIN-500] 79000/250000 | 592s elapsed | ETA 1281s
#   [TRAIN-500] 79100/250000 | 593s elapsed | ETA 1280s
#   [TRAIN-500] 79200/250000 | 594s elapsed | ETA 1280s
#   [TRAIN-500] 79300/250000 | 594s elapsed | ETA 1279s
#   [TRAIN-500] 79400/250000 | 595s elapsed | ETA 1279s
#   [TRAIN-500] 79500/250000 | 596s elapsed | ETA 1278s
#   [TRAIN-500] 79600/250000 | 597s elapsed | ETA 1277s
#   [TRAIN-500] 79700/250000 | 597s elapsed | ETA 1276s
#   [TRAIN-500] 79800/250000 | 598s elapsed | ETA 1276s
#   [TRAIN-500] 79900/250000 | 599s elapsed | ETA 1275s
#   [TRAIN-500] 80000/250000 | 600s elapsed | ETA 1274s
#   [TRAIN-500] 80100/250000 | 600s elapsed | ETA 1273s
#   [TRAIN-500] 80200/250000 | 601s elapsed | ETA 1272s
#   [TRAIN-500] 80300/250000 | 602s elapsed | ETA 1272s
#   [TRAIN-500] 80400/250000 | 602s elapsed | ETA 1271s
#   [TRAIN-500] 80500/250000 | 603s elapsed | ETA 1270s
#   [TRAIN-500] 80600/250000 | 604s elapsed | ETA 1269s
#   [TRAIN-500] 80700/250000 | 605s elapsed | ETA 1269s
#   [TRAIN-500] 80800/250000 | 605s elapsed | ETA 1268s
#   [TRAIN-500] 80900/250000 | 606s elapsed | ETA 1267s
#   [TRAIN-500] 81000/250000 | 607s elapsed | ETA 1266s
#   [TRAIN-500] 81100/250000 | 608s elapsed | ETA 1266s
#   [TRAIN-500] 81200/250000 | 608s elapsed | ETA 1265s
#   [TRAIN-500] 81300/250000 | 609s elapsed | ETA 1264s
#   [TRAIN-500] 81400/250000 | 610s elapsed | ETA 1264s
#   [TRAIN-500] 81500/250000 | 611s elapsed | ETA 1263s
#   [TRAIN-500] 81600/250000 | 612s elapsed | ETA 1262s
#   [TRAIN-500] 81700/250000 | 612s elapsed | ETA 1261s
#   [TRAIN-500] 81800/250000 | 613s elapsed | ETA 1261s
#   [TRAIN-500] 81900/250000 | 614s elapsed | ETA 1260s
#   [TRAIN-500] 82000/250000 | 614s elapsed | ETA 1259s
#   [TRAIN-500] 82100/250000 | 615s elapsed | ETA 1258s
#   [TRAIN-500] 82200/250000 | 616s elapsed | ETA 1257s
#   [TRAIN-500] 82300/250000 | 617s elapsed | ETA 1257s
#   [TRAIN-500] 82400/250000 | 617s elapsed | ETA 1256s
#   [TRAIN-500] 82500/250000 | 618s elapsed | ETA 1255s
#   [TRAIN-500] 82600/250000 | 619s elapsed | ETA 1254s
#   [TRAIN-500] 82700/250000 | 620s elapsed | ETA 1253s
#   [TRAIN-500] 82800/250000 | 620s elapsed | ETA 1253s
#   [TRAIN-500] 82900/250000 | 621s elapsed | ETA 1252s
#   [TRAIN-500] 83000/250000 | 622s elapsed | ETA 1251s
#   [TRAIN-500] 83100/250000 | 623s elapsed | ETA 1250s
#   [TRAIN-500] 83200/250000 | 623s elapsed | ETA 1250s
#   [TRAIN-500] 83300/250000 | 624s elapsed | ETA 1249s
#   [TRAIN-500] 83400/250000 | 625s elapsed | ETA 1248s
#   [TRAIN-500] 83500/250000 | 625s elapsed | ETA 1247s
#   [TRAIN-500] 83600/250000 | 626s elapsed | ETA 1246s
#   [TRAIN-500] 83700/250000 | 627s elapsed | ETA 1246s
#   [TRAIN-500] 83800/250000 | 628s elapsed | ETA 1245s
#   [TRAIN-500] 83900/250000 | 628s elapsed | ETA 1244s
#   [TRAIN-500] 84000/250000 | 629s elapsed | ETA 1243s
#   [TRAIN-500] 84100/250000 | 630s elapsed | ETA 1243s
#   [TRAIN-500] 84200/250000 | 631s elapsed | ETA 1242s
#   [TRAIN-500] 84300/250000 | 631s elapsed | ETA 1241s
#   [TRAIN-500] 84400/250000 | 632s elapsed | ETA 1240s
#   [TRAIN-500] 84500/250000 | 633s elapsed | ETA 1239s
#   [TRAIN-500] 84600/250000 | 634s elapsed | ETA 1239s
#   [TRAIN-500] 84700/250000 | 634s elapsed | ETA 1238s
#   [TRAIN-500] 84800/250000 | 635s elapsed | ETA 1237s
#   [TRAIN-500] 84900/250000 | 636s elapsed | ETA 1236s
#   [TRAIN-500] 85000/250000 | 636s elapsed | ETA 1235s
#   [TRAIN-500] 85100/250000 | 637s elapsed | ETA 1235s
#   [TRAIN-500] 85200/250000 | 638s elapsed | ETA 1234s
#   [TRAIN-500] 85300/250000 | 639s elapsed | ETA 1233s
#   [TRAIN-500] 85400/250000 | 639s elapsed | ETA 1232s
#   [TRAIN-500] 85500/250000 | 640s elapsed | ETA 1232s
#   [TRAIN-500] 85600/250000 | 641s elapsed | ETA 1231s
#   [TRAIN-500] 85700/250000 | 642s elapsed | ETA 1230s
#   [TRAIN-500] 85800/250000 | 642s elapsed | ETA 1229s
#   [TRAIN-500] 85900/250000 | 643s elapsed | ETA 1229s
#   [TRAIN-500] 86000/250000 | 644s elapsed | ETA 1228s
#   [TRAIN-500] 86100/250000 | 645s elapsed | ETA 1227s
#   [TRAIN-500] 86200/250000 | 645s elapsed | ETA 1226s
#   [TRAIN-500] 86300/250000 | 646s elapsed | ETA 1226s
#   [TRAIN-500] 86400/250000 | 647s elapsed | ETA 1225s
#   [TRAIN-500] 86500/250000 | 648s elapsed | ETA 1224s
#   [TRAIN-500] 86600/250000 | 648s elapsed | ETA 1223s
#   [TRAIN-500] 86700/250000 | 649s elapsed | ETA 1222s
#   [TRAIN-500] 86800/250000 | 650s elapsed | ETA 1222s
#   [TRAIN-500] 86900/250000 | 650s elapsed | ETA 1221s
#   [TRAIN-500] 87000/250000 | 651s elapsed | ETA 1220s
#   [TEST-500] 110800/115000 | 824s elapsed | ETA 31s
#   [TEST-500] 110900/115000 | 825s elapsed | ETA 30s
#   [TEST-500] 111000/115000 | 825s elapsed | ETA 30s
#   [TEST-500] 111100/115000 | 826s elapsed | ETA 29s
#   [TEST-500] 111200/115000 | 827s elapsed | ETA 28s
#   [TEST-500] 111300/115000 | 828s elapsed | ETA 28s
#   [TEST-500] 111400/115000 | 828s elapsed | ETA 27s
#   [TEST-500] 111500/115000 | 829s elapsed | ETA 26s
#   [TEST-500] 111600/115000 | 830s elapsed | ETA 25s
#   [TEST-500] 111700/115000 | 830s elapsed | ETA 25s
#   [TEST-500] 111800/115000 | 831s elapsed | ETA 24s
#   [TEST-500] 111900/115000 | 832s elapsed | ETA 23s
#   [TEST-500] 112000/115000 | 833s elapsed | ETA 22s
#   [TEST-500] 112100/115000 | 833s elapsed | ETA 22s
#   [TEST-500] 112200/115000 | 834s elapsed | ETA 21s
#   [TEST-500] 112300/115000 | 835s elapsed | ETA 20s
#   [TEST-500] 112400/115000 | 836s elapsed | ETA 19s
#   [TEST-500] 112500/115000 | 836s elapsed | ETA 19s
#   [TEST-500] 112600/115000 | 837s elapsed | ETA 18s
#   [TEST-500] 112700/115000 | 838s elapsed | ETA 17s
#   [TEST-500] 112800/115000 | 839s elapsed | ETA 16s
#   [TEST-500] 112900/115000 | 839s elapsed | ETA 16s
#   [TEST-500] 113000/115000 | 840s elapsed | ETA 15s
#   [TEST-500] 113100/115000 | 841s elapsed | ETA 14s
#   [TEST-500] 113200/115000 | 842s elapsed | ETA 13s
#   [TEST-500] 113300/115000 | 842s elapsed | ETA 13s
#   [TEST-500] 113400/115000 | 843s elapsed | ETA 12s
#   [TEST-500] 113500/115000 | 844s elapsed | ETA 11s
#   [TEST-500] 113600/115000 | 845s elapsed | ETA 10s
#   [TEST-500] 113700/115000 | 845s elapsed | ETA 10s
#   [TEST-500] 113800/115000 | 846s elapsed | ETA 9s
#   [TEST-500] 113900/115000 | 847s elapsed | ETA 8s
#   [TEST-500] 114000/115000 | 848s elapsed | ETA 7s
#   [TEST-500] 114100/115000 | 848s elapsed | ETA 7s
#   [TEST-500] 114200/115000 | 849s elapsed | ETA 6s
#   [TEST-500] 114300/115000 | 850s elapsed | ETA 5s
#   [TEST-500] 114400/115000 | 851s elapsed | ETA 4s
#   [TEST-500] 114500/115000 | 851s elapsed | ETA 4s
#   [TEST-500] 114600/115000 | 852s elapsed | ETA 3s
#   [TEST-500] 114700/115000 | 853s elapsed | ETA 2s
#   [TEST-500] 114800/115000 | 854s elapsed | ETA 1s
#   [TEST-500] 114900/115000 | 854s elapsed | ETA 1s
#   [TEST-500] 115000/115000 | 855s elapsed | ETA 0s
#   [TEST-500] Done — 230x500 in 855s
# Done.

# %% [markdown]
# # Cell 24 — Train and evaluate QSVM at 500 samples

# %%
# Train and evaluate QSVM on the 500-sample precomputed kernels
clf9, val_acc9, test_acc9, test_f19 = evaluate_qsvm(
    K_train_500, Y_tr4, K_val_500, Y_v4, K_test_500, Y_te4)
Y_pred9 = clf9.predict(K_test_500)

# Classical SVM baseline (RBF) on the same subset
svm9 = svm.SVC(kernel="rbf", probability=True, class_weight="balanced", random_state=42)
svm9.fit(X_tr4, Y_tr4)
svm_pred9 = svm9.predict(X_te4)
svm_acc9  = accuracy_score(Y_te4, svm_pred9)
svm_f19   = f1_score(Y_te4, svm_pred9, average="weighted", zero_division=0)

# Report QSVM metrics and per-class breakdown
print("=== QSVM Results (500 samples) ===")
print(f"Val Accuracy  : {val_acc9:.3f}")
print(f"Test Accuracy : {test_acc9:.3f}")
print(f"Test F1       : {test_f19:.3f}")
print(classification_report(Y_te4, Y_pred9,
      target_names=["Upward","Downward","Flat"], zero_division=0))

# Report classical SVM metrics for direct comparison
print("=== Classical SVM Results (500 samples) ===")
print(f"Test Accuracy : {svm_acc9:.3f}")
print(f"Test F1       : {svm_f19:.3f}")
print(classification_report(Y_te4, svm_pred9,
      target_names=["Upward","Downward","Flat"], zero_division=0))

# Log attempt 9: largest training set, expected to confirm or refine the QSVM advantage
attempt_log.append([
    9, "QSVM\nZZ Kernel\nFixed Adjoint\n500 samples",
    "Scaled training subset to 500 samples. 500x500 kernel matrix = 250,000 circuit evaluations.",
    f"QSVM test acc: {test_acc9:.3f}, F1: {test_f19:.3f}. SVM test acc: {svm_acc9:.3f}, F1: {svm_f19:.3f}.",
    "Success"
])
show_summary()
# Out:
# === QSVM Results (500 samples) ===
# Val Accuracy  : 0.815
# Test Accuracy : 0.822
# Test F1       : 0.822
#               precision    recall  f1-score   support
#
#       Upward       0.74      0.87      0.80        76
#     Downward       0.86      0.75      0.80        83
#         Flat       0.88      0.86      0.87        71
#
#     accuracy                           0.82       230
#    macro avg       0.83      0.82      0.82       230
# weighted avg       0.83      0.82      0.82       230
#
# === Classical SVM Results (500 samples) ===
# Test Accuracy : 0.848
# Test F1       : 0.851
#               precision    recall  f1-score   support
#
#       Upward       0.94      0.82      0.87        76
#     Downward       0.93      0.84      0.89        83
#         Flat       0.71      0.89      0.79        71
#
#     accuracy                           0.85       230
#    macro avg       0.86      0.85      0.85       230
# weighted avg       0.87      0.85      0.85       230
#
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.27 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.288. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.23-0.47. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9535. Gap: 0.0465. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0622 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7360. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700.             |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 7  |QSVM ZZ Kernel  |Increased training subset to 200  |QSVM test acc: 0.730, F1: 0.726.  |✓ Success |
# |    |Fixed Adjoint   |samples. 200x200 kernel matrix =  |SVM test acc: 0.720, F1: 0.723.   |          |
# |    |200 samples     |40,000 circuit evaluations.       |QSVM wins on every metric.        |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 8  |QSVM ZZ Kernel  |Scaled training subset to 300     |QSVM test acc: 0.821, F1: 0.820.  |✓ Success |
# |    |Fixed Adjoint   |samples. 300x300 kernel matrix =  |SVM test acc: 0.821, F1: 0.823.   |          |
# |    |300 samples     |90,000 circuit evaluations.       |                                  |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 9  |QSVM ZZ Kernel  |Scaled training subset to 500     |QSVM test acc: 0.822, F1: 0.822.  |✓ Success |
# |    |Fixed Adjoint   |samples. 500x500 kernel matrix =  |SVM test acc: 0.848, F1: 0.851.   |          |
# |    |500 samples     |250,000 circuit evaluations.      |                                  |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 25 - Plot result for QSVM with 100, 300 and 500 samples

# %%
# QSVM-only summary across three sample sizes
# Left: per-class F1 by sample size (3 bars per class group)
# Right: accuracy scaling curve, three points

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
fig.suptitle("QSVM Performance Across Sample Sizes",
             fontsize=15, fontweight="bold", color="#1F4E79")


# ── Left panel: per-class F1 across the three sample sizes ──────

def f1_breakdown(y_true, y_pred):
    rep = classification_report(y_true, y_pred, output_dict=True, zero_division=0)
    return [rep["0"]["f1-score"], rep["1"]["f1-score"],
            rep["2"]["f1-score"], rep["weighted avg"]["f1-score"]]

# Collect QSVM F1 vectors at each sample size
f1_q100 = f1_breakdown(Y_te_sub, Y_pred6)
f1_q300 = f1_breakdown(Y_te3,    Y_pred8)
f1_q500 = f1_breakdown(Y_te4,    Y_pred9)

labels = ["Upward", "Downward", "Flat", "Overall"]
x      = np.arange(len(labels))
w      = 0.25   # three bars per group

# Three bars per class group, ordered light-to-dark by sample size
bars = [
    (x - w, f1_q100, "#FADBD8", "QSVM 100"),
    (x,     f1_q300, "#CB4335", "QSVM 300"),
    (x + w, f1_q500, "#922B21", "QSVM 500"),
]
for px, vals, color, lbl in bars:
    bar_set = ax1.bar(px, vals, w, color=color, label=lbl, alpha=0.95)
    # Annotate each bar with its F1 value above it
    for b in bar_set:
        ax1.text(b.get_x() + b.get_width()/2, b.get_height() + 0.012,
                 f"{b.get_height():.2f}", ha="center",
                 fontsize=11, fontweight="bold", color="#333333")

ax1.set_xticks(x, labels=labels, fontsize=12)
ax1.tick_params(axis="y", labelsize=12)
ax1.set_ylim(0, 1.0)
ax1.set_ylabel("F1 Score", fontsize=13)
ax1.set_title("QSVM Per-Class F1 by Sample Size", fontweight="bold")
ax1.legend(fontsize=11, ncol=3, loc="upper center", bbox_to_anchor=(0.5, -0.10))
ax1.grid(True, alpha=0.3, axis="y")


# ── Right panel: QSVM accuracy scaling curve, three points ──────

sizes  = [100, 300, 500]
q_accs = [test_acc6, test_acc8, test_acc9]

ax2.plot(sizes, q_accs, "o-", color="#C0392B", linewidth=3.0,
         markersize=14, label="QSVM Test Accuracy")

# Annotate each point with its accuracy value
for s, q in zip(sizes, q_accs):
    ax2.annotate(f"{q:.3f}", (s, q), xytext=(0, 16), textcoords="offset points",
                 fontsize=14, color="#C0392B", fontweight="bold", ha="center")

# Light green band marks the higher-accuracy region the curve reaches
ax2.axvspan(200, 510, alpha=0.07, color="#1A7A4A")

ax2.tick_params(axis="y", labelsize=12)
ax2.set_xticks(sizes, labels=[f"{s}" for s in sizes], fontsize=12)
ax2.set_xlabel("Training Samples", fontsize=13)
ax2.set_ylabel("Test Accuracy", fontsize=13)
ax2.set_title("QSVM Accuracy vs Training Size", fontweight="bold")
ax2.set_ylim(0.50, max(q_accs) + 0.10)
ax2.legend(fontsize=12, loc="lower right")
ax2.grid(True, alpha=0.3)


plt.tight_layout()
plt.savefig("scaling_qsvm_3point.png", dpi=300, bbox_inches="tight")
plt.show()
print("Figure saved as scaling_qsvm_3point.png")
# Out:
# Figure saved as scaling_qsvm_3point.png
