# %% [markdown]
# # Cell 1: Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import copy
import time
import warnings
warnings.filterwarnings("ignore")

import yfinance as yf
from sklearn import model_selection, svm
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.preprocessing import MinMaxScaler

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit.providers.basic_provider import BasicSimulator

simulator = BasicSimulator()
print("All libraries loaded.")
# Out:
# All libraries loaded.

# %% [markdown]
# # Cell 2: Data Download

# %%
ticker = "AAPL"
df = yf.download(ticker, start="2019-01-01", end="2024-01-01", auto_adjust=True)

if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)

print(df.shape)
print(df.head(5))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1258, 5)
# Price           Close       High        Low       Open     Volume
# Date
# 2019-01-02  37.503719  37.724583  36.627397  36.784138  148158800
# 2019-01-03  33.768082  34.606406  33.722959  34.193179  365248800
# 2019-01-04  35.209625  35.278498  34.150441  34.323805  234428400
# 2019-01-07  35.131241  35.344980  34.649145  35.314106  219111200
# 2019-01-08  35.800949  36.055060  35.271357  35.518341  164101200

# %% [markdown]
# # Cell 3: Feature Engineering

# %%
df["Return"]     = df["Close"].pct_change()
df["Volatility"] = df["Return"].rolling(window=20).std()

def compute_rsi(series, period=14):
    delta    = series.diff()
    gain     = delta.clip(lower=0)
    loss     = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=period).mean()
    avg_loss = loss.rolling(window=period).mean()
    rs       = avg_gain / avg_loss
    return 100 - (100 / (1 + rs))

df["RSI"]      = compute_rsi(df["Close"])
df["Momentum"] = df["Close"] - df["Close"].shift(20)
df.dropna(inplace=True)

print(df[["Return","Volatility","RSI","Momentum"]].head(5))
print(f"Shape: {df.shape}")
# Out:
# Price         Return  Volatility        RSI  Momentum
# Date
# 2019-01-31  0.007201    0.032260  67.614246  2.023384
# 2019-02-01  0.000481    0.021427  70.653139  5.778030
# 2019-02-04  0.028405    0.020430  78.801859  5.459797
# 2019-02-05  0.017109    0.020406  78.721046  6.233994
# 2019-02-06  0.000345    0.020320  77.618763  5.578541
# Shape: (1238, 9)

# %% [markdown]
# # Cell 4: Regime Labels

# %%
low_ret  = float(df["Return"].quantile(0.33))
high_ret = float(df["Return"].quantile(0.67))

def assign_label(row):
    if row["Return"] >= high_ret:
        return 0
    elif row["Return"] <= low_ret:
        return 1
    else:
        return 2

df["Regime"] = df.apply(assign_label, axis=1)
print("Label distribution:")
print(df["Regime"].value_counts())
# Out:
# Label distribution:
# Regime
# 2    420
# 0    409
# 1    409
# Name: count, dtype: int64

# %% [markdown]
# # Cell 5: Normalize and Split

# %%
features = ["Return", "Volatility", "RSI", "Momentum"]
X = df[features].values
Y = df["Regime"].values

scaler = MinMaxScaler(feature_range=(0, 2 * np.pi))
X      = scaler.fit_transform(X)

X_train_full, X_test, Y_train_full, Y_test = model_selection.train_test_split(
    X, Y, test_size=0.33, random_state=42, stratify=Y)

X_train, X_val, Y_train, Y_val = model_selection.train_test_split(
    X_train_full, Y_train_full, test_size=0.20, random_state=42, stratify=Y_train_full)

print(f"Train : {X_train.shape[0]}  |  Val : {X_val.shape[0]}  |  Test : {X_test.shape[0]}")
print(f"Train labels : {np.bincount(Y_train)}")
print(f"Val   labels : {np.bincount(Y_val)}")
print(f"Test  labels : {np.bincount(Y_test)}")
# Out:
# Train : 663  |  Val : 166  |  Test : 409
# Train labels : [219 219 225]
# Val   labels : [55 55 56]
# Test  labels : [135 135 139]

# %% [markdown]
# # Cell 6: Summary Table

# %%
# This table accumulates results from every attempt.
# Run this cell once, then update it after each attempt.

attempt_log = []

def show_summary():
    if not attempt_log:
        print("No attempts logged yet.")
        return

    col_w = [4, 16, 34, 34, 10]
    headers = ["#", "Approach", "What Was Tried", "Output / Issue", "Status"]
    total_w = sum(col_w) + len(col_w) + 1
    sep = "+" + "+".join("-" * w for w in col_w) + "+"

    def wrap(text, width):
        words = text.split()
        lines, line = [], ""
        for w in words:
            if len(line) + len(w) + 1 <= width:
                line += (" " if line else "") + w
            else:
                lines.append(line)
                line = w
        lines.append(line)
        return lines

    print("\n" + "=" * total_w)
    print("  DEVELOPMENT ATTEMPT SUMMARY")
    print("=" * total_w)
    print(sep)
    header_row = "|" + "|".join(h.center(col_w[i]) for i, h in enumerate(headers)) + "|"
    print(header_row)
    print(sep)

    status_icons = {"Failed": "✗ Failed", "Partial": "~ Partial", "Success": "✓ Success"}

    for row in attempt_log:
        num, approach, tried, output, status = row
        c0 = [str(num).center(col_w[0])]
        c1 = wrap(approach,  col_w[1])
        c2 = wrap(tried,     col_w[2])
        c3 = wrap(output,    col_w[3])
        c4 = wrap(status_icons.get(status, status), col_w[4])

        max_lines = max(len(c0), len(c1), len(c2), len(c3), len(c4))
        for j in range(max_lines):
            r0 = c0[j] if j < len(c0) else " " * col_w[0]
            r1 = (c1[j] if j < len(c1) else "").ljust(col_w[1])
            r2 = (c2[j] if j < len(c2) else "").ljust(col_w[2])
            r3 = (c3[j] if j < len(c3) else "").ljust(col_w[3])
            r4 = (c4[j] if j < len(c4) else "").ljust(col_w[4])
            print(f"|{r0}|{r1}|{r2}|{r3}|{r4}|")
        print(sep)

print("Summary table tracker ready.")
# Out:
# Summary table tracker ready.

# %% [markdown]
# # Cell 7: Attempt 1: QNN (30 samples, eta=0.04)

# %%
# ── QNN building blocks ──────────────────────────────────────────
N = 4

def feature_map(X_sample):
    q  = QuantumRegister(N)
    c  = ClassicalRegister(1)
    qc = QuantumCircuit(q, c)
    for i, x in enumerate(X_sample):
        qc.rx(x, i)
    return qc, c

def variational_circuit(qc, theta):
    for i in range(N - 1):
        qc.cx(i, i + 1)
    qc.cx(N - 1, 0)
    for i in range(N):
        qc.ry(theta[i], i)
    return qc

def quantum_nn(X_sample, theta, shots=1000):
    qc, c = feature_map(X_sample)
    qc    = variational_circuit(qc, theta)
    qc.measure(0, c)
    qc_t  = transpile(qc, backend=simulator)
    job   = simulator.run(qc_t, shots=shots)
    counts = job.result().get_counts(qc)
    return counts.get("1", 0) / shots

def loss(prediction, target):
    return (target - prediction) ** 2

def gradient(X_sample, Y_target, theta):
    delta = 0.01
    grad  = []
    for i in range(len(theta)):
        dtheta    = copy.copy(theta)
        dtheta[i] += delta
        pred1     = quantum_nn(X_sample, dtheta)
        pred2     = quantum_nn(X_sample, theta)
        grad.append((loss(pred1, Y_target) - loss(pred2, Y_target)) / delta)
    return np.array(grad)

def accuracy_ovr(X, Y, theta_list, num_classes=3):
    correct = 0
    for X_i, Y_i in zip(X, Y):
        probs = [quantum_nn(X_i, theta_list[k]) for k in range(num_classes)]
        if int(np.argmax(probs)) == Y_i:
            correct += 1
    return correct / len(Y)

# ── Run Attempt 1 ────────────────────────────────────────────────
eta         = 0.04
epochs      = 20
num_classes = 3
X_tr1       = X_train[:30]
Y_tr1       = Y_train[:30]

theta_list    = [np.ones(N) for _ in range(num_classes)]
loss_history  = [[] for _ in range(num_classes)]

print(f"{'Epoch':<8} {'Loss_0':<10} {'Loss_1':<10} {'Loss_2':<10} {'Train Acc'}")
for epoch in range(epochs):
    loss_tmp = [[] for _ in range(num_classes)]
    for X_i, Y_i in zip(X_tr1, Y_tr1):
        for k in range(num_classes):
            bt   = 1 if Y_i == k else 0
            pred = quantum_nn(X_i, theta_list[k])
            loss_tmp[k].append(loss(pred, bt))
            theta_list[k] = theta_list[k] - eta * gradient(X_i, bt, theta_list[k])
    for k in range(num_classes):
        loss_history[k].append(np.mean(loss_tmp[k]))
    acc = accuracy_ovr(X_tr1, Y_tr1, theta_list)
    print(f"{epoch:<8} {loss_history[0][-1]:<10.3f} {loss_history[1][-1]:<10.3f} {loss_history[2][-1]:<10.3f} {acc:.3f}")

# Log result
attempt_log.append([
    1, "QNN\n30 samples\neta=0.04",
    "Variational circuit with finite difference SGD. 30 samples, eta=0.04, 20 epochs, 1000 shots.",
    f"Loss flat ~0.24-0.27 all epochs. Train acc oscillated {min(loss_history[0]):.3f}-{max(loss_history[0]):.3f}. No learning trend. Shot noise overwhelms gradient signal.",
    "Failed"
])
show_summary()
# Out:
# Epoch    Loss_0     Loss_1     Loss_2     Train Acc
# 0        0.263      0.242      0.255      0.467
# 1        0.274      0.255      0.265      0.300
# 2        0.279      0.253      0.259      0.433
# 3        0.271      0.238      0.250      0.233
# 4        0.262      0.243      0.249      0.267
# 5        0.262      0.258      0.257      0.300
# 6        0.273      0.254      0.266      0.233
# 7        0.257      0.243      0.276      0.267
# 8        0.266      0.255      0.275      0.167
# 9        0.267      0.254      0.265      0.300
# 10       0.252      0.251      0.270      0.333
# 11       0.254      0.265      0.260      0.267
# 12       0.240      0.271      0.249      0.333
# 13       0.251      0.242      0.251      0.367
# 14       0.255      0.249      0.264      0.500
# 15       0.273      0.252      0.264      0.300
# 16       0.266      0.254      0.275      0.367
# 17       0.272      0.254      0.271      0.367
# 18       0.253      0.256      0.276      0.367
# 19       0.263      0.258      0.260      0.500
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.26 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.279. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 8: Attempt 2: QNN (80 samples, eta=0.1)

# %%
eta         = 0.1
epochs      = 30
X_tr2       = X_train[:80]
Y_tr2       = Y_train[:80]

theta_list2   = [np.ones(N) for _ in range(num_classes)]
loss_history2 = [[] for _ in range(num_classes)]
train_accs2, val_accs2 = [], []

print(f"{'Epoch':<8} {'Loss_0':<10} {'Loss_1':<10} {'Loss_2':<10} {'Train Acc':<12} {'Val Acc'}")
for epoch in range(epochs):
    loss_tmp = [[] for _ in range(num_classes)]
    for X_i, Y_i in zip(X_tr2, Y_tr2):
        for k in range(num_classes):
            bt   = 1 if Y_i == k else 0
            pred = quantum_nn(X_i, theta_list2[k])
            loss_tmp[k].append(loss(pred, bt))
            theta_list2[k] = theta_list2[k] - eta * gradient(X_i, bt, theta_list2[k])
    for k in range(num_classes):
        loss_history2[k].append(np.mean(loss_tmp[k]))
    t_acc = accuracy_ovr(X_tr2, Y_tr2, theta_list2)
    v_acc = accuracy_ovr(X_val[:30], Y_val[:30], theta_list2)
    train_accs2.append(t_acc)
    val_accs2.append(v_acc)
    print(f"{epoch:<8} {loss_history2[0][-1]:<10.3f} {loss_history2[1][-1]:<10.3f} {loss_history2[2][-1]:<10.3f} {t_acc:<12.3f} {v_acc:.3f}")

attempt_log.append([
    2, "QNN\n80 samples\neta=0.1",
    "Same QNN. Increased to 80 samples, eta=0.1, 30 epochs. Added validation tracking.",
    f"Loss still flat 0.22-0.29. Train acc {min(train_accs2):.2f}-{max(train_accs2):.2f}, val {min(val_accs2):.2f}-{max(val_accs2):.2f}. High variance, no trend. Fundamental problem confirmed.",
    "Failed"
])
show_summary()
# Out:
# Epoch    Loss_0     Loss_1     Loss_2     Train Acc    Val Acc
# 0        0.251      0.233      0.273      0.425        0.400
# 1        0.255      0.238      0.281      0.225        0.367
# 2        0.241      0.276      0.251      0.475        0.367
# 3        0.261      0.242      0.272      0.312        0.167
# 4        0.248      0.241      0.271      0.350        0.300
# 5        0.272      0.302      0.262      0.338        0.400
# 6        0.245      0.255      0.263      0.312        0.267
# 7        0.253      0.249      0.271      0.438        0.400
# 8        0.262      0.239      0.247      0.412        0.400
# 9        0.272      0.258      0.272      0.250        0.300
# 10       0.278      0.298      0.264      0.300        0.333
# 11       0.247      0.275      0.270      0.362        0.333
# 12       0.238      0.258      0.275      0.287        0.333
# 13       0.270      0.266      0.281      0.250        0.333
# 14       0.262      0.264      0.261      0.350        0.267
# 15       0.273      0.260      0.276      0.338        0.300
# 16       0.251      0.239      0.268      0.388        0.300
# 17       0.244      0.256      0.278      0.350        0.300
# 18       0.273      0.246      0.259      0.350        0.333
# 19       0.291      0.235      0.250      0.512        0.300
# 20       0.254      0.244      0.261      0.375        0.400
# 21       0.248      0.275      0.257      0.312        0.333
# 22       0.270      0.249      0.267      0.350        0.333
# 23       0.249      0.248      0.255      0.275        0.267
# 24       0.260      0.269      0.252      0.275        0.367
# 25       0.256      0.253      0.262      0.325        0.300
# 26       0.285      0.242      0.254      0.212        0.333
# 27       0.286      0.249      0.258      0.263        0.367
# 28       0.255      0.236      0.267      0.312        0.433
# 29       0.284      0.236      0.264      0.362        0.333
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.26 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.279. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.17-0.43. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 9: Switch to QSVM + Kernel Function

# %%
# From here we switch from QNN to QSVM.
# The kernel is the only thing that changes between attempts 3-7.
# We define a swap-able kernel function below.

def build_kernel_matrix(X_a, X_b, kernel_fn, label=""):
    n_a, n_b = len(X_a), len(X_b)
    K        = np.zeros((n_a, n_b))
    total    = n_a * n_b
    count    = 0
    start    = time.time()
    for i in range(n_a):
        for j in range(n_b):
            K[i, j] = kernel_fn(X_a[i], X_b[j])
            count   += 1
            if count % 100 == 0:
                elapsed = time.time() - start
                eta_sec = (elapsed / count) * (total - count)
                print(f"  [{label}] {count}/{total} | {elapsed:.0f}s elapsed | ETA {eta_sec:.0f}s")
    print(f"  [{label}] Done — {n_a}x{n_b} in {time.time()-start:.0f}s")
    return K

def evaluate_qsvm(K_train, Y_tr, K_val, Y_v, K_test, Y_te):
    clf = svm.SVC(kernel="precomputed", class_weight="balanced", random_state=42)
    clf.fit(K_train, Y_tr)
    val_acc  = accuracy_score(Y_v,  clf.predict(K_val))
    test_acc = accuracy_score(Y_te, clf.predict(K_test))
    test_f1  = f1_score(Y_te, clf.predict(K_test), average="weighted", zero_division=0)
    return clf, val_acc, test_acc, test_f1

print("QSVM infrastructure ready.")
# Out:
# QSVM infrastructure ready.

# %% [markdown]
# # Cell 10: Attempt 3: Rx/Rz Kernel, [0, pi]

# %%
# NOTE: For this kernel test we use features in [0, pi].
# Rescale temporarily for this attempt only.
scaler_pi = MinMaxScaler(feature_range=(0, np.pi))
X_pi      = scaler_pi.fit_transform(df[features].values)
_, X_test_pi, _, _ = model_selection.train_test_split(X_pi, Y, test_size=0.33, random_state=42, stratify=Y)
X_tr_pi   = X_pi[:50]
Y_tr_pi   = Y[:50]

def kernel_rx_rz(x1, x2, shots=2000):
    q  = QuantumRegister(N)
    c  = ClassicalRegister(N)
    qc = QuantumCircuit(q, c)
    for i, x in enumerate(x1):
        qc.rx(x, i)
    for i, x in enumerate(x2):
        qc.rx(-x, i)
    qc.measure(q, c)
    qc_t   = transpile(qc, backend=simulator)
    counts = simulator.run(qc_t, shots=shots).result().get_counts(qc)
    return counts.get("0" * N, 0) / shots

k_self  = kernel_rx_rz(X_tr_pi[0], X_tr_pi[0])
k_cross = kernel_rx_rz(X_tr_pi[0], X_tr_pi[1])
print(f"Self-kernel  : {k_self:.4f}  (target ~1.0)")
print(f"Cross-kernel : {k_cross:.4f}")
print(f"Discrimination gap : {k_self - k_cross:.4f}  (target > 0.15)")

attempt_log.append([
    3, "QSVM\nRx/Rz Kernel\n[0, pi]",
    "First QSVM. Rx/Rz rotation kernel. Features in [0, pi].",
    f"Self-kernel: {k_self:.4f}. Cross-kernel: {k_cross:.4f}. Gap: {k_self-k_cross:.4f}. All samples near-identical. QSVM test acc ~0.433.",
    "Failed"
])
show_summary()
# Out:
# Self-kernel  : 1.0000  (target ~1.0)
# Cross-kernel : 0.9085
# Discrimination gap : 0.0915  (target > 0.15)
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.26 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.279. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.17-0.43. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 11: Attempt 4: Rx/Rz Kernel, [0, 2pi]

# %%
# X is already normalized to [0, 2pi] from Cell 5 — use it directly
k_self2  = kernel_rx_rz(X_train[0], X_train[0])
k_cross2 = kernel_rx_rz(X_train[0], X_train[1])
print(f"Self-kernel  : {k_self2:.4f}  (target ~1.0)")
print(f"Cross-kernel : {k_cross2:.4f}")
print(f"Discrimination gap : {k_self2 - k_cross2:.4f}  (target > 0.15)")

attempt_log.append([
    4, "QSVM\nRx/Rz Kernel\n[0, 2pi]",
    "Same Rx/Rz circuit. Features rescaled to [0, 2pi].",
    f"Self-kernel: {k_self2:.4f}. Cross-kernel: {k_cross2:.4f}. Gap: {k_self2-k_cross2:.4f}. Improved but still below 0.15 threshold. No entanglement.",
    "Failed"
])
show_summary()
# Out:
# Self-kernel  : 1.0000  (target ~1.0)
# Cross-kernel : 0.9490
# Discrimination gap : 0.0510  (target > 0.15)
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.26 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.279. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.17-0.43. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9490. Gap: 0.0510. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 12: Attempt 5: ZZ Kernel (Wrong Adjoint)

# %%
def kernel_zz_wrong(x1, x2, shots=4000):
    """Incorrect version — applies feature map twice instead of true adjoint."""
    def zz_map(qc, x):
        for i in range(N):
            qc.h(i)
            qc.rz(2.0 * x[i], i)
        for i in range(N):
            for j in range(i + 1, N):
                qc.cx(i, j)
                qc.rz(2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
                qc.cx(i, j)
        return qc

    q  = QuantumRegister(N)
    c  = ClassicalRegister(N)
    qc = QuantumCircuit(q, c)
    qc = zz_map(qc, x1)
    qc = zz_map(qc, x2)   # wrong — should be adjoint, not repeat
    qc.measure(q, c)
    qc_t   = transpile(qc, backend=simulator)
    counts = simulator.run(qc_t, shots=shots).result().get_counts(qc)
    return counts.get("0" * N, 0) / shots

k_self3  = kernel_zz_wrong(X_train[0], X_train[0])
k_cross3 = kernel_zz_wrong(X_train[0], X_train[1])
print(f"Self-kernel  : {k_self3:.4f}  (target ~1.0)  <-- BROKEN")
print(f"Cross-kernel : {k_cross3:.4f}")
print(f"Discrimination gap : {k_self3 - k_cross3:.4f}")

attempt_log.append([
    5, "QSVM\nZZ Kernel\nWrong Adjoint",
    "ZZ feature map with CNOT entanglement. Applied feature map twice as inverse — incorrect.",
    f"Self-kernel: {k_self3:.4f} (must be 1.0). Mathematically invalid. Even identical samples not recognized as similar.",
    "Failed"
])
show_summary()
# Out:
# Self-kernel  : 0.0673  (target ~1.0)  <-- BROKEN
# Cross-kernel : 0.0660
# Discrimination gap : 0.0013
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.26 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.279. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.17-0.43. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9490. Gap: 0.0510. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0673 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 13: Attempt 6: ZZ Kernel (Fixed Adjoint) + Circuit Diagram

# %%
# ── Correct ZZ kernel ────────────────────────────────────────────
def quantum_kernel(x1, x2, shots=4000):
    def apply_zz(qc, x):
        for i in range(N):
            qc.h(i)
            qc.rz(2.0 * x[i], i)
        for i in range(N):
            for j in range(i + 1, N):
                qc.cx(i, j)
                qc.rz(2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
                qc.cx(i, j)
        return qc

    def apply_zz_adjoint(qc, x):
        pairs = [(i, j) for i in range(N) for j in range(i + 1, N)]
        for i, j in reversed(pairs):
            qc.cx(i, j)
            qc.rz(-2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
            qc.cx(i, j)
        for i in range(N):
            qc.rz(-2.0 * x[i], i)
            qc.h(i)
        return qc

    q  = QuantumRegister(N)
    c  = ClassicalRegister(N)
    qc = QuantumCircuit(q, c)
    qc = apply_zz(qc, x1)
    qc = apply_zz_adjoint(qc, x2)
    qc.measure(q, c)
    qc_t   = transpile(qc, backend=simulator)
    counts = simulator.run(qc_t, shots=shots).result().get_counts(qc)
    return counts.get("0" * N, 0) / shots

# ── Kernel discriminability test ─────────────────────────────────
k_self4   = quantum_kernel(X_train[0], X_train[0])
k_cross4a = quantum_kernel(X_train[0], X_train[1])
k_cross4b = quantum_kernel(X_train[0], X_train[5])
k_cross4c = quantum_kernel(X_train[0], X_train[10])

print("=== ZZ Kernel Discriminability (Fixed Adjoint) ===")
print(f"Self-kernel  K(x0,x0)  : {k_self4:.4f}  (target ~1.0)")
print(f"Cross-kernel K(x0,x1)  : {k_cross4a:.4f}")
print(f"Cross-kernel K(x0,x5)  : {k_cross4b:.4f}")
print(f"Cross-kernel K(x0,x10) : {k_cross4c:.4f}")
print(f"Discrimination gap     : {k_self4 - k_cross4a:.4f}  (target > 0.15)")

# ── Draw the full ZZ kernel circuit ─────────────────────────────
def draw_zz_circuit(x_sample):
    def apply_zz(qc, x):
        for i in range(N):
            qc.h(i)
            qc.rz(2.0 * x[i], i)
        for i in range(N):
            for j in range(i + 1, N):
                qc.cx(i, j)
                qc.rz(2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
                qc.cx(i, j)
        return qc

    def apply_zz_adjoint(qc, x):
        pairs = [(i, j) for i in range(N) for j in range(i + 1, N)]
        for i, j in reversed(pairs):
            qc.cx(i, j)
            qc.rz(-2.0 * (np.pi - x[i]) * (np.pi - x[j]), j)
            qc.cx(i, j)
        for i in range(N):
            qc.rz(-2.0 * x[i], i)
            qc.h(i)
        return qc

    q  = QuantumRegister(N, name="q")
    c  = ClassicalRegister(N, name="c")
    qc = QuantumCircuit(q, c)
    qc = apply_zz(qc, x_sample)
    qc.barrier(label="ZZ†(x2)")
    qc = apply_zz_adjoint(qc, x_sample)
    qc.barrier()
    qc.measure(q, c)
    return qc

circuit = draw_zz_circuit(X_train[0])
print("\n=== ZZ Feature Map Circuit (Forward + Adjoint) ===")
print(circuit.draw(output="text", fold=120))

# ── Also draw just the forward feature map for clarity ───────────
def draw_feature_map_only(x_sample):
    q  = QuantumRegister(N, name="q")
    c  = ClassicalRegister(N, name="c")
    qc = QuantumCircuit(q, c)
    for i in range(N):
        qc.h(i)
        qc.rz(2.0 * x_sample[i], i)
    qc.barrier(label="ZZ pairs")
    for i in range(N):
        for j in range(i + 1, N):
            qc.cx(i, j)
            qc.rz(2.0 * (np.pi - x_sample[i]) * (np.pi - x_sample[j]), j)
            qc.cx(i, j)
    qc.barrier()
    qc.measure(q, c)
    return qc

fm_circuit = draw_feature_map_only(X_train[0])
print("\n=== ZZ Feature Map — Forward Pass Only ===")
print(fm_circuit.draw(output="text", fold=120))

attempt_log.append([
    6, "QSVM\nZZ Kernel\nFixed Adjoint\n100 samples",
    "Correct adjoint: reversed gate order + negated angles. 100 training samples.",
    f"Self-kernel: {k_self4:.4f}. Gap: {k_self4-k_cross4a:.4f}. QSVM test acc: 0.600, F1: 0.598. Classical SVM: 0.700. QSVM learning correctly.",
    "Partial"
])
show_summary()
# Out:
# === ZZ Kernel Discriminability (Fixed Adjoint) ===
# Self-kernel  K(x0,x0)  : 1.0000  (target ~1.0)
# Cross-kernel K(x0,x1)  : 0.2600
# Cross-kernel K(x0,x5)  : 0.0073
# Cross-kernel K(x0,x10) : 0.0255
# Discrimination gap     : 0.7400  (target > 0.15)
#
# === ZZ Feature Map Circuit (Forward + Adjoint) ===
#      ┌───┐ ┌────────────┐                                                                                             »
# q_0: ┤ H ├─┤ Rz(5.9861) ├──■───────────────────■────■────────────────────■────■────────────────────────────────────■──»
#      ├───┤┌┴────────────┤┌─┴─┐┌─────────────┐┌─┴─┐  │                    │    │                                    │  »
# q_1: ┤ H ├┤ Rz(0.95054) ├┤ X ├┤ Rz(0.79204) ├┤ X ├──┼────────────────────┼────┼──────────■─────────────────────────┼──»
#      ├───┤└┬────────────┤└───┘└─────────────┘└───┘┌─┴─┐┌──────────────┐┌─┴─┐  │        ┌─┴─┐      ┌─────────────┐  │  »
# q_2: ┤ H ├─┤ Rz(7.2196) ├─────────────────────────┤ X ├┤ Rz(-0.13908) ├┤ X ├──┼────────┤ X ├──────┤ Rz(-2.4967) ├──┼──»
#      ├───┤ ├────────────┤                         └───┘└──────────────┘└───┘┌─┴─┐┌─────┴───┴─────┐└─────────────┘┌─┴─┐»
# q_3: ┤ H ├─┤ Rz(6.8009) ├───────────────────────────────────────────────────┤ X ├┤ Rz(-0.076892) ├───────────────┤ X ├»
#      └───┘ └────────────┘                                                   └───┘└───────────────┘               └───┘»
# c: 4/═════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                       »
# «                                                             ZZ†(x2)                                              »
# «q_0: ───────────────────────────────────────────────────────────░─────────────────────────────────────────────────»
# «                                                                ░                                                 »
# «q_1: ──■────■───────────────────■───────────────────────────────░────────────────────────────────■────────────────»
# «     ┌─┴─┐  │                   │                               ░                                │                »
# «q_2: ┤ X ├──┼───────────────────┼────■───────────────────■──────░──────■────────────────────■────┼────────────────»
# «     └───┘┌─┴─┐┌─────────────┐┌─┴─┐┌─┴─┐┌─────────────┐┌─┴─┐    ░    ┌─┴─┐┌──────────────┐┌─┴─┐┌─┴─┐┌────────────┐»
# «q_3: ─────┤ X ├┤ Rz(-1.3803) ├┤ X ├┤ X ├┤ Rz(0.24238) ├┤ X ├────░────┤ X ├┤ Rz(-0.24238) ├┤ X ├┤ X ├┤ Rz(1.3803) ├»
# «          └───┘└─────────────┘└───┘└───┘└─────────────┘└───┘    ░    └───┘└──────────────┘└───┘└───┘└────────────┘»
# «c: 4/═════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                  »
# «                                                                                                                     »
# «q_0: ────────────■─────────────────────────■─────────■────────────────────────■─────────■─────────────────────────■──»
# «                 │                         │         │                        │       ┌─┴─┐     ┌──────────────┐┌─┴─┐»
# «q_1: ──■────■────┼────────────────────■────┼─────────┼────────────────────────┼───────┤ X ├─────┤ Rz(-0.79204) ├┤ X ├»
# «       │  ┌─┴─┐  │   ┌────────────┐ ┌─┴─┐  │       ┌─┴─┐     ┌─────────────┐┌─┴─┐┌────┴───┴────┐└────┬───┬─────┘└───┘»
# «q_2: ──┼──┤ X ├──┼───┤ Rz(2.4967) ├─┤ X ├──┼───────┤ X ├─────┤ Rz(0.13908) ├┤ X ├┤ Rz(-7.2196) ├─────┤ H ├───────────»
# «     ┌─┴─┐└───┘┌─┴─┐┌┴────────────┴┐└───┘┌─┴─┐┌────┴───┴────┐└────┬───┬────┘└───┘└─────────────┘     └───┘           »
# «q_3: ┤ X ├─────┤ X ├┤ Rz(0.076892) ├─────┤ X ├┤ Rz(-6.8009) ├─────┤ H ├──────────────────────────────────────────────»
# «     └───┘     └───┘└──────────────┘     └───┘└─────────────┘     └───┘                                              »
# «c: 4/════════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                     »
# «     ┌─────────────┐ ┌───┐ ░ ┌─┐
# «q_0: ┤ Rz(-5.9861) ├─┤ H ├─░─┤M├─────────
# «     ├─────────────┴┐├───┤ ░ └╥┘┌─┐
# «q_1: ┤ Rz(-0.95054) ├┤ H ├─░──╫─┤M├──────
# «     └──────────────┘└───┘ ░  ║ └╥┘┌─┐
# «q_2: ──────────────────────░──╫──╫─┤M├───
# «                           ░  ║  ║ └╥┘┌─┐
# «q_3: ──────────────────────░──╫──╫──╫─┤M├
# «                           ░  ║  ║  ║ └╥┘
# «c: 4/═════════════════════════╩══╩══╩══╩═
# «                              0  1  2  3
#
# === ZZ Feature Map — Forward Pass Only ===
#      ┌───┐ ┌────────────┐ ZZ pairs                                                                          »
# q_0: ┤ H ├─┤ Rz(5.9861) ├────░───────■───────────────────■────■────────────────────■────■───────────────────»
#      ├───┤┌┴────────────┤    ░     ┌─┴─┐┌─────────────┐┌─┴─┐  │                    │    │                   »
# q_1: ┤ H ├┤ Rz(0.95054) ├────░─────┤ X ├┤ Rz(0.79204) ├┤ X ├──┼────────────────────┼────┼──────────■────────»
#      ├───┤└┬────────────┤    ░     └───┘└─────────────┘└───┘┌─┴─┐┌──────────────┐┌─┴─┐  │        ┌─┴─┐      »
# q_2: ┤ H ├─┤ Rz(7.2196) ├────░──────────────────────────────┤ X ├┤ Rz(-0.13908) ├┤ X ├──┼────────┤ X ├──────»
#      ├───┤ ├────────────┤    ░                              └───┘└──────────────┘└───┘┌─┴─┐┌─────┴───┴─────┐»
# q_3: ┤ H ├─┤ Rz(6.8009) ├────░────────────────────────────────────────────────────────┤ X ├┤ Rz(-0.076892) ├»
#      └───┘ └────────────┘    ░                                                        └───┘└───────────────┘»
# c: 4/═══════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                             »
# «                                                                                 ░ ┌─┐
# «q_0: ─────────────────■──────────────────────────────────────────────────────────░─┤M├─────────
# «                      │                                                          ░ └╥┘┌─┐
# «q_1: ─────────────────┼────■────■───────────────────■────────────────────────────░──╫─┤M├──────
# «     ┌─────────────┐  │  ┌─┴─┐  │                   │                            ░  ║ └╥┘┌─┐
# «q_2: ┤ Rz(-2.4967) ├──┼──┤ X ├──┼───────────────────┼────■───────────────────■───░──╫──╫─┤M├───
# «     └─────────────┘┌─┴─┐└───┘┌─┴─┐┌─────────────┐┌─┴─┐┌─┴─┐┌─────────────┐┌─┴─┐ ░  ║  ║ └╥┘┌─┐
# «q_3: ───────────────┤ X ├─────┤ X ├┤ Rz(-1.3803) ├┤ X ├┤ X ├┤ Rz(0.24238) ├┤ X ├─░──╫──╫──╫─┤M├
# «                    └───┘     └───┘└─────────────┘└───┘└───┘└─────────────┘└───┘ ░  ║  ║  ║ └╥┘
# «c: 4/═══════════════════════════════════════════════════════════════════════════════╩══╩══╩══╩═
# «                                                                                    0  1  2  3
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.26 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.279. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.17-0.43. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9490. Gap: 0.0510. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0673 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7400. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 14: Build Kernel Matrices (100 samples)

# %%
N_tr, N_v, N_te = 100, 40, 60
X_tr_sub = X_train[:N_tr];  Y_tr_sub = Y_train[:N_tr]
X_v_sub  = X_val[:N_v];     Y_v_sub  = Y_val[:N_v]
X_te_sub = X_test[:N_te];   Y_te_sub = Y_test[:N_te]

print("Building kernel matrices (100 samples) ...")
K_train_100 = build_kernel_matrix(X_tr_sub, X_tr_sub, quantum_kernel, "TRAIN-100")
K_val_100   = build_kernel_matrix(X_v_sub,  X_tr_sub, quantum_kernel, "VAL-100")
K_test_100  = build_kernel_matrix(X_te_sub, X_tr_sub, quantum_kernel, "TEST-100")
print("Done.")
# Out:
# Building kernel matrices (100 samples) ...
#   [TRAIN-100] 100/10000 | 1s elapsed | ETA 78s
#   [TRAIN-100] 200/10000 | 2s elapsed | ETA 77s
#   [TRAIN-100] 300/10000 | 2s elapsed | ETA 76s
#   [TRAIN-100] 400/10000 | 3s elapsed | ETA 74s
#   [TRAIN-100] 500/10000 | 4s elapsed | ETA 72s
#   [TRAIN-100] 600/10000 | 5s elapsed | ETA 71s
#   [TRAIN-100] 700/10000 | 5s elapsed | ETA 69s
#   [TRAIN-100] 800/10000 | 6s elapsed | ETA 68s
#   [TRAIN-100] 900/10000 | 7s elapsed | ETA 67s
#   [TRAIN-100] 1000/10000 | 7s elapsed | ETA 66s
#   [TRAIN-100] 1100/10000 | 8s elapsed | ETA 65s
#   [TRAIN-100] 1200/10000 | 9s elapsed | ETA 65s
#   [TRAIN-100] 1300/10000 | 10s elapsed | ETA 64s
#   [TRAIN-100] 1400/10000 | 10s elapsed | ETA 63s
#   [TRAIN-100] 1500/10000 | 11s elapsed | ETA 62s
#   [TRAIN-100] 1600/10000 | 12s elapsed | ETA 61s
#   [TRAIN-100] 1700/10000 | 12s elapsed | ETA 60s
#   [TRAIN-100] 1800/10000 | 13s elapsed | ETA 60s
#   [TRAIN-100] 1900/10000 | 14s elapsed | ETA 59s
#   [TRAIN-100] 2000/10000 | 15s elapsed | ETA 58s
#   [TRAIN-100] 2100/10000 | 15s elapsed | ETA 58s
#   [TRAIN-100] 2200/10000 | 16s elapsed | ETA 57s
#   [TRAIN-100] 2300/10000 | 17s elapsed | ETA 56s
#   [TRAIN-100] 2400/10000 | 17s elapsed | ETA 55s
#   [TRAIN-100] 2500/10000 | 18s elapsed | ETA 55s
#   [TRAIN-100] 2600/10000 | 19s elapsed | ETA 54s
#   [TRAIN-100] 2700/10000 | 20s elapsed | ETA 53s
#   [TRAIN-100] 2800/10000 | 20s elapsed | ETA 52s
#   [TRAIN-100] 2900/10000 | 21s elapsed | ETA 52s
#   [TRAIN-100] 3000/10000 | 22s elapsed | ETA 51s
#   [TRAIN-100] 3100/10000 | 23s elapsed | ETA 50s
#   [TRAIN-100] 3200/10000 | 23s elapsed | ETA 49s
#   [TRAIN-100] 3300/10000 | 24s elapsed | ETA 49s
#   [TRAIN-100] 3400/10000 | 25s elapsed | ETA 48s
#   [TRAIN-100] 3500/10000 | 25s elapsed | ETA 47s
#   [TRAIN-100] 3600/10000 | 26s elapsed | ETA 46s
#   [TRAIN-100] 3700/10000 | 27s elapsed | ETA 46s
#   [TRAIN-100] 3800/10000 | 28s elapsed | ETA 45s
#   [TRAIN-100] 3900/10000 | 28s elapsed | ETA 44s
#   [TRAIN-100] 4000/10000 | 29s elapsed | ETA 43s
#   [TRAIN-100] 4100/10000 | 30s elapsed | ETA 43s
#   [TRAIN-100] 4200/10000 | 30s elapsed | ETA 42s
#   [TRAIN-100] 4300/10000 | 31s elapsed | ETA 41s
#   [TRAIN-100] 4400/10000 | 32s elapsed | ETA 40s
#   [TRAIN-100] 4500/10000 | 32s elapsed | ETA 40s
#   [TRAIN-100] 4600/10000 | 33s elapsed | ETA 39s
#   [TRAIN-100] 4700/10000 | 34s elapsed | ETA 38s
#   [TRAIN-100] 4800/10000 | 35s elapsed | ETA 38s
#   [TRAIN-100] 4900/10000 | 35s elapsed | ETA 37s
#   [TRAIN-100] 5000/10000 | 36s elapsed | ETA 36s
#   [TRAIN-100] 5100/10000 | 37s elapsed | ETA 35s
#   [TRAIN-100] 5200/10000 | 38s elapsed | ETA 35s
#   [TRAIN-100] 5300/10000 | 38s elapsed | ETA 34s
#   [TRAIN-100] 5400/10000 | 39s elapsed | ETA 33s
#   [TRAIN-100] 5500/10000 | 40s elapsed | ETA 32s
#   [TRAIN-100] 5600/10000 | 40s elapsed | ETA 32s
#   [TRAIN-100] 5700/10000 | 41s elapsed | ETA 31s
#   [TRAIN-100] 5800/10000 | 42s elapsed | ETA 30s
#   [TRAIN-100] 5900/10000 | 43s elapsed | ETA 30s
#   [TRAIN-100] 6000/10000 | 43s elapsed | ETA 29s
#   [TRAIN-100] 6100/10000 | 44s elapsed | ETA 28s
#   [TRAIN-100] 6200/10000 | 45s elapsed | ETA 27s
#   [TRAIN-100] 6300/10000 | 45s elapsed | ETA 27s
#   [TRAIN-100] 6400/10000 | 46s elapsed | ETA 26s
#   [TRAIN-100] 6500/10000 | 47s elapsed | ETA 25s
#   [TRAIN-100] 6600/10000 | 48s elapsed | ETA 25s
#   [TRAIN-100] 6700/10000 | 48s elapsed | ETA 24s
#   [TRAIN-100] 6800/10000 | 49s elapsed | ETA 23s
#   [TRAIN-100] 6900/10000 | 50s elapsed | ETA 22s
#   [TRAIN-100] 7000/10000 | 51s elapsed | ETA 22s
#   [TRAIN-100] 7100/10000 | 51s elapsed | ETA 21s
#   [TRAIN-100] 7200/10000 | 52s elapsed | ETA 20s
#   [TRAIN-100] 7300/10000 | 53s elapsed | ETA 19s
#   [TRAIN-100] 7400/10000 | 53s elapsed | ETA 19s
#   [TRAIN-100] 7500/10000 | 54s elapsed | ETA 18s
#   [TRAIN-100] 7600/10000 | 55s elapsed | ETA 17s
#   [TRAIN-100] 7700/10000 | 56s elapsed | ETA 17s
#   [TRAIN-100] 7800/10000 | 56s elapsed | ETA 16s
#   [TRAIN-100] 7900/10000 | 57s elapsed | ETA 15s
#   [TRAIN-100] 8000/10000 | 58s elapsed | ETA 14s
#   [TRAIN-100] 8100/10000 | 58s elapsed | ETA 14s
#   [TRAIN-100] 8200/10000 | 59s elapsed | ETA 13s
#   [TRAIN-100] 8300/10000 | 60s elapsed | ETA 12s
#   [TRAIN-100] 8400/10000 | 61s elapsed | ETA 12s
#   [TRAIN-100] 8500/10000 | 61s elapsed | ETA 11s
#   [TRAIN-100] 8600/10000 | 62s elapsed | ETA 10s
#   [TRAIN-100] 8700/10000 | 63s elapsed | ETA 9s
#   [TRAIN-100] 8800/10000 | 63s elapsed | ETA 9s
#   [TRAIN-100] 8900/10000 | 64s elapsed | ETA 8s
#   [TRAIN-100] 9000/10000 | 65s elapsed | ETA 7s
#   [TRAIN-100] 9100/10000 | 66s elapsed | ETA 6s
#   [TRAIN-100] 9200/10000 | 66s elapsed | ETA 6s
#   [TRAIN-100] 9300/10000 | 67s elapsed | ETA 5s
#   [TRAIN-100] 9400/10000 | 68s elapsed | ETA 4s
#   [TRAIN-100] 9500/10000 | 69s elapsed | ETA 4s
#   [TRAIN-100] 9600/10000 | 69s elapsed | ETA 3s
#   [TRAIN-100] 9700/10000 | 70s elapsed | ETA 2s
#   [TRAIN-100] 9800/10000 | 71s elapsed | ETA 1s
#   [TRAIN-100] 9900/10000 | 71s elapsed | ETA 1s
#   [TRAIN-100] 10000/10000 | 72s elapsed | ETA 0s
#   [TRAIN-100] Done — 100x100 in 72s
#   [VAL-100] 100/4000 | 1s elapsed | ETA 28s
#   [VAL-100] 200/4000 | 1s elapsed | ETA 27s
#   [VAL-100] 300/4000 | 2s elapsed | ETA 26s
#   [VAL-100] 400/4000 | 3s elapsed | ETA 26s
#   [VAL-100] 500/4000 | 4s elapsed | ETA 25s
#   [VAL-100] 600/4000 | 4s elapsed | ETA 24s
#   [VAL-100] 700/4000 | 5s elapsed | ETA 24s
#   [VAL-100] 800/4000 | 6s elapsed | ETA 23s
#   [VAL-100] 900/4000 | 6s elapsed | ETA 22s
#   [VAL-100] 1000/4000 | 7s elapsed | ETA 21s
#   [VAL-100] 1100/4000 | 8s elapsed | ETA 21s
#   [VAL-100] 1200/4000 | 9s elapsed | ETA 20s
#   [VAL-100] 1300/4000 | 9s elapsed | ETA 19s
#   [VAL-100] 1400/4000 | 10s elapsed | ETA 19s
#   [VAL-100] 1500/4000 | 11s elapsed | ETA 18s
#   [VAL-100] 1600/4000 | 11s elapsed | ETA 17s
#   [VAL-100] 1700/4000 | 12s elapsed | ETA 17s
#   [VAL-100] 1800/4000 | 13s elapsed | ETA 16s
#   [VAL-100] 1900/4000 | 14s elapsed | ETA 15s
#   [VAL-100] 2000/4000 | 14s elapsed | ETA 14s
#   [VAL-100] 2100/4000 | 15s elapsed | ETA 14s
#   [VAL-100] 2200/4000 | 16s elapsed | ETA 13s
#   [VAL-100] 2300/4000 | 17s elapsed | ETA 12s
#   [VAL-100] 2400/4000 | 17s elapsed | ETA 12s
#   [VAL-100] 2500/4000 | 18s elapsed | ETA 11s
#   [VAL-100] 2600/4000 | 19s elapsed | ETA 10s
#   [VAL-100] 2700/4000 | 19s elapsed | ETA 9s
#   [VAL-100] 2800/4000 | 20s elapsed | ETA 9s
#   [VAL-100] 2900/4000 | 21s elapsed | ETA 8s
#   [VAL-100] 3000/4000 | 22s elapsed | ETA 7s
#   [VAL-100] 3100/4000 | 22s elapsed | ETA 6s
#   [VAL-100] 3200/4000 | 23s elapsed | ETA 6s
#   [VAL-100] 3300/4000 | 24s elapsed | ETA 5s
#   [VAL-100] 3400/4000 | 24s elapsed | ETA 4s
#   [VAL-100] 3500/4000 | 25s elapsed | ETA 4s
#   [VAL-100] 3600/4000 | 26s elapsed | ETA 3s
#   [VAL-100] 3700/4000 | 27s elapsed | ETA 2s
#   [VAL-100] 3800/4000 | 27s elapsed | ETA 1s
#   [VAL-100] 3900/4000 | 28s elapsed | ETA 1s
#   [VAL-100] 4000/4000 | 29s elapsed | ETA 0s
#   [VAL-100] Done — 40x100 in 29s
#   [TEST-100] 100/6000 | 1s elapsed | ETA 42s
#   [TEST-100] 200/6000 | 1s elapsed | ETA 41s
#   [TEST-100] 300/6000 | 2s elapsed | ETA 41s
#   [TEST-100] 400/6000 | 3s elapsed | ETA 40s
#   [TEST-100] 500/6000 | 4s elapsed | ETA 39s
#   [TEST-100] 600/6000 | 4s elapsed | ETA 39s
#   [TEST-100] 700/6000 | 5s elapsed | ETA 38s
#   [TEST-100] 800/6000 | 6s elapsed | ETA 37s
#   [TEST-100] 900/6000 | 6s elapsed | ETA 36s
#   [TEST-100] 1000/6000 | 7s elapsed | ETA 36s
#   [TEST-100] 1100/6000 | 8s elapsed | ETA 35s
#   [TEST-100] 1200/6000 | 9s elapsed | ETA 34s
#   [TEST-100] 1300/6000 | 9s elapsed | ETA 34s
#   [TEST-100] 1400/6000 | 10s elapsed | ETA 33s
#   [TEST-100] 1500/6000 | 11s elapsed | ETA 32s
#   [TEST-100] 1600/6000 | 11s elapsed | ETA 31s
#   [TEST-100] 1700/6000 | 12s elapsed | ETA 31s
#   [TEST-100] 1800/6000 | 13s elapsed | ETA 30s
#   [TEST-100] 1900/6000 | 14s elapsed | ETA 29s
#   [TEST-100] 2000/6000 | 14s elapsed | ETA 29s
#   [TEST-100] 2100/6000 | 15s elapsed | ETA 28s
#   [TEST-100] 2200/6000 | 16s elapsed | ETA 27s
#   [TEST-100] 2300/6000 | 17s elapsed | ETA 27s
#   [TEST-100] 2400/6000 | 17s elapsed | ETA 26s
#   [TEST-100] 2500/6000 | 18s elapsed | ETA 25s
#   [TEST-100] 2600/6000 | 19s elapsed | ETA 25s
#   [TEST-100] 2700/6000 | 19s elapsed | ETA 24s
#   [TEST-100] 2800/6000 | 20s elapsed | ETA 23s
#   [TEST-100] 2900/6000 | 21s elapsed | ETA 22s
#   [TEST-100] 3000/6000 | 22s elapsed | ETA 22s
#   [TEST-100] 3100/6000 | 22s elapsed | ETA 21s
#   [TEST-100] 3200/6000 | 23s elapsed | ETA 20s
#   [TEST-100] 3300/6000 | 24s elapsed | ETA 19s
#   [TEST-100] 3400/6000 | 24s elapsed | ETA 19s
#   [TEST-100] 3500/6000 | 25s elapsed | ETA 18s
#   [TEST-100] 3600/6000 | 26s elapsed | ETA 17s
#   [TEST-100] 3700/6000 | 27s elapsed | ETA 17s
#   [TEST-100] 3800/6000 | 27s elapsed | ETA 16s
#   [TEST-100] 3900/6000 | 28s elapsed | ETA 15s
#   [TEST-100] 4000/6000 | 29s elapsed | ETA 14s
#   [TEST-100] 4100/6000 | 30s elapsed | ETA 14s
#   [TEST-100] 4200/6000 | 30s elapsed | ETA 13s
#   [TEST-100] 4300/6000 | 31s elapsed | ETA 12s
#   [TEST-100] 4400/6000 | 32s elapsed | ETA 12s
#   [TEST-100] 4500/6000 | 32s elapsed | ETA 11s
#   [TEST-100] 4600/6000 | 33s elapsed | ETA 10s
#   [TEST-100] 4700/6000 | 34s elapsed | ETA 9s
#   [TEST-100] 4800/6000 | 35s elapsed | ETA 9s
#   [TEST-100] 4900/6000 | 35s elapsed | ETA 8s
#   [TEST-100] 5000/6000 | 36s elapsed | ETA 7s
#   [TEST-100] 5100/6000 | 37s elapsed | ETA 6s
#   [TEST-100] 5200/6000 | 38s elapsed | ETA 6s
#   [TEST-100] 5300/6000 | 38s elapsed | ETA 5s
#   [TEST-100] 5400/6000 | 39s elapsed | ETA 4s
#   [TEST-100] 5500/6000 | 40s elapsed | ETA 4s
#   [TEST-100] 5600/6000 | 40s elapsed | ETA 3s
#   [TEST-100] 5700/6000 | 41s elapsed | ETA 2s
#   [TEST-100] 5800/6000 | 42s elapsed | ETA 1s
#   [TEST-100] 5900/6000 | 43s elapsed | ETA 1s
#   [TEST-100] 6000/6000 | 43s elapsed | ETA 0s
#   [TEST-100] Done — 60x100 in 43s
# Done.

# %% [markdown]
# # Cell 15: Attempt 6 QSVM vs Classical SVM (100 samples)

# %%
# QSVM
clf6, val_acc6, test_acc6, test_f16 = evaluate_qsvm(
    K_train_100, Y_tr_sub, K_val_100, Y_v_sub, K_test_100, Y_te_sub)
Y_pred6 = clf6.predict(K_test_100)

# Classical SVM
svm6 = svm.SVC(kernel="rbf", probability=True, class_weight="balanced", random_state=42)
svm6.fit(X_tr_sub, Y_tr_sub)
svm_acc6 = accuracy_score(Y_te_sub, svm6.predict(X_te_sub))
svm_f16  = f1_score(Y_te_sub, svm6.predict(X_te_sub), average="weighted", zero_division=0)

print("=== 100 Samples ===")
print(f"QSVM    — Val: {val_acc6:.3f}  Test: {test_acc6:.3f}  F1: {test_f16:.3f}")
print(f"SVM     — Test: {svm_acc6:.3f}  F1: {svm_f16:.3f}")
# Out:
# === 100 Samples ===
# QSVM    — Val: 0.675  Test: 0.600  F1: 0.598
# SVM     — Test: 0.700  F1: 0.710

# %% [markdown]
# # Cell 16: Build Kernel Matrices (200 samples)

# %%
N_tr2, N_v2, N_te2 = 200, 60, 100
X_tr2 = X_train[:N_tr2];  Y_tr2 = Y_train[:N_tr2]
X_v2  = X_val[:N_v2];     Y_v2  = Y_val[:N_v2]
X_te2 = X_test[:N_te2];   Y_te2 = Y_test[:N_te2]

print("Building kernel matrices (200 samples) — this takes ~30-50 min ...")
K_train_200 = build_kernel_matrix(X_tr2, X_tr2, quantum_kernel, "TRAIN-200")
K_val_200   = build_kernel_matrix(X_v2,  X_tr2, quantum_kernel, "VAL-200")
K_test_200  = build_kernel_matrix(X_te2, X_tr2, quantum_kernel, "TEST-200")
print("Done.")
# Out:
# Building kernel matrices (200 samples) — this takes ~30-50 min ...
#   [TRAIN-200] 100/40000 | 1s elapsed | ETA 318s
#   [TRAIN-200] 200/40000 | 2s elapsed | ETA 309s
#   [TRAIN-200] 300/40000 | 2s elapsed | ETA 303s
#   [TRAIN-200] 400/40000 | 3s elapsed | ETA 300s
#   [TRAIN-200] 500/40000 | 4s elapsed | ETA 301s
#   [TRAIN-200] 600/40000 | 5s elapsed | ETA 305s
#   [TRAIN-200] 700/40000 | 5s elapsed | ETA 302s
#   [TRAIN-200] 800/40000 | 6s elapsed | ETA 302s
#   [TRAIN-200] 900/40000 | 7s elapsed | ETA 300s
#   [TRAIN-200] 1000/40000 | 8s elapsed | ETA 297s
#   [TRAIN-200] 1100/40000 | 8s elapsed | ETA 295s
#   [TRAIN-200] 1200/40000 | 9s elapsed | ETA 294s
#   [TRAIN-200] 1300/40000 | 10s elapsed | ETA 293s
#   [TRAIN-200] 1400/40000 | 11s elapsed | ETA 295s
#   [TRAIN-200] 1500/40000 | 11s elapsed | ETA 294s
#   [TRAIN-200] 1600/40000 | 12s elapsed | ETA 293s
#   [TRAIN-200] 1700/40000 | 13s elapsed | ETA 291s
#   [TRAIN-200] 1800/40000 | 14s elapsed | ETA 290s
#   [TRAIN-200] 1900/40000 | 14s elapsed | ETA 289s
#   [TRAIN-200] 2000/40000 | 15s elapsed | ETA 288s
#   [TRAIN-200] 2100/40000 | 16s elapsed | ETA 287s
#   [TRAIN-200] 2200/40000 | 17s elapsed | ETA 286s
#   [TRAIN-200] 2300/40000 | 17s elapsed | ETA 284s
#   [TRAIN-200] 2400/40000 | 18s elapsed | ETA 283s
#   [TRAIN-200] 2500/40000 | 19s elapsed | ETA 282s
#   [TRAIN-200] 2600/40000 | 20s elapsed | ETA 281s
#   [TRAIN-200] 2700/40000 | 20s elapsed | ETA 280s
#   [TRAIN-200] 2800/40000 | 21s elapsed | ETA 280s
#   [TRAIN-200] 2900/40000 | 22s elapsed | ETA 280s
#   [TRAIN-200] 3000/40000 | 23s elapsed | ETA 278s
#   [TRAIN-200] 3100/40000 | 23s elapsed | ETA 277s
#   [TRAIN-200] 3200/40000 | 24s elapsed | ETA 276s
#   [TRAIN-200] 3300/40000 | 25s elapsed | ETA 276s
#   [TRAIN-200] 3400/40000 | 26s elapsed | ETA 275s
#   [TRAIN-200] 3500/40000 | 26s elapsed | ETA 276s
#   [TRAIN-200] 3600/40000 | 27s elapsed | ETA 275s
#   [TRAIN-200] 3700/40000 | 28s elapsed | ETA 274s
#   [TRAIN-200] 3800/40000 | 29s elapsed | ETA 273s
#   [TRAIN-200] 3900/40000 | 29s elapsed | ETA 272s
#   [TRAIN-200] 4000/40000 | 30s elapsed | ETA 271s
#   [TRAIN-200] 4100/40000 | 31s elapsed | ETA 270s
#   [TRAIN-200] 4200/40000 | 32s elapsed | ETA 269s
#   [TRAIN-200] 4300/40000 | 32s elapsed | ETA 268s
#   [TRAIN-200] 4400/40000 | 33s elapsed | ETA 267s
#   [TRAIN-200] 4500/40000 | 34s elapsed | ETA 266s
#   [TRAIN-200] 4600/40000 | 35s elapsed | ETA 266s
#   [TRAIN-200] 4700/40000 | 35s elapsed | ETA 265s
#   [TRAIN-200] 4800/40000 | 36s elapsed | ETA 264s
#   [TRAIN-200] 4900/40000 | 37s elapsed | ETA 263s
#   [TRAIN-200] 5000/40000 | 37s elapsed | ETA 262s
#   [TRAIN-200] 5100/40000 | 38s elapsed | ETA 261s
#   [TRAIN-200] 5200/40000 | 39s elapsed | ETA 260s
#   [TRAIN-200] 5300/40000 | 40s elapsed | ETA 259s
#   [TRAIN-200] 5400/40000 | 40s elapsed | ETA 258s
#   [TRAIN-200] 5500/40000 | 41s elapsed | ETA 258s
#   [TRAIN-200] 5600/40000 | 42s elapsed | ETA 257s
#   [TRAIN-200] 5700/40000 | 43s elapsed | ETA 256s
#   [TRAIN-200] 5800/40000 | 43s elapsed | ETA 255s
#   [TRAIN-200] 5900/40000 | 44s elapsed | ETA 254s
#   [TRAIN-200] 6000/40000 | 45s elapsed | ETA 253s
#   [TRAIN-200] 6100/40000 | 45s elapsed | ETA 253s
#   [TRAIN-200] 6200/40000 | 46s elapsed | ETA 252s
#   [TRAIN-200] 6300/40000 | 47s elapsed | ETA 251s
#   [TRAIN-200] 6400/40000 | 48s elapsed | ETA 250s
#   [TRAIN-200] 6500/40000 | 48s elapsed | ETA 250s
#   [TRAIN-200] 6600/40000 | 49s elapsed | ETA 249s
#   [TRAIN-200] 6700/40000 | 50s elapsed | ETA 248s
#   [TRAIN-200] 6800/40000 | 51s elapsed | ETA 247s
#   [TRAIN-200] 6900/40000 | 51s elapsed | ETA 246s
#   [TRAIN-200] 7000/40000 | 52s elapsed | ETA 246s
#   [TRAIN-200] 7100/40000 | 53s elapsed | ETA 245s
#   [TRAIN-200] 7200/40000 | 54s elapsed | ETA 244s
#   [TRAIN-200] 7300/40000 | 54s elapsed | ETA 243s
#   [TRAIN-200] 7400/40000 | 55s elapsed | ETA 243s
#   [TRAIN-200] 7500/40000 | 56s elapsed | ETA 242s
#   [TRAIN-200] 7600/40000 | 57s elapsed | ETA 241s
#   [TRAIN-200] 7700/40000 | 57s elapsed | ETA 240s
#   [TRAIN-200] 7800/40000 | 58s elapsed | ETA 239s
#   [TRAIN-200] 7900/40000 | 59s elapsed | ETA 238s
#   [TRAIN-200] 8000/40000 | 59s elapsed | ETA 238s
#   [TRAIN-200] 8100/40000 | 60s elapsed | ETA 237s
#   [TRAIN-200] 8200/40000 | 61s elapsed | ETA 236s
#   [TRAIN-200] 8300/40000 | 62s elapsed | ETA 235s
#   [TRAIN-200] 8400/40000 | 62s elapsed | ETA 235s
#   [TRAIN-200] 8500/40000 | 63s elapsed | ETA 234s
#   [TRAIN-200] 8600/40000 | 64s elapsed | ETA 233s
#   [TRAIN-200] 8700/40000 | 65s elapsed | ETA 232s
#   [TRAIN-200] 8800/40000 | 65s elapsed | ETA 232s
#   [TRAIN-200] 8900/40000 | 66s elapsed | ETA 231s
#   [TRAIN-200] 9000/40000 | 67s elapsed | ETA 230s
#   [TRAIN-200] 9100/40000 | 68s elapsed | ETA 229s
#   [TRAIN-200] 9200/40000 | 68s elapsed | ETA 229s
#   [TRAIN-200] 9300/40000 | 69s elapsed | ETA 228s
#   [TRAIN-200] 9400/40000 | 70s elapsed | ETA 227s
#   [TRAIN-200] 9500/40000 | 70s elapsed | ETA 226s
#   [TRAIN-200] 9600/40000 | 71s elapsed | ETA 226s
#   [TRAIN-200] 9700/40000 | 72s elapsed | ETA 225s
#   [TRAIN-200] 9800/40000 | 73s elapsed | ETA 224s
#   [TRAIN-200] 9900/40000 | 73s elapsed | ETA 223s
#   [TRAIN-200] 10000/40000 | 74s elapsed | ETA 222s
#   [TRAIN-200] 10100/40000 | 75s elapsed | ETA 222s
#   [TRAIN-200] 10200/40000 | 76s elapsed | ETA 221s
#   [TRAIN-200] 10300/40000 | 76s elapsed | ETA 220s
#   [TRAIN-200] 10400/40000 | 77s elapsed | ETA 219s
#   [TRAIN-200] 10500/40000 | 78s elapsed | ETA 219s
#   [TRAIN-200] 10600/40000 | 79s elapsed | ETA 218s
#   [TRAIN-200] 10700/40000 | 79s elapsed | ETA 217s
#   [TRAIN-200] 10800/40000 | 80s elapsed | ETA 217s
#   [TRAIN-200] 10900/40000 | 81s elapsed | ETA 216s
#   [TRAIN-200] 11000/40000 | 82s elapsed | ETA 215s
#   [TRAIN-200] 11100/40000 | 82s elapsed | ETA 214s
#   [TRAIN-200] 11200/40000 | 83s elapsed | ETA 214s
#   [TRAIN-200] 11300/40000 | 84s elapsed | ETA 213s
#   [TRAIN-200] 11400/40000 | 84s elapsed | ETA 212s
#   [TRAIN-200] 11500/40000 | 85s elapsed | ETA 211s
#   [TRAIN-200] 11600/40000 | 86s elapsed | ETA 210s
#   [TRAIN-200] 11700/40000 | 87s elapsed | ETA 210s
#   [TRAIN-200] 11800/40000 | 87s elapsed | ETA 209s
#   [TRAIN-200] 11900/40000 | 88s elapsed | ETA 208s
#   [TRAIN-200] 12000/40000 | 89s elapsed | ETA 207s
#   [TRAIN-200] 12100/40000 | 90s elapsed | ETA 207s
#   [TRAIN-200] 12200/40000 | 90s elapsed | ETA 206s
#   [TRAIN-200] 12300/40000 | 91s elapsed | ETA 205s
#   [TRAIN-200] 12400/40000 | 92s elapsed | ETA 204s
#   [TRAIN-200] 12500/40000 | 93s elapsed | ETA 204s
#   [TRAIN-200] 12600/40000 | 93s elapsed | ETA 203s
#   [TRAIN-200] 12700/40000 | 94s elapsed | ETA 202s
#   [TRAIN-200] 12800/40000 | 95s elapsed | ETA 201s
#   [TRAIN-200] 12900/40000 | 95s elapsed | ETA 201s
#   [TRAIN-200] 13000/40000 | 96s elapsed | ETA 200s
#   [TRAIN-200] 13100/40000 | 97s elapsed | ETA 199s
#   [TRAIN-200] 13200/40000 | 98s elapsed | ETA 198s
#   [TRAIN-200] 13300/40000 | 98s elapsed | ETA 198s
#   [TRAIN-200] 13400/40000 | 99s elapsed | ETA 197s
#   [TRAIN-200] 13500/40000 | 100s elapsed | ETA 196s
#   [TRAIN-200] 13600/40000 | 101s elapsed | ETA 195s
#   [TRAIN-200] 13700/40000 | 101s elapsed | ETA 195s
#   [TRAIN-200] 13800/40000 | 102s elapsed | ETA 194s
#   [TRAIN-200] 13900/40000 | 103s elapsed | ETA 193s
#   [TRAIN-200] 14000/40000 | 104s elapsed | ETA 193s
#   [TRAIN-200] 14100/40000 | 104s elapsed | ETA 192s
#   [TRAIN-200] 14200/40000 | 105s elapsed | ETA 191s
#   [TRAIN-200] 14300/40000 | 106s elapsed | ETA 190s
#   [TRAIN-200] 14400/40000 | 107s elapsed | ETA 190s
#   [TRAIN-200] 14500/40000 | 107s elapsed | ETA 189s
#   [TRAIN-200] 14600/40000 | 108s elapsed | ETA 188s
#   [TRAIN-200] 14700/40000 | 109s elapsed | ETA 187s
#   [TRAIN-200] 14800/40000 | 110s elapsed | ETA 187s
#   [TRAIN-200] 14900/40000 | 110s elapsed | ETA 186s
#   [TRAIN-200] 15000/40000 | 111s elapsed | ETA 185s
#   [TRAIN-200] 15100/40000 | 112s elapsed | ETA 185s
#   [TRAIN-200] 15200/40000 | 113s elapsed | ETA 184s
#   [TRAIN-200] 15300/40000 | 113s elapsed | ETA 183s
#   [TRAIN-200] 15400/40000 | 114s elapsed | ETA 182s
#   [TRAIN-200] 15500/40000 | 115s elapsed | ETA 182s
#   [TRAIN-200] 15600/40000 | 116s elapsed | ETA 181s
#   [TRAIN-200] 15700/40000 | 116s elapsed | ETA 180s
#   [TRAIN-200] 15800/40000 | 117s elapsed | ETA 179s
#   [TRAIN-200] 15900/40000 | 118s elapsed | ETA 179s
#   [TRAIN-200] 16000/40000 | 119s elapsed | ETA 178s
#   [TRAIN-200] 16100/40000 | 119s elapsed | ETA 177s
#   [TRAIN-200] 16200/40000 | 120s elapsed | ETA 176s
#   [TRAIN-200] 16300/40000 | 121s elapsed | ETA 176s
#   [TRAIN-200] 16400/40000 | 121s elapsed | ETA 175s
#   [TRAIN-200] 16500/40000 | 122s elapsed | ETA 174s
#   [TRAIN-200] 16600/40000 | 123s elapsed | ETA 173s
#   [TRAIN-200] 16700/40000 | 124s elapsed | ETA 173s
#   [TRAIN-200] 16800/40000 | 124s elapsed | ETA 172s
#   [TRAIN-200] 16900/40000 | 125s elapsed | ETA 171s
#   [TRAIN-200] 17000/40000 | 126s elapsed | ETA 170s
#   [TRAIN-200] 17100/40000 | 127s elapsed | ETA 170s
#   [TRAIN-200] 17200/40000 | 127s elapsed | ETA 169s
#   [TRAIN-200] 17300/40000 | 128s elapsed | ETA 168s
#   [TRAIN-200] 17400/40000 | 129s elapsed | ETA 167s
#   [TRAIN-200] 17500/40000 | 130s elapsed | ETA 167s
#   [TRAIN-200] 17600/40000 | 130s elapsed | ETA 166s
#   [TRAIN-200] 17700/40000 | 131s elapsed | ETA 165s
#   [TRAIN-200] 17800/40000 | 132s elapsed | ETA 164s
#   [TRAIN-200] 17900/40000 | 133s elapsed | ETA 164s
#   [TRAIN-200] 18000/40000 | 133s elapsed | ETA 163s
#   [TRAIN-200] 18100/40000 | 134s elapsed | ETA 162s
#   [TRAIN-200] 18200/40000 | 135s elapsed | ETA 162s
#   [TRAIN-200] 18300/40000 | 136s elapsed | ETA 161s
#   [TRAIN-200] 18400/40000 | 136s elapsed | ETA 160s
#   [TRAIN-200] 18500/40000 | 137s elapsed | ETA 159s
#   [TRAIN-200] 18600/40000 | 138s elapsed | ETA 159s
#   [TRAIN-200] 18700/40000 | 139s elapsed | ETA 158s
#   [TRAIN-200] 18800/40000 | 139s elapsed | ETA 157s
#   [TRAIN-200] 18900/40000 | 140s elapsed | ETA 156s
#   [TRAIN-200] 19000/40000 | 141s elapsed | ETA 156s
#   [TRAIN-200] 19100/40000 | 141s elapsed | ETA 155s
#   [TRAIN-200] 19200/40000 | 142s elapsed | ETA 154s
#   [TRAIN-200] 19300/40000 | 143s elapsed | ETA 153s
#   [TRAIN-200] 19400/40000 | 144s elapsed | ETA 153s
#   [TRAIN-200] 19500/40000 | 144s elapsed | ETA 152s
#   [TRAIN-200] 19600/40000 | 145s elapsed | ETA 151s
#   [TRAIN-200] 19700/40000 | 146s elapsed | ETA 150s
#   [TRAIN-200] 19800/40000 | 147s elapsed | ETA 150s
#   [TRAIN-200] 19900/40000 | 148s elapsed | ETA 149s
#   [TRAIN-200] 20000/40000 | 148s elapsed | ETA 148s
#   [TRAIN-200] 20100/40000 | 149s elapsed | ETA 148s
#   [TRAIN-200] 20200/40000 | 150s elapsed | ETA 147s
#   [TRAIN-200] 20300/40000 | 151s elapsed | ETA 146s
#   [TRAIN-200] 20400/40000 | 151s elapsed | ETA 145s
#   [TRAIN-200] 20500/40000 | 152s elapsed | ETA 145s
#   [TRAIN-200] 20600/40000 | 153s elapsed | ETA 144s
#   [TRAIN-200] 20700/40000 | 153s elapsed | ETA 143s
#   [TRAIN-200] 20800/40000 | 154s elapsed | ETA 142s
#   [TRAIN-200] 20900/40000 | 155s elapsed | ETA 142s
#   [TRAIN-200] 21000/40000 | 156s elapsed | ETA 141s
#   [TRAIN-200] 21100/40000 | 156s elapsed | ETA 140s
#   [TRAIN-200] 21200/40000 | 157s elapsed | ETA 139s
#   [TRAIN-200] 21300/40000 | 158s elapsed | ETA 139s
#   [TRAIN-200] 21400/40000 | 159s elapsed | ETA 138s
#   [TRAIN-200] 21500/40000 | 159s elapsed | ETA 137s
#   [TRAIN-200] 21600/40000 | 160s elapsed | ETA 136s
#   [TRAIN-200] 21700/40000 | 161s elapsed | ETA 136s
#   [TRAIN-200] 21800/40000 | 162s elapsed | ETA 135s
#   [TRAIN-200] 21900/40000 | 162s elapsed | ETA 134s
#   [TRAIN-200] 22000/40000 | 163s elapsed | ETA 133s
#   [TRAIN-200] 22100/40000 | 164s elapsed | ETA 133s
#   [TRAIN-200] 22200/40000 | 165s elapsed | ETA 132s
#   [TRAIN-200] 22300/40000 | 165s elapsed | ETA 131s
#   [TRAIN-200] 22400/40000 | 166s elapsed | ETA 130s
#   [TRAIN-200] 22500/40000 | 167s elapsed | ETA 130s
#   [TRAIN-200] 22600/40000 | 167s elapsed | ETA 129s
#   [TRAIN-200] 22700/40000 | 168s elapsed | ETA 128s
#   [TRAIN-200] 22800/40000 | 169s elapsed | ETA 127s
#   [TRAIN-200] 22900/40000 | 170s elapsed | ETA 127s
#   [TRAIN-200] 23000/40000 | 170s elapsed | ETA 126s
#   [TRAIN-200] 23100/40000 | 171s elapsed | ETA 125s
#   [TRAIN-200] 23200/40000 | 172s elapsed | ETA 124s
#   [TRAIN-200] 23300/40000 | 173s elapsed | ETA 124s
#   [TRAIN-200] 23400/40000 | 173s elapsed | ETA 123s
#   [TRAIN-200] 23500/40000 | 174s elapsed | ETA 122s
#   [TRAIN-200] 23600/40000 | 175s elapsed | ETA 122s
#   [TRAIN-200] 23700/40000 | 176s elapsed | ETA 121s
#   [TRAIN-200] 23800/40000 | 176s elapsed | ETA 120s
#   [TRAIN-200] 23900/40000 | 177s elapsed | ETA 119s
#   [TRAIN-200] 24000/40000 | 178s elapsed | ETA 119s
#   [TRAIN-200] 24100/40000 | 179s elapsed | ETA 118s
#   [TRAIN-200] 24200/40000 | 179s elapsed | ETA 117s
#   [TRAIN-200] 24300/40000 | 180s elapsed | ETA 116s
#   [TRAIN-200] 24400/40000 | 181s elapsed | ETA 116s
#   [TRAIN-200] 24500/40000 | 182s elapsed | ETA 115s
#   [TRAIN-200] 24600/40000 | 182s elapsed | ETA 114s
#   [TRAIN-200] 24700/40000 | 183s elapsed | ETA 113s
#   [TRAIN-200] 24800/40000 | 184s elapsed | ETA 113s
#   [TRAIN-200] 24900/40000 | 184s elapsed | ETA 112s
#   [TRAIN-200] 25000/40000 | 185s elapsed | ETA 111s
#   [TRAIN-200] 25100/40000 | 186s elapsed | ETA 110s
#   [TRAIN-200] 25200/40000 | 187s elapsed | ETA 110s
#   [TRAIN-200] 25300/40000 | 187s elapsed | ETA 109s
#   [TRAIN-200] 25400/40000 | 188s elapsed | ETA 108s
#   [TRAIN-200] 25500/40000 | 189s elapsed | ETA 107s
#   [TRAIN-200] 25600/40000 | 190s elapsed | ETA 107s
#   [TRAIN-200] 25700/40000 | 190s elapsed | ETA 106s
#   [TRAIN-200] 25800/40000 | 191s elapsed | ETA 105s
#   [TRAIN-200] 25900/40000 | 192s elapsed | ETA 104s
#   [TRAIN-200] 26000/40000 | 193s elapsed | ETA 104s
#   [TRAIN-200] 26100/40000 | 193s elapsed | ETA 103s
#   [TRAIN-200] 26200/40000 | 194s elapsed | ETA 102s
#   [TRAIN-200] 26300/40000 | 195s elapsed | ETA 102s
#   [TRAIN-200] 26400/40000 | 196s elapsed | ETA 101s
#   [TRAIN-200] 26500/40000 | 196s elapsed | ETA 100s
#   [TRAIN-200] 26600/40000 | 197s elapsed | ETA 99s
#   [TRAIN-200] 26700/40000 | 198s elapsed | ETA 99s
#   [TRAIN-200] 26800/40000 | 199s elapsed | ETA 98s
#   [TRAIN-200] 26900/40000 | 199s elapsed | ETA 97s
#   [TRAIN-200] 27000/40000 | 200s elapsed | ETA 96s
#   [TRAIN-200] 27100/40000 | 201s elapsed | ETA 96s
#   [TRAIN-200] 27200/40000 | 201s elapsed | ETA 95s
#   [TRAIN-200] 27300/40000 | 202s elapsed | ETA 94s
#   [TRAIN-200] 27400/40000 | 203s elapsed | ETA 93s
#   [TRAIN-200] 27500/40000 | 204s elapsed | ETA 93s
#   [TRAIN-200] 27600/40000 | 204s elapsed | ETA 92s
#   [TRAIN-200] 27700/40000 | 205s elapsed | ETA 91s
#   [TRAIN-200] 27800/40000 | 206s elapsed | ETA 90s
#   [TRAIN-200] 27900/40000 | 207s elapsed | ETA 90s
#   [TRAIN-200] 28000/40000 | 207s elapsed | ETA 89s
#   [TRAIN-200] 28100/40000 | 208s elapsed | ETA 88s
#   [TRAIN-200] 28200/40000 | 209s elapsed | ETA 87s
#   [TRAIN-200] 28300/40000 | 210s elapsed | ETA 87s
#   [TRAIN-200] 28400/40000 | 210s elapsed | ETA 86s
#   [TRAIN-200] 28500/40000 | 211s elapsed | ETA 85s
#   [TRAIN-200] 28600/40000 | 212s elapsed | ETA 84s
#   [TRAIN-200] 28700/40000 | 213s elapsed | ETA 84s
#   [TRAIN-200] 28800/40000 | 213s elapsed | ETA 83s
#   [TRAIN-200] 28900/40000 | 214s elapsed | ETA 82s
#   [TRAIN-200] 29000/40000 | 215s elapsed | ETA 81s
#   [TRAIN-200] 29100/40000 | 216s elapsed | ETA 81s
#   [TRAIN-200] 29200/40000 | 216s elapsed | ETA 80s
#   [TRAIN-200] 29300/40000 | 217s elapsed | ETA 79s
#   [TRAIN-200] 29400/40000 | 218s elapsed | ETA 79s
#   [TRAIN-200] 29500/40000 | 219s elapsed | ETA 78s
#   [TRAIN-200] 29600/40000 | 219s elapsed | ETA 77s
#   [TRAIN-200] 29700/40000 | 220s elapsed | ETA 76s
#   [TRAIN-200] 29800/40000 | 221s elapsed | ETA 76s
#   [TRAIN-200] 29900/40000 | 221s elapsed | ETA 75s
#   [TRAIN-200] 30000/40000 | 222s elapsed | ETA 74s
#   [TRAIN-200] 30100/40000 | 223s elapsed | ETA 73s
#   [TRAIN-200] 30200/40000 | 224s elapsed | ETA 73s
#   [TRAIN-200] 30300/40000 | 224s elapsed | ETA 72s
#   [TRAIN-200] 30400/40000 | 225s elapsed | ETA 71s
#   [TRAIN-200] 30500/40000 | 226s elapsed | ETA 70s
#   [TRAIN-200] 30600/40000 | 227s elapsed | ETA 70s
#   [TRAIN-200] 30700/40000 | 227s elapsed | ETA 69s
#   [TRAIN-200] 30800/40000 | 228s elapsed | ETA 68s
#   [TRAIN-200] 30900/40000 | 229s elapsed | ETA 67s
#   [TRAIN-200] 31000/40000 | 230s elapsed | ETA 67s
#   [TRAIN-200] 31100/40000 | 230s elapsed | ETA 66s
#   [TRAIN-200] 31200/40000 | 231s elapsed | ETA 65s
#   [TRAIN-200] 31300/40000 | 232s elapsed | ETA 64s
#   [TRAIN-200] 31400/40000 | 233s elapsed | ETA 64s
#   [TRAIN-200] 31500/40000 | 233s elapsed | ETA 63s
#   [TRAIN-200] 31600/40000 | 234s elapsed | ETA 62s
#   [TRAIN-200] 31700/40000 | 235s elapsed | ETA 61s
#   [TRAIN-200] 31800/40000 | 236s elapsed | ETA 61s
#   [TRAIN-200] 31900/40000 | 236s elapsed | ETA 60s
#   [TRAIN-200] 32000/40000 | 237s elapsed | ETA 59s
#   [TRAIN-200] 32100/40000 | 238s elapsed | ETA 59s
#   [TRAIN-200] 32200/40000 | 239s elapsed | ETA 58s
#   [TRAIN-200] 32300/40000 | 239s elapsed | ETA 57s
#   [TRAIN-200] 32400/40000 | 240s elapsed | ETA 56s
#   [TRAIN-200] 32500/40000 | 241s elapsed | ETA 56s
#   [TRAIN-200] 32600/40000 | 242s elapsed | ETA 55s
#   [TRAIN-200] 32700/40000 | 242s elapsed | ETA 54s
#   [TRAIN-200] 32800/40000 | 243s elapsed | ETA 53s
#   [TRAIN-200] 32900/40000 | 244s elapsed | ETA 53s
#   [TRAIN-200] 33000/40000 | 244s elapsed | ETA 52s
#   [TRAIN-200] 33100/40000 | 245s elapsed | ETA 51s
#   [TRAIN-200] 33200/40000 | 246s elapsed | ETA 50s
#   [TRAIN-200] 33300/40000 | 247s elapsed | ETA 50s
#   [TRAIN-200] 33400/40000 | 247s elapsed | ETA 49s
#   [TRAIN-200] 33500/40000 | 248s elapsed | ETA 48s
#   [TRAIN-200] 33600/40000 | 249s elapsed | ETA 47s
#   [TRAIN-200] 33700/40000 | 250s elapsed | ETA 47s
#   [TRAIN-200] 33800/40000 | 250s elapsed | ETA 46s
#   [TRAIN-200] 33900/40000 | 251s elapsed | ETA 45s
#   [TRAIN-200] 34000/40000 | 252s elapsed | ETA 44s
#   [TRAIN-200] 34100/40000 | 253s elapsed | ETA 44s
#   [TRAIN-200] 34200/40000 | 253s elapsed | ETA 43s
#   [TRAIN-200] 34300/40000 | 254s elapsed | ETA 42s
#   [TRAIN-200] 34400/40000 | 255s elapsed | ETA 41s
#   [TRAIN-200] 34500/40000 | 256s elapsed | ETA 41s
#   [TRAIN-200] 34600/40000 | 256s elapsed | ETA 40s
#   [TRAIN-200] 34700/40000 | 257s elapsed | ETA 39s
#   [TRAIN-200] 34800/40000 | 258s elapsed | ETA 39s
#   [TRAIN-200] 34900/40000 | 259s elapsed | ETA 38s
#   [TRAIN-200] 35000/40000 | 259s elapsed | ETA 37s
#   [TRAIN-200] 35100/40000 | 260s elapsed | ETA 36s
#   [TRAIN-200] 35200/40000 | 261s elapsed | ETA 36s
#   [TRAIN-200] 35300/40000 | 261s elapsed | ETA 35s
#   [TRAIN-200] 35400/40000 | 262s elapsed | ETA 34s
#   [TRAIN-200] 35500/40000 | 263s elapsed | ETA 33s
#   [TRAIN-200] 35600/40000 | 264s elapsed | ETA 33s
#   [TRAIN-200] 35700/40000 | 264s elapsed | ETA 32s
#   [TRAIN-200] 35800/40000 | 265s elapsed | ETA 31s
#   [TRAIN-200] 35900/40000 | 266s elapsed | ETA 30s
#   [TRAIN-200] 36000/40000 | 267s elapsed | ETA 30s
#   [TRAIN-200] 36100/40000 | 267s elapsed | ETA 29s
#   [TRAIN-200] 36200/40000 | 268s elapsed | ETA 28s
#   [TRAIN-200] 36300/40000 | 269s elapsed | ETA 27s
#   [TRAIN-200] 36400/40000 | 270s elapsed | ETA 27s
#   [TRAIN-200] 36500/40000 | 270s elapsed | ETA 26s
#   [TRAIN-200] 36600/40000 | 271s elapsed | ETA 25s
#   [TRAIN-200] 36700/40000 | 272s elapsed | ETA 24s
#   [TRAIN-200] 36800/40000 | 273s elapsed | ETA 24s
#   [TRAIN-200] 36900/40000 | 273s elapsed | ETA 23s
#   [TRAIN-200] 37000/40000 | 274s elapsed | ETA 22s
#   [TRAIN-200] 37100/40000 | 275s elapsed | ETA 21s
#   [TRAIN-200] 37200/40000 | 276s elapsed | ETA 21s
#   [TRAIN-200] 37300/40000 | 276s elapsed | ETA 20s
#   [TRAIN-200] 37400/40000 | 277s elapsed | ETA 19s
#   [TRAIN-200] 37500/40000 | 278s elapsed | ETA 19s
#   [TRAIN-200] 37600/40000 | 279s elapsed | ETA 18s
#   [TRAIN-200] 37700/40000 | 279s elapsed | ETA 17s
#   [TRAIN-200] 37800/40000 | 280s elapsed | ETA 16s
#   [TRAIN-200] 37900/40000 | 281s elapsed | ETA 16s
#   [TRAIN-200] 38000/40000 | 282s elapsed | ETA 15s
#   [TRAIN-200] 38100/40000 | 282s elapsed | ETA 14s
#   [TRAIN-200] 38200/40000 | 283s elapsed | ETA 13s
#   [TRAIN-200] 38300/40000 | 284s elapsed | ETA 13s
#   [TRAIN-200] 38400/40000 | 284s elapsed | ETA 12s
#   [TRAIN-200] 38500/40000 | 285s elapsed | ETA 11s
#   [TRAIN-200] 38600/40000 | 286s elapsed | ETA 10s
#   [TRAIN-200] 38700/40000 | 287s elapsed | ETA 10s
#   [TRAIN-200] 38800/40000 | 287s elapsed | ETA 9s
#   [TRAIN-200] 38900/40000 | 288s elapsed | ETA 8s
#   [TRAIN-200] 39000/40000 | 289s elapsed | ETA 7s
#   [TRAIN-200] 39100/40000 | 290s elapsed | ETA 7s
#   [TRAIN-200] 39200/40000 | 290s elapsed | ETA 6s
#   [TRAIN-200] 39300/40000 | 291s elapsed | ETA 5s
#   [TRAIN-200] 39400/40000 | 292s elapsed | ETA 4s
#   [TRAIN-200] 39500/40000 | 293s elapsed | ETA 4s
#   [TRAIN-200] 39600/40000 | 293s elapsed | ETA 3s
#   [TRAIN-200] 39700/40000 | 294s elapsed | ETA 2s
#   [TRAIN-200] 39800/40000 | 295s elapsed | ETA 1s
#   [TRAIN-200] 39900/40000 | 296s elapsed | ETA 1s
#   [TRAIN-200] 40000/40000 | 296s elapsed | ETA 0s
#   [TRAIN-200] Done — 200x200 in 296s
#   [VAL-200] 100/12000 | 1s elapsed | ETA 87s
#   [VAL-200] 200/12000 | 2s elapsed | ETA 89s
#   [VAL-200] 300/12000 | 2s elapsed | ETA 88s
#   [VAL-200] 400/12000 | 3s elapsed | ETA 86s
#   [VAL-200] 500/12000 | 4s elapsed | ETA 85s
#   [VAL-200] 600/12000 | 4s elapsed | ETA 85s
#   [VAL-200] 700/12000 | 5s elapsed | ETA 84s
#   [VAL-200] 800/12000 | 6s elapsed | ETA 83s
#   [VAL-200] 900/12000 | 7s elapsed | ETA 83s
#   [VAL-200] 1000/12000 | 7s elapsed | ETA 82s
#   [VAL-200] 1100/12000 | 8s elapsed | ETA 81s
#   [VAL-200] 1200/12000 | 9s elapsed | ETA 81s
#   [VAL-200] 1300/12000 | 10s elapsed | ETA 80s
#   [VAL-200] 1400/12000 | 10s elapsed | ETA 79s
#   [VAL-200] 1500/12000 | 11s elapsed | ETA 78s
#   [VAL-200] 1600/12000 | 12s elapsed | ETA 77s
#   [VAL-200] 1700/12000 | 13s elapsed | ETA 77s
#   [VAL-200] 1800/12000 | 13s elapsed | ETA 76s
#   [VAL-200] 1900/12000 | 14s elapsed | ETA 75s
#   [VAL-200] 2000/12000 | 15s elapsed | ETA 74s
#   [VAL-200] 2100/12000 | 16s elapsed | ETA 74s
#   [VAL-200] 2200/12000 | 16s elapsed | ETA 73s
#   [VAL-200] 2300/12000 | 17s elapsed | ETA 72s
#   [VAL-200] 2400/12000 | 18s elapsed | ETA 71s
#   [VAL-200] 2500/12000 | 19s elapsed | ETA 71s
#   [VAL-200] 2600/12000 | 19s elapsed | ETA 70s
#   [VAL-200] 2700/12000 | 20s elapsed | ETA 69s
#   [VAL-200] 2800/12000 | 21s elapsed | ETA 68s
#   [VAL-200] 2900/12000 | 22s elapsed | ETA 68s
#   [VAL-200] 3000/12000 | 22s elapsed | ETA 67s
#   [VAL-200] 3100/12000 | 23s elapsed | ETA 66s
#   [VAL-200] 3200/12000 | 24s elapsed | ETA 65s
#   [VAL-200] 3300/12000 | 25s elapsed | ETA 65s
#   [VAL-200] 3400/12000 | 25s elapsed | ETA 64s
#   [VAL-200] 3500/12000 | 26s elapsed | ETA 63s
#   [VAL-200] 3600/12000 | 27s elapsed | ETA 63s
#   [VAL-200] 3700/12000 | 28s elapsed | ETA 62s
#   [VAL-200] 3800/12000 | 28s elapsed | ETA 61s
#   [VAL-200] 3900/12000 | 29s elapsed | ETA 60s
#   [VAL-200] 4000/12000 | 30s elapsed | ETA 59s
#   [VAL-200] 4100/12000 | 30s elapsed | ETA 59s
#   [VAL-200] 4200/12000 | 31s elapsed | ETA 58s
#   [VAL-200] 4300/12000 | 32s elapsed | ETA 57s
#   [VAL-200] 4400/12000 | 33s elapsed | ETA 56s
#   [VAL-200] 4500/12000 | 33s elapsed | ETA 56s
#   [VAL-200] 4600/12000 | 34s elapsed | ETA 55s
#   [VAL-200] 4700/12000 | 35s elapsed | ETA 54s
#   [VAL-200] 4800/12000 | 36s elapsed | ETA 53s
#   [VAL-200] 4900/12000 | 36s elapsed | ETA 53s
#   [VAL-200] 5000/12000 | 37s elapsed | ETA 52s
#   [VAL-200] 5100/12000 | 38s elapsed | ETA 51s
#   [VAL-200] 5200/12000 | 39s elapsed | ETA 51s
#   [VAL-200] 5300/12000 | 39s elapsed | ETA 50s
#   [VAL-200] 5400/12000 | 40s elapsed | ETA 49s
#   [VAL-200] 5500/12000 | 41s elapsed | ETA 48s
#   [VAL-200] 5600/12000 | 42s elapsed | ETA 48s
#   [VAL-200] 5700/12000 | 42s elapsed | ETA 47s
#   [VAL-200] 5800/12000 | 43s elapsed | ETA 46s
#   [VAL-200] 5900/12000 | 44s elapsed | ETA 45s
#   [VAL-200] 6000/12000 | 45s elapsed | ETA 45s
#   [VAL-200] 6100/12000 | 45s elapsed | ETA 44s
#   [VAL-200] 6200/12000 | 46s elapsed | ETA 43s
#   [VAL-200] 6300/12000 | 47s elapsed | ETA 42s
#   [VAL-200] 6400/12000 | 48s elapsed | ETA 42s
#   [VAL-200] 6500/12000 | 48s elapsed | ETA 41s
#   [VAL-200] 6600/12000 | 49s elapsed | ETA 40s
#   [VAL-200] 6700/12000 | 50s elapsed | ETA 39s
#   [VAL-200] 6800/12000 | 50s elapsed | ETA 39s
#   [VAL-200] 6900/12000 | 51s elapsed | ETA 38s
#   [VAL-200] 7000/12000 | 52s elapsed | ETA 37s
#   [VAL-200] 7100/12000 | 53s elapsed | ETA 36s
#   [VAL-200] 7200/12000 | 53s elapsed | ETA 36s
#   [VAL-200] 7300/12000 | 54s elapsed | ETA 35s
#   [VAL-200] 7400/12000 | 55s elapsed | ETA 34s
#   [VAL-200] 7500/12000 | 56s elapsed | ETA 33s
#   [VAL-200] 7600/12000 | 56s elapsed | ETA 33s
#   [VAL-200] 7700/12000 | 57s elapsed | ETA 32s
#   [VAL-200] 7800/12000 | 58s elapsed | ETA 31s
#   [VAL-200] 7900/12000 | 59s elapsed | ETA 30s
#   [VAL-200] 8000/12000 | 59s elapsed | ETA 30s
#   [VAL-200] 8100/12000 | 60s elapsed | ETA 29s
#   [VAL-200] 8200/12000 | 61s elapsed | ETA 28s
#   [VAL-200] 8300/12000 | 62s elapsed | ETA 27s
#   [VAL-200] 8400/12000 | 62s elapsed | ETA 27s
#   [VAL-200] 8500/12000 | 63s elapsed | ETA 26s
#   [VAL-200] 8600/12000 | 64s elapsed | ETA 25s
#   [VAL-200] 8700/12000 | 65s elapsed | ETA 24s
#   [VAL-200] 8800/12000 | 65s elapsed | ETA 24s
#   [VAL-200] 8900/12000 | 66s elapsed | ETA 23s
#   [VAL-200] 9000/12000 | 67s elapsed | ETA 22s
#   [VAL-200] 9100/12000 | 68s elapsed | ETA 22s
#   [VAL-200] 9200/12000 | 68s elapsed | ETA 21s
#   [VAL-200] 9300/12000 | 69s elapsed | ETA 20s
#   [VAL-200] 9400/12000 | 70s elapsed | ETA 19s
#   [VAL-200] 9500/12000 | 71s elapsed | ETA 19s
#   [VAL-200] 9600/12000 | 71s elapsed | ETA 18s
#   [VAL-200] 9700/12000 | 72s elapsed | ETA 17s
#   [VAL-200] 9800/12000 | 73s elapsed | ETA 16s
#   [VAL-200] 9900/12000 | 73s elapsed | ETA 16s
#   [VAL-200] 10000/12000 | 74s elapsed | ETA 15s
#   [VAL-200] 10100/12000 | 75s elapsed | ETA 14s
#   [VAL-200] 10200/12000 | 76s elapsed | ETA 13s
#   [VAL-200] 10300/12000 | 76s elapsed | ETA 13s
#   [VAL-200] 10400/12000 | 77s elapsed | ETA 12s
#   [VAL-200] 10500/12000 | 78s elapsed | ETA 11s
#   [VAL-200] 10600/12000 | 79s elapsed | ETA 10s
#   [VAL-200] 10700/12000 | 79s elapsed | ETA 10s
#   [VAL-200] 10800/12000 | 80s elapsed | ETA 9s
#   [VAL-200] 10900/12000 | 81s elapsed | ETA 8s
#   [VAL-200] 11000/12000 | 82s elapsed | ETA 7s
#   [VAL-200] 11100/12000 | 82s elapsed | ETA 7s
#   [VAL-200] 11200/12000 | 83s elapsed | ETA 6s
#   [VAL-200] 11300/12000 | 84s elapsed | ETA 5s
#   [VAL-200] 11400/12000 | 85s elapsed | ETA 4s
#   [VAL-200] 11500/12000 | 85s elapsed | ETA 4s
#   [VAL-200] 11600/12000 | 86s elapsed | ETA 3s
#   [VAL-200] 11700/12000 | 87s elapsed | ETA 2s
#   [VAL-200] 11800/12000 | 88s elapsed | ETA 1s
#   [VAL-200] 11900/12000 | 88s elapsed | ETA 1s
#   [VAL-200] 12000/12000 | 89s elapsed | ETA 0s
#   [VAL-200] Done — 60x200 in 89s
#   [TEST-200] 100/20000 | 1s elapsed | ETA 145s
#   [TEST-200] 200/20000 | 1s elapsed | ETA 147s
#   [TEST-200] 300/20000 | 2s elapsed | ETA 146s
#   [TEST-200] 400/20000 | 3s elapsed | ETA 145s
#   [TEST-200] 500/20000 | 4s elapsed | ETA 144s
#   [TEST-200] 600/20000 | 4s elapsed | ETA 144s
#   [TEST-200] 700/20000 | 5s elapsed | ETA 143s
#   [TEST-200] 800/20000 | 6s elapsed | ETA 142s
#   [TEST-200] 900/20000 | 7s elapsed | ETA 141s
#   [TEST-200] 1000/20000 | 7s elapsed | ETA 140s
#   [TEST-200] 1100/20000 | 8s elapsed | ETA 140s
#   [TEST-200] 1200/20000 | 9s elapsed | ETA 139s
#   [TEST-200] 1300/20000 | 10s elapsed | ETA 138s
#   [TEST-200] 1400/20000 | 10s elapsed | ETA 137s
#   [TEST-200] 1500/20000 | 11s elapsed | ETA 137s
#   [TEST-200] 1600/20000 | 12s elapsed | ETA 136s
#   [TEST-200] 1700/20000 | 13s elapsed | ETA 135s
#   [TEST-200] 1800/20000 | 13s elapsed | ETA 135s
#   [TEST-200] 1900/20000 | 14s elapsed | ETA 134s
#   [TEST-200] 2000/20000 | 15s elapsed | ETA 133s
#   [TEST-200] 2100/20000 | 16s elapsed | ETA 133s
#   [TEST-200] 2200/20000 | 16s elapsed | ETA 132s
#   [TEST-200] 2300/20000 | 17s elapsed | ETA 131s
#   [TEST-200] 2400/20000 | 18s elapsed | ETA 131s
#   [TEST-200] 2500/20000 | 19s elapsed | ETA 130s
#   [TEST-200] 2600/20000 | 19s elapsed | ETA 129s
#   [TEST-200] 2700/20000 | 20s elapsed | ETA 128s
#   [TEST-200] 2800/20000 | 21s elapsed | ETA 128s
#   [TEST-200] 2900/20000 | 22s elapsed | ETA 127s
#   [TEST-200] 3000/20000 | 22s elapsed | ETA 126s
#   [TEST-200] 3100/20000 | 23s elapsed | ETA 125s
#   [TEST-200] 3200/20000 | 24s elapsed | ETA 125s
#   [TEST-200] 3300/20000 | 25s elapsed | ETA 124s
#   [TEST-200] 3400/20000 | 25s elapsed | ETA 123s
#   [TEST-200] 3500/20000 | 26s elapsed | ETA 123s
#   [TEST-200] 3600/20000 | 27s elapsed | ETA 122s
#   [TEST-200] 3700/20000 | 28s elapsed | ETA 121s
#   [TEST-200] 3800/20000 | 28s elapsed | ETA 121s
#   [TEST-200] 3900/20000 | 29s elapsed | ETA 120s
#   [TEST-200] 4000/20000 | 30s elapsed | ETA 119s
#   [TEST-200] 4100/20000 | 31s elapsed | ETA 119s
#   [TEST-200] 4200/20000 | 31s elapsed | ETA 118s
#   [TEST-200] 4300/20000 | 32s elapsed | ETA 117s
#   [TEST-200] 4400/20000 | 33s elapsed | ETA 116s
#   [TEST-200] 4500/20000 | 34s elapsed | ETA 115s
#   [TEST-200] 4600/20000 | 34s elapsed | ETA 115s
#   [TEST-200] 4700/20000 | 35s elapsed | ETA 114s
#   [TEST-200] 4800/20000 | 36s elapsed | ETA 113s
#   [TEST-200] 4900/20000 | 36s elapsed | ETA 112s
#   [TEST-200] 5000/20000 | 37s elapsed | ETA 112s
#   [TEST-200] 5100/20000 | 38s elapsed | ETA 111s
#   [TEST-200] 5200/20000 | 39s elapsed | ETA 110s
#   [TEST-200] 5300/20000 | 39s elapsed | ETA 109s
#   [TEST-200] 5400/20000 | 40s elapsed | ETA 109s
#   [TEST-200] 5500/20000 | 41s elapsed | ETA 108s
#   [TEST-200] 5600/20000 | 42s elapsed | ETA 107s
#   [TEST-200] 5700/20000 | 42s elapsed | ETA 106s
#   [TEST-200] 5800/20000 | 43s elapsed | ETA 106s
#   [TEST-200] 5900/20000 | 44s elapsed | ETA 105s
#   [TEST-200] 6000/20000 | 45s elapsed | ETA 104s
#   [TEST-200] 6100/20000 | 45s elapsed | ETA 104s
#   [TEST-200] 6200/20000 | 46s elapsed | ETA 103s
#   [TEST-200] 6300/20000 | 47s elapsed | ETA 102s
#   [TEST-200] 6400/20000 | 48s elapsed | ETA 101s
#   [TEST-200] 6500/20000 | 48s elapsed | ETA 100s
#   [TEST-200] 6600/20000 | 49s elapsed | ETA 100s
#   [TEST-200] 6700/20000 | 50s elapsed | ETA 99s
#   [TEST-200] 6800/20000 | 51s elapsed | ETA 98s
#   [TEST-200] 6900/20000 | 51s elapsed | ETA 97s
#   [TEST-200] 7000/20000 | 52s elapsed | ETA 97s
#   [TEST-200] 7100/20000 | 53s elapsed | ETA 96s
#   [TEST-200] 7200/20000 | 54s elapsed | ETA 95s
#   [TEST-200] 7300/20000 | 54s elapsed | ETA 94s
#   [TEST-200] 7400/20000 | 55s elapsed | ETA 94s
#   [TEST-200] 7500/20000 | 56s elapsed | ETA 93s
#   [TEST-200] 7600/20000 | 56s elapsed | ETA 92s
#   [TEST-200] 7700/20000 | 57s elapsed | ETA 91s
#   [TEST-200] 7800/20000 | 58s elapsed | ETA 91s
#   [TEST-200] 7900/20000 | 59s elapsed | ETA 90s
#   [TEST-200] 8000/20000 | 59s elapsed | ETA 89s
#   [TEST-200] 8100/20000 | 60s elapsed | ETA 88s
#   [TEST-200] 8200/20000 | 61s elapsed | ETA 88s
#   [TEST-200] 8300/20000 | 62s elapsed | ETA 87s
#   [TEST-200] 8400/20000 | 62s elapsed | ETA 86s
#   [TEST-200] 8500/20000 | 63s elapsed | ETA 86s
#   [TEST-200] 8600/20000 | 64s elapsed | ETA 85s
#   [TEST-200] 8700/20000 | 65s elapsed | ETA 84s
#   [TEST-200] 8800/20000 | 65s elapsed | ETA 83s
#   [TEST-200] 8900/20000 | 66s elapsed | ETA 82s
#   [TEST-200] 9000/20000 | 67s elapsed | ETA 82s
#   [TEST-200] 9100/20000 | 68s elapsed | ETA 81s
#   [TEST-200] 9200/20000 | 68s elapsed | ETA 80s
#   [TEST-200] 9300/20000 | 69s elapsed | ETA 79s
#   [TEST-200] 9400/20000 | 70s elapsed | ETA 79s
#   [TEST-200] 9500/20000 | 71s elapsed | ETA 78s
#   [TEST-200] 9600/20000 | 71s elapsed | ETA 77s
#   [TEST-200] 9700/20000 | 72s elapsed | ETA 77s
#   [TEST-200] 9800/20000 | 73s elapsed | ETA 76s
#   [TEST-200] 9900/20000 | 74s elapsed | ETA 75s
#   [TEST-200] 10000/20000 | 74s elapsed | ETA 74s
#   [TEST-200] 10100/20000 | 75s elapsed | ETA 73s
#   [TEST-200] 10200/20000 | 76s elapsed | ETA 73s
#   [TEST-200] 10300/20000 | 76s elapsed | ETA 72s
#   [TEST-200] 10400/20000 | 77s elapsed | ETA 71s
#   [TEST-200] 10500/20000 | 78s elapsed | ETA 71s
#   [TEST-200] 10600/20000 | 79s elapsed | ETA 70s
#   [TEST-200] 10700/20000 | 79s elapsed | ETA 69s
#   [TEST-200] 10800/20000 | 80s elapsed | ETA 68s
#   [TEST-200] 10900/20000 | 81s elapsed | ETA 68s
#   [TEST-200] 11000/20000 | 82s elapsed | ETA 67s
#   [TEST-200] 11100/20000 | 82s elapsed | ETA 66s
#   [TEST-200] 11200/20000 | 83s elapsed | ETA 65s
#   [TEST-200] 11300/20000 | 84s elapsed | ETA 65s
#   [TEST-200] 11400/20000 | 85s elapsed | ETA 64s
#   [TEST-200] 11500/20000 | 85s elapsed | ETA 63s
#   [TEST-200] 11600/20000 | 86s elapsed | ETA 62s
#   [TEST-200] 11700/20000 | 87s elapsed | ETA 62s
#   [TEST-200] 11800/20000 | 88s elapsed | ETA 61s
#   [TEST-200] 11900/20000 | 88s elapsed | ETA 60s
#   [TEST-200] 12000/20000 | 89s elapsed | ETA 59s
#   [TEST-200] 12100/20000 | 90s elapsed | ETA 59s
#   [TEST-200] 12200/20000 | 91s elapsed | ETA 58s
#   [TEST-200] 12300/20000 | 91s elapsed | ETA 57s
#   [TEST-200] 12400/20000 | 92s elapsed | ETA 56s
#   [TEST-200] 12500/20000 | 93s elapsed | ETA 56s
#   [TEST-200] 12600/20000 | 94s elapsed | ETA 55s
#   [TEST-200] 12700/20000 | 94s elapsed | ETA 54s
#   [TEST-200] 12800/20000 | 95s elapsed | ETA 54s
#   [TEST-200] 12900/20000 | 96s elapsed | ETA 53s
#   [TEST-200] 13000/20000 | 97s elapsed | ETA 52s
#   [TEST-200] 13100/20000 | 97s elapsed | ETA 51s
#   [TEST-200] 13200/20000 | 98s elapsed | ETA 51s
#   [TEST-200] 13300/20000 | 99s elapsed | ETA 50s
#   [TEST-200] 13400/20000 | 100s elapsed | ETA 49s
#   [TEST-200] 13500/20000 | 100s elapsed | ETA 48s
#   [TEST-200] 13600/20000 | 101s elapsed | ETA 48s
#   [TEST-200] 13700/20000 | 102s elapsed | ETA 47s
#   [TEST-200] 13800/20000 | 103s elapsed | ETA 46s
#   [TEST-200] 13900/20000 | 103s elapsed | ETA 45s
#   [TEST-200] 14000/20000 | 104s elapsed | ETA 45s
#   [TEST-200] 14100/20000 | 105s elapsed | ETA 44s
#   [TEST-200] 14200/20000 | 105s elapsed | ETA 43s
#   [TEST-200] 14300/20000 | 106s elapsed | ETA 42s
#   [TEST-200] 14400/20000 | 107s elapsed | ETA 42s
#   [TEST-200] 14500/20000 | 108s elapsed | ETA 41s
#   [TEST-200] 14600/20000 | 108s elapsed | ETA 40s
#   [TEST-200] 14700/20000 | 109s elapsed | ETA 39s
#   [TEST-200] 14800/20000 | 110s elapsed | ETA 39s
#   [TEST-200] 14900/20000 | 111s elapsed | ETA 38s
#   [TEST-200] 15000/20000 | 111s elapsed | ETA 37s
#   [TEST-200] 15100/20000 | 112s elapsed | ETA 36s
#   [TEST-200] 15200/20000 | 113s elapsed | ETA 36s
#   [TEST-200] 15300/20000 | 114s elapsed | ETA 35s
#   [TEST-200] 15400/20000 | 114s elapsed | ETA 34s
#   [TEST-200] 15500/20000 | 115s elapsed | ETA 33s
#   [TEST-200] 15600/20000 | 116s elapsed | ETA 33s
#   [TEST-200] 15700/20000 | 117s elapsed | ETA 32s
#   [TEST-200] 15800/20000 | 117s elapsed | ETA 31s
#   [TEST-200] 15900/20000 | 118s elapsed | ETA 30s
#   [TEST-200] 16000/20000 | 119s elapsed | ETA 30s
#   [TEST-200] 16100/20000 | 120s elapsed | ETA 29s
#   [TEST-200] 16200/20000 | 120s elapsed | ETA 28s
#   [TEST-200] 16300/20000 | 121s elapsed | ETA 27s
#   [TEST-200] 16400/20000 | 122s elapsed | ETA 27s
#   [TEST-200] 16500/20000 | 123s elapsed | ETA 26s
#   [TEST-200] 16600/20000 | 123s elapsed | ETA 25s
#   [TEST-200] 16700/20000 | 124s elapsed | ETA 25s
#   [TEST-200] 16800/20000 | 125s elapsed | ETA 24s
#   [TEST-200] 16900/20000 | 126s elapsed | ETA 23s
#   [TEST-200] 17000/20000 | 126s elapsed | ETA 22s
#   [TEST-200] 17100/20000 | 127s elapsed | ETA 22s
#   [TEST-200] 17200/20000 | 128s elapsed | ETA 21s
#   [TEST-200] 17300/20000 | 129s elapsed | ETA 20s
#   [TEST-200] 17400/20000 | 129s elapsed | ETA 19s
#   [TEST-200] 17500/20000 | 130s elapsed | ETA 19s
#   [TEST-200] 17600/20000 | 131s elapsed | ETA 18s
#   [TEST-200] 17700/20000 | 132s elapsed | ETA 17s
#   [TEST-200] 17800/20000 | 132s elapsed | ETA 16s
#   [TEST-200] 17900/20000 | 133s elapsed | ETA 16s
#   [TEST-200] 18000/20000 | 134s elapsed | ETA 15s
#   [TEST-200] 18100/20000 | 135s elapsed | ETA 14s
#   [TEST-200] 18200/20000 | 135s elapsed | ETA 13s
#   [TEST-200] 18300/20000 | 136s elapsed | ETA 13s
#   [TEST-200] 18400/20000 | 137s elapsed | ETA 12s
#   [TEST-200] 18500/20000 | 137s elapsed | ETA 11s
#   [TEST-200] 18600/20000 | 138s elapsed | ETA 10s
#   [TEST-200] 18700/20000 | 139s elapsed | ETA 10s
#   [TEST-200] 18800/20000 | 140s elapsed | ETA 9s
#   [TEST-200] 18900/20000 | 140s elapsed | ETA 8s
#   [TEST-200] 19000/20000 | 141s elapsed | ETA 7s
#   [TEST-200] 19100/20000 | 142s elapsed | ETA 7s
#   [TEST-200] 19200/20000 | 143s elapsed | ETA 6s
#   [TEST-200] 19300/20000 | 143s elapsed | ETA 5s
#   [TEST-200] 19400/20000 | 144s elapsed | ETA 4s
#   [TEST-200] 19500/20000 | 145s elapsed | ETA 4s
#   [TEST-200] 19600/20000 | 146s elapsed | ETA 3s
#   [TEST-200] 19700/20000 | 146s elapsed | ETA 2s
#   [TEST-200] 19800/20000 | 147s elapsed | ETA 1s
#   [TEST-200] 19900/20000 | 148s elapsed | ETA 1s
#   [TEST-200] 20000/20000 | 149s elapsed | ETA 0s
#   [TEST-200] Done — 100x200 in 149s
# Done.

# %% [markdown]
# # Cell 17: Attempt 7: Final QSVM (200 samples)

# %%
# QSVM
clf7, val_acc7, test_acc7, test_f17 = evaluate_qsvm(
    K_train_200, Y_tr2, K_val_200, Y_v2, K_test_200, Y_te2)
Y_pred7 = clf7.predict(K_test_200)

# Classical SVM
svm7 = svm.SVC(kernel="rbf", probability=True, class_weight="balanced", random_state=42)
svm7.fit(X_tr2, Y_tr2)
svm_pred7 = svm7.predict(X_te2)
svm_acc7  = accuracy_score(Y_te2, svm_pred7)
svm_f17   = f1_score(Y_te2, svm_pred7, average="weighted", zero_division=0)

print("=== QSVM Results (200 samples) ===")
print(f"Val Accuracy  : {val_acc7:.3f}")
print(f"Test Accuracy : {test_acc7:.3f}")
print(f"Test F1       : {test_f17:.3f}")
print(classification_report(Y_te2, Y_pred7,
      target_names=["Upward","Downward","Flat"], zero_division=0))

print("=== Classical SVM Results (200 samples) ===")
print(f"Test Accuracy : {svm_acc7:.3f}")
print(f"Test F1       : {svm_f17:.3f}")
print(classification_report(Y_te2, svm_pred7,
      target_names=["Upward","Downward","Flat"], zero_division=0))

attempt_log.append([
    7, "QSVM\nZZ Kernel\nFixed Adjoint\n200 samples",
    "Increased training subset to 200 samples. 200x200 kernel matrix = 40,000 circuit evaluations.",
    f"QSVM test acc: {test_acc7:.3f}, F1: {test_f17:.3f}. SVM test acc: {svm_acc7:.3f}, F1: {svm_f17:.3f}. QSVM wins on every metric.",
    "Success"
])
show_summary()
# Out:
# === QSVM Results (200 samples) ===
# Val Accuracy  : 0.817
# Test Accuracy : 0.740
# Test F1       : 0.736
#               precision    recall  f1-score   support
#
#       Upward       0.73      0.88      0.80        34
#     Downward       0.74      0.69      0.71        36
#         Flat       0.76      0.63      0.69        30
#
#     accuracy                           0.74       100
#    macro avg       0.74      0.74      0.74       100
# weighted avg       0.74      0.74      0.74       100
#
# === Classical SVM Results (200 samples) ===
# Test Accuracy : 0.720
# Test F1       : 0.723
#               precision    recall  f1-score   support
#
#       Upward       0.88      0.85      0.87        34
#     Downward       0.74      0.72      0.73        36
#         Flat       0.53      0.57      0.55        30
#
#     accuracy                           0.72       100
#    macro avg       0.72      0.71      0.72       100
# weighted avg       0.73      0.72      0.72       100
#
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.26 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.279. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.17-0.43. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9490. Gap: 0.0510. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0673 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7400. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 7  |QSVM ZZ Kernel  |Increased training subset to 200  |QSVM test acc: 0.740, F1: 0.736.  |✓ Success |
# |    |Fixed Adjoint   |samples. 200x200 kernel matrix =  |SVM test acc: 0.720, F1: 0.723.   |          |
# |    |200 samples     |40,000 circuit evaluations.       |QSVM wins on every metric.        |          |
# +----+----------------+----------------------------------+----------------------------------+----------+

# %% [markdown]
# # Cell 18: Output Figures (Success Attempt)

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 11))
fig.suptitle("QSVM vs Classical SVM — Final Results (200 Training Samples)",
             fontsize=14, fontweight="bold", color="#1F4E79")

class_names = ["Upward", "Downward", "Flat"]

# ── Plot 1: Kernel Matrix Heatmap ────────────────────────────────
ax = axes[0, 0]
sns.heatmap(K_train_200[:50, :50], cmap="viridis", ax=ax,
            xticklabels=False, yticklabels=False,
            cbar_kws={"label": "Kernel Value"})
ax.set_title("Quantum Kernel Matrix\n(first 50x50 of training set)", fontweight="bold")
ax.set_xlabel("Sample i")
ax.set_ylabel("Sample j")

# ── Plot 2: Confusion Matrices ───────────────────────────────────
ax = axes[0, 1]
cm_q  = confusion_matrix(Y_te2, Y_pred7)
cm_s  = confusion_matrix(Y_te2, svm_pred7)
cm_q_norm = cm_q.astype(float) / cm_q.sum(axis=1, keepdims=True)
sns.heatmap(cm_q_norm, annot=cm_q, fmt="d", cmap="Oranges",
            xticklabels=class_names, yticklabels=class_names,
            ax=ax, linewidths=0.5, cbar=False)
for i in range(3):
    ax.add_patch(plt.Rectangle((i, i), 1, 1, fill=False,
                                edgecolor="green", linewidth=2.5))
ax.set_title(f"QSVM Confusion Matrix\nTest Accuracy: {test_acc7:.3f}", fontweight="bold", color="#C0392B")
ax.set_xlabel("Predicted")
ax.set_ylabel("Actual")

# ── Plot 3: Per-class F1 ─────────────────────────────────────────
ax = axes[1, 0]
rep_q = classification_report(Y_te2, Y_pred7, output_dict=True, zero_division=0)
rep_s = classification_report(Y_te2, svm_pred7, output_dict=True, zero_division=0)

labels_f1 = ["Upward", "Downward", "Flat", "Overall"]
f1_q = [rep_q["0"]["f1-score"], rep_q["1"]["f1-score"],
        rep_q["2"]["f1-score"], rep_q["weighted avg"]["f1-score"]]
f1_s = [rep_s["0"]["f1-score"], rep_s["1"]["f1-score"],
        rep_s["2"]["f1-score"], rep_s["weighted avg"]["f1-score"]]

x     = np.arange(len(labels_f1))
width = 0.35
b1 = ax.bar(x - width/2, f1_s, width, color="#1F4E79", alpha=0.85, label="Classical SVM")
b2 = ax.bar(x + width/2, f1_q, width, color="#C0392B", alpha=0.85, label="QSVM")
for bar in b1:
    ax.text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.008,
            f"{bar.get_height():.2f}", ha="center", fontsize=9, color="#1F4E79", fontweight="bold")
for bar in b2:
    ax.text(bar.get_x()+bar.get_width()/2, bar.get_height()+0.008,
            f"{bar.get_height():.2f}", ha="center", fontsize=9, color="#C0392B", fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(labels_f1)
ax.set_ylim(0, 1.0)
ax.set_ylabel("F1 Score")
ax.set_title("Per-Class F1 Score Comparison", fontweight="bold")
ax.legend()
ax.grid(True, alpha=0.3, axis="y")

# ── Plot 4: Sample Size Crossover ────────────────────────────────
ax = axes[1, 1]
sizes    = [100, 200]
q_accs   = [test_acc6, test_acc7]
svm_accs = [svm_acc6,  svm_acc7]

ax.plot(sizes, q_accs,   "o-", color="#C0392B", linewidth=2.5,
        markersize=10, label="QSVM")
ax.plot(sizes, svm_accs, "s-", color="#1F4E79", linewidth=2.5,
        markersize=10, label="Classical SVM")
for s, q, sv in zip(sizes, q_accs, svm_accs):
    ax.annotate(f"{q:.3f}", (s, q),   xytext=(8, 5),  textcoords="offset points",
                fontsize=9, color="#C0392B", fontweight="bold")
    ax.annotate(f"{sv:.3f}", (s, sv), xytext=(8, -15), textcoords="offset points",
                fontsize=9, color="#1F4E79", fontweight="bold")
ax.axvspan(140, 210, alpha=0.07, color="#1A7A4A")
ax.annotate("QSVM\novertakes", xy=(200, test_acc7), xytext=(155, (test_acc7+svm_acc7)/2 - 0.03),
            arrowprops=dict(arrowstyle="->", color="#1A7A4A"), fontsize=9,
            color="#1A7A4A", fontweight="bold")
ax.set_xticks(sizes)
ax.set_xlabel("Training Samples")
ax.set_ylabel("Test Accuracy")
ax.set_title("Sample-Size Crossover", fontweight="bold")
ax.set_ylim(0.50, 0.82)
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("qsvm_results.png", dpi=150, bbox_inches="tight")
plt.show()
print("Figure saved as qsvm_results.png")
# Out:
# Figure saved as qsvm_results.png

# %% [markdown]
# # Cell 19: Classical SVM Confusion Matrix Side by Side

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))
fig.suptitle("Confusion Matrices: QSVM vs Classical SVM (200 Training Samples)",
             fontsize=13, fontweight="bold", color="#1F4E79")

for ax, cm, pred, title, cmap in zip(
    [ax1, ax2],
    [cm_s, cm_q],
    [svm_pred7, Y_pred7],
    [f"Classical SVM — Accuracy: {svm_acc7:.3f}", f"QSVM — Accuracy: {test_acc7:.3f}"],
    ["Blues", "Oranges"]
):
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
    sns.heatmap(cm_norm, annot=cm, fmt="d", cmap=cmap,
                xticklabels=class_names, yticklabels=class_names,
                ax=ax, linewidths=0.5, linecolor="white",
                vmin=0, vmax=1, cbar_kws={"label": "Proportion"})
    ax.set_title(title, fontsize=12, fontweight="bold")
    ax.set_xlabel("Predicted Label")
    ax.set_ylabel("True Label")
    for i in range(3):
        ax.add_patch(plt.Rectangle((i, i), 1, 1, fill=False,
                                    edgecolor="green", linewidth=2.5))

plt.tight_layout()
plt.savefig("confusion_matrices.png", dpi=150, bbox_inches="tight")
plt.show()
print("Figure saved as confusion_matrices.png")
# Out:
# Figure saved as confusion_matrices.png

# %% [markdown]
# # Cell 20: Final Summary Print

# %%
print("=" * 65)
print(f"{'Model':<22} {'Val Acc':<12} {'Test Acc':<12} {'Test F1'}")
print("=" * 65)
print(f"{'Classical SVM':<22} {'—':<12} {svm_acc7:<12.3f} {svm_f17:.3f}")
print(f"{'QSVM (100 samples)':<22} {val_acc6:<12.3f} {test_acc6:<12.3f} {test_f16:.3f}")
print(f"{'QSVM (200 samples)':<22} {val_acc7:<12.3f} {test_acc7:<12.3f} {test_f17:.3f}")
print("=" * 65)
print(f"\nQSVM gain over Classical SVM (200 samples):")
print(f"  Accuracy : +{test_acc7 - svm_acc7:.3f}")
print(f"  F1 Score : +{test_f17  - svm_f17:.3f}")

show_summary()
# Out:
# =================================================================
# Model                  Val Acc      Test Acc     Test F1
# =================================================================
# Classical SVM          —            0.720        0.723
# QSVM (100 samples)     0.675        0.600        0.598
# QSVM (200 samples)     0.817        0.740        0.736
# =================================================================
#
# QSVM gain over Classical SVM (200 samples):
#   Accuracy : +0.020
#   F1 Score : +0.014
#
# ========================================================================================================
#   DEVELOPMENT ATTEMPT SUMMARY
# ========================================================================================================
# +----+----------------+----------------------------------+----------------------------------+----------+
# | #  |    Approach    |          What Was Tried          |          Output / Issue          |  Status  |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 1  |QNN 30 samples  |Variational circuit with finite   |Loss flat ~0.24-0.26 all epochs.  |✗ Failed  |
# |    |eta=0.04        |difference SGD. 30 samples,       |Train acc oscillated 0.240-0.279. |          |
# |    |                |eta=0.04, 20 epochs, 1000 shots.  |No learning trend. Shot noise     |          |
# |    |                |                                  |overwhelms gradient signal.       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 2  |QNN 80 samples  |Same QNN. Increased to 80 samples,|Loss still flat 0.22-0.29. Train  |✗ Failed  |
# |    |eta=0.1         |eta=0.1, 30 epochs. Added         |acc 0.21-0.51, val 0.17-0.43. High|          |
# |    |                |validation tracking.              |variance, no trend. Fundamental   |          |
# |    |                |                                  |problem confirmed.                |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 3  |QSVM Rx/Rz      |First QSVM. Rx/Rz rotation kernel.|Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, pi]  |Features in [0, pi].              |0.9085. Gap: 0.0915. All samples  |          |
# |    |                |                                  |near-identical. QSVM test acc     |          |
# |    |                |                                  |~0.433.                           |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 4  |QSVM Rx/Rz      |Same Rx/Rz circuit. Features      |Self-kernel: 1.0000. Cross-kernel:|✗ Failed  |
# |    |Kernel [0, 2pi] |rescaled to [0, 2pi].             |0.9490. Gap: 0.0510. Improved but |          |
# |    |                |                                  |still below 0.15 threshold. No    |          |
# |    |                |                                  |entanglement.                     |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 5  |QSVM ZZ Kernel  |ZZ feature map with CNOT          |Self-kernel: 0.0673 (must be 1.0).|✗ Failed  |
# |    |Wrong Adjoint   |entanglement. Applied feature map |Mathematically invalid. Even      |          |
# |    |                |twice as inverse — incorrect.     |identical samples not recognized  |          |
# |    |                |                                  |as similar.                       |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 6  |QSVM ZZ Kernel  |Correct adjoint: reversed gate    |Self-kernel: 1.0000. Gap: 0.7400. |~ Partial |
# |    |Fixed Adjoint   |order + negated angles. 100       |QSVM test acc: 0.600, F1: 0.598.  |          |
# |    |100 samples     |training samples.                 |Classical SVM: 0.700. QSVM        |          |
# |    |                |                                  |learning correctly.               |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
# | 7  |QSVM ZZ Kernel  |Increased training subset to 200  |QSVM test acc: 0.740, F1: 0.736.  |✓ Success |
# |    |Fixed Adjoint   |samples. 200x200 kernel matrix =  |SVM test acc: 0.720, F1: 0.723.   |          |
# |    |200 samples     |40,000 circuit evaluations.       |QSVM wins on every metric.        |          |
# +----+----------------+----------------------------------+----------------------------------+----------+
